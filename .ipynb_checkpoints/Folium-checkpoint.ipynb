# %%
import pandas as pd
import os
import folium

# %%
path = os.path.join(".", "people_1908.csv")
people_1908 = pd.read_csv(path)

# %%
people_1908 = people_1908.fillna("")
people = people_1908[:100].reset_index()[['Last name', 'First name', 'address']]
people
# Out:
#                           Last name     First name  \
# 0                  ABRADIE-d’ARRAST  Michel-Robert
# 1                         ABBATUCCI
# 2                         ABBATUCCI
# 3                          ABOILARI        Georges
# 4   ABOVILLE et Mme née IIENNE-CART      Christian
# ..                              ...            ...
# 95      ANCEAL et Mme née HEODERERT         Eugène
# 96                            ANCEL        Adolphe
# 97       ANCEL et Mme née COPPINGER          Raoul
# 98                            ANCEL        Georges
# 99                         ANDERSON        Captain
#
#                              address
# 0               5S bis rue Jouffroy
# 1                 103 rue La Boétie
# 2                 32 rue Washington
# 3             46 avenue de Breteuil
# 4                23 rue de Grenelle
# ..                               ...
# 95   114 ave nue des Champs-Elysées
# 96                103 rue La Boétie
# 97                19 rue de Bassano
# 98             191 boni. St-Gcrmain
# 99              33 avenue Montaigne
#
# [100 rows x 3 columns]

# %%
paris_coord = [48.864716, 2.349014]
paris_1908 = folium.Map(location=paris_coord)
paris_1908
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#pip install geopy
from geopy.geocoders import Nominatim

# %%
people["latitude"] = "0"
people["longitude"] = "0"
for i in range(len(people)):
    geolocator = Nominatim(user_agent=people["Last name"][i])
    print(people['address'][i])
    #coord = geolocator.geocode(people['address'][i])
    people["latitude"][i] = coord.latitude
    people["longitude"][i] = coord.longitude

people
# Out:
#  5S bis rue Jouffroy
#  103 rue La Boétie
#  32 rue Washington
#  46 avenue de Breteuil
#  23 rue de Grenelle
#  28 rue Copernic
#  12 ave- nue Henri-Martin
#  12 avenue Henri- Martin
#  12 avenue Henri-Martin
#  12 avenue Henri-Martin
#  181 rue de La Pompe
#  62 avenue de la Grande-Armée
#  124 rue de Provence
#  26 avenue Mar ceau
#  9 place des Etats- Unis
#  19 rue de Presbourg
#  29 avenue Friedland
#  21 avenue d’Antin
#  2 bis rue de La Baume
#  2 bis rue de La Baume
#  47 bis rue Ampère
#  33 avenue d’Antin
#  23 avenue de Messine
# 75rue deCourcelles
#  31 rue Pierre- Charron
#  55 rue Pierre Charron
#  24 rue de Courcelles
#  24 rue de Courcelles
# 20 rue Daru
#  3 rue de Monceau
#  33 rue Was hington
#  147 rue de Rennes
#  14 rue Weber
#  24 rue Clément-Marot
#  50 avenue Victor- Hugo
#  59 rue de Prony
#  59 rue Chardon-Lagache
#  78 avenue Henri-Martin
#  19 boulevard de La Tour-Maubourg
#  63 bis rue de Yarenne —
#  63 bis rue de Yarenne —
#  74 rue Michel-Ange [Ht 239.81]—et fljj le Prieuré Saint-Michel à Saint- Pair-sur-la-Mer
#  8 rue Magellan
#  8 rue Magellan
#  60 rue François-lor
#  5 rue Montaigne
#  16 rue Bayard
#  16 rue Bayard
# 214 boni. Saint-Germain
#  44 rue François- Ir
#  3 rue Le Nôtre
#  9 square Lamartine
#  73 boulevard Haussmann
#  224 rue de Rivoli IJ- 243.89]. ALBERT-MORIX
#  6 impasse des Gendarmes à Versailles — et ^ d’Orthe a ]ÿ= St-MartindeConnée
#  17 rue Vaneau
#  3 rue St Didier
#  35 rue St-Bominique
#  4 sq. du Roule
#  4 sq. du Roule
#  1 place des Perchamps
#  64 avenue du Bois- de-Boulogne
#  38 avenue Gabriel
#  46 rue Pierre-Charron
#  165 avenue de Wagram [7. 557.85]
#  165 avenue de Wagram [7. 557.85]
#  31 quai d’Orsay
#  89 faubourg St-Honoré
#  17 avenue d’Eylau
#  16 rue Mari- gnati
#  101 rue du Bac
#  10 rue La Terrasre
#  5 quai Malaquuis
#  19 rue Leroux
#  21 avenue de l’Alina
#  39 rue d’Artois
#  39 rue d’Artois
#  30 rue Boissière
#  28 avenue du Troca- déro
#  11 avenue de L11 Grande Armée
#  11 avenue de L11 Grande Armée
#  20 rue Washington
#  72 avenue Kléber
#  72 avenue Kléber
#  119 avenue de Wagram
#  57 avenue Kléber
#  13 rue Lôon-Cogniet [7. 549.46]
#  11 avenue Hoche
#  11 avenue Hoche
#  9 rue Portalis
#  9 boulevard de La Tour- Maubourg
#  3 boni de La Tour Maubourg
#  9 boulevard de La Tour-Maubourg
#  64 ave nue du Bois-de-Boulogne
#  66 avenue des Champs- Elysées
#  114 ave nue des Champs-Elysées
#  103 rue La Boétie
#  19 rue de Bassano
#  191 boni. St-Gcrmain
#  33 avenue Montaigne
#                           Last name     First name  \
# 0                  ABRADIE-d’ARRAST  Michel-Robert
# 1                         ABBATUCCI
# 2                         ABBATUCCI
# 3                          ABOILARI        Georges
# 4   ABOVILLE et Mme née IIENNE-CART      Christian
# ..                              ...            ...
# 95      ANCEAL et Mme née HEODERERT         Eugène
# 96                            ANCEL        Adolphe
# 97       ANCEL et Mme née COPPINGER          Raoul
# 98                            ANCEL        Georges
# 99                         ANDERSON        Captain
#
#                              address latitude longitude
# 0               5S bis rue Jouffroy   48.8736   2.30377
# 1                 103 rue La Boétie   48.8736   2.30377
# 2                 32 rue Washington   48.8736   2.30377
# 3             46 avenue de Breteuil   48.8736   2.30377
# 4                23 rue de Grenelle   48.8736   2.30377
# ..                               ...      ...       ...
# 95   114 ave nue des Champs-Elysées   48.8736   2.30377
# 96                103 rue La Boétie   48.8736   2.30377
# 97                19 rue de Bassano   48.8736   2.30377
# 98             191 boni. St-Gcrmain   48.8736   2.30377
# 99              33 avenue Montaigne   48.8736   2.30377
#
# [100 rows x 5 columns]

# %%
for i in range(len(people)):
    folium.Marker([people["latitude"][i], people["longitude"][i]], \
                  popup=people['Last name'][i] + people['First name'][i]).add_to(paris_1908)

# %%
paris_1908
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
geolocator = Nominatim(user_agent="Test")
geolocator.geocode("74 rue Michel-Ange [Ht 239.81]—et fljj le Prieuré Saint-Michel à Saint- Pair-sur-la-Mer ")
