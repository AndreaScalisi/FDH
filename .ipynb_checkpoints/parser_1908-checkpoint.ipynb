# %%
import pandas as pd
import numpy as np
path = 'beau_monde_1908.txt'

# %%
# Import data
r = open(path, 'r')
raw_data = r.readlines()
r.close()
raw_data = raw_data[23:] # Skipping intro of the directory

# %%
raw_data
# Out:
# ['A\n',
#  '\n',
#  '\n',
#  "Aage (cl’) voir Colmet (I'Aage.\n",
#  '\n',
#  '\n',
#  'ABRADIE-d’ARRAST (Michel-Robert d’), 5S bis, rue\n',
#  'Jouffroy (xvu*) — et d’Elhorriaga, S Saint-\n',
#  'Jcan-de-Luz (Basses-Pyrénées).\n',
#  '\n',
#  '\n',
#  'ABBATUCCI, née de FORESTA (M-), 103, rue La\n',
#  'Boétie (vin*) [35 321.S7] — et fljj Rey de Foresta, SI\n',
#  "[s ' â [A] Montmorency (Seine-et-Oise).\n",
#  'ABBATUCCI (C“ Jacques), 103, rue La Boétie (mi‘)\n',
#  '[35 521.57] — et même A . Sp-RR\n',
#  '\n',
#  '\n',
#  'ABBATUCCI (C1""*), 32, rue Washington (vni\'j.\n',
#  'ABEILLE (Adolphe),27, Faubourg-Saint-Honoré (vm*)\n',
#  'et haras de Viroflay, CK! feâ Virollay [35 3)\n',
#  '\n',
#  '\n',
#  '(Seine-et-Oise). RR-UA-T\n',
#  '\n',
#  '\n',
#  'ABOILARI) Georges), U. #,[et M“" née BONUS], 46,\n',
#  'avenue de Breteuil (vu*) [35 707.11] — et de\n',
#  'Peyrieu, Kl \\p= eS Peyrieu (Ain). AC-M-YC\n',
#  "ABOVILLE (V‘* H. d’), O.iK, Colonel du 131' de ligne\n",
#  'à Orléans [et V*,“‘ née de GOUVELLO de KÉ-\n',
#  'RIAVAL], à d® Kerentré, K {s= aË [0] Auray\n',
#  '(Morbihan) — et de Rouville, K à\n',
#  '[P.L.M.] Malesherbes (Loiret).\n',
#  '\n',
#  '\n',
#  'Paris-Mondain — 1908\n',
#  '\n',
#  '\n',
#  'ABOVILLE (B** Christian d’) [et B*»”" née I1ENNE-\n',
#  'CART], 23, rue de Grenelle (vu*)— et A deGlux,\n',
#  'K Chàteau-Chinon fs= St-Prix-sous-Beuvray, 1 kil.\n',
#  '(Nièvre), Etang, 22 kil. (Saône-et-Loire) ou gg.\n',
#  '\n',
#  '\n',
#  'de E’achin-le-Chàtelet, 10 kil. — et ^ de Brouay,\n',
#  'K ]ÿ= Audrieu (Calvados).\n',
#  '\n',
#  '\n',
#  'Alt RA Ml (II* Henri) [et M«« née KNITTEL], 28, rue\n',
#  'Copernic (xvi*), 35 667.01.\n',
#  '\n',
#  '\n',
#  "ABRANTÈS, née JL'XOT (LE RAY, v--° d’), 12, ave-\n",
#  'nue Henri-Martin (xvi*) — et sêâ de Bailleul, K)\n',
#  'Gorron (Mayenne), ^ [O] St-Denis-de-Gastines.\n',
#  '\n',
#  '\n',
#  "ABRANTÈS (Duc d’), Capitaine d'infanterie hors\n",
#  'cadres, à F État-major du Gouverneur de Xicer\n',
#  '[et !)**• nee Nicole, de MAIGRET], 12, avenue Henri-\n',
#  'Martin (xvi*) —- même de Bailleul — et villa\n',
#  '\n',
#  '\n',
#  '“ Myosotis " Vallon des Fleurs à Nice.\n',
#  '\n',
#  '\n',
#  'ABRANTÈS (M** d’}, Lieutenant au 14e hussards à\n',
#  'Alençon (et Mi,# née Hélène LANGSDORFF], 12,\n',
#  'avenue Henri-Martin (xvi*) — et même M.\n',
#  '\n',
#  '\n',
#  "ABRANTÈS (Cte d’}, Lieutenant au îS6* d'infanterie\n",
#  'à St-Lô (Manche), mêmes adresses.\n',
#  '\n',
#  '\n',
#  '3\n',
#  '\n',
#  '\n',
#  'ABZ\n',
#  '\n',
#  '\n',
#  '34\n',
#  '\n',
#  '\n',
#  'A GH\n',
#  '\n',
#  '\n',
#  'ABZAC (C1""* Paul d’), 181, rue de La Pompe (xvi*).\n',
#  'fACHER de MONTGASCON ll!°» d’) [et B”""\' née Jeanne\n',
#  'de COURCY], 18, avenue d’Antin (vui"),— et ià\n',
#  'de Villequier, E M [Q], Caudebec-en-Caux (Seine-\n',
#  'Inférieure) Villequier.\n',
#  '\n',
#  '\n',
#  "ACHERY de SAS DON'N'IN'O (P“ d’), Ex-camérier\n",
#  'secret, 62, avenue de la Grande-Armée (xvn‘) — et\n',
#  'de Soisy-sous-Montmorency, 121 35 *3 [N]\n',
#  '\n',
#  '\n',
#  'Soisy-sous-Montmorency (Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  "ACHON (B°n René d'), Capitaine au l*r chasseurs [et\n",
#  "B'*” née de LAMOLÈRE, Cu”* d'HUST], 124, rue\n",
#  'de Provence (vm*), — et de la Roche-de-\n',
#  'Gennes, El Gennes (Maine-et-Loire), M [Or],\n',
#  '\n',
#  '\n',
#  'Les Rosiers-sur-Loire.\n',
#  '\n',
#  '\n',
#  "AGLOQLE (Mm*) née DU CH AN O Y', 26, avenue Mar¬\n",
#  'ceau (xvi" )— et jÎ5 de La Borde, E Saint-An-\n',
#  'toiue-du-Rocher, (35 au £•£ .N” S), M Mettray\n',
#  '(Indre-et-Loire).\n',
#  '\n',
#  '\n',
#  "ACLOQL'E (M»« AWnée SEBERT, 9, place des Etats-\n",
#  'Unis (xvi*)-[35 698.92].\n',
#  '\n',
#  '\n',
#  "ACI.OQl'E (Maurice), 19, rue de Presbourg (xvi') — et\n",
#  'villa Monténégro [35 590], à Cannes (Alpes-Mari¬\n',
#  'times). AC-Y\n',
#  '\n',
#  '\n',
#  'ACOLLÀS (René), K, Conseillerréférendaire à la Cour\n',
#  'des Comptes [et Mm* née de MOY], 29, avenue\n',
#  'Friedland (vin*) [35 547.26]\n',
#  '\n',
#  '\n',
#  'Acquasanta (d’) voir de Narducci.\n',
#  '\n',
#  '\n',
#  'ADAM (Achille), Député du Pas-de-Calais, 21, avenue\n',
#  'd’Antin (vin*) [35 311.04] — et 10, rue Victor-Hugo,\n',
#  'à Boulogne-sur-Mer (Pas-de-Calais), —et « La Soli¬\n',
#  'tude », à Saint-Quentin-en-Tourmont, par Rue\n',
#  '(Somme). AC-B-HRRUA\n',
#  '\n',
#  '\n',
#  'ADAM (M“* Achille), née VERBERKMOÉS — et *£$\n',
#  'de Verneuil, E î;~ Si [Or] Verneuil-sur-Indre\n',
#  '(Indre-et-Loire).\n',
#  '\n',
#  '\n',
#  'ADAM (M“* Eugène), 2 bis, rue de La Baume (vin")\n',
#  "[35 520.00] — et 24, rue de Confiai», à'Poissy,\n",
#  '35 (Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  'ADAM (Henri), mêmes adresses. AC\n',
#  '\n',
#  '\n',
#  'ADAM (Mm* Hippolytel, 47 bis, rue Ampère (xvn")\n',
#  '[35 525.33] — et & des Mazurettes, E é3\n',
#  '\n',
#  '\n',
#  '[N] Boulogne (Pas-de-Calais),\n',
#  '\n',
#  '\n',
#  'ADAM (M- Léon) née JÉROME PICHON, 33, av.\n',
#  'd’Antin (vnr).\n',
#  '\n',
#  '\n',
#  'ADAM (M. et M“* Georges), 23, av. de Messine (vin")\n',
#  '— et 14, rue Circulaire, à Versailles.\n',
#  '\n',
#  '\n',
#  'ADAM (Louis), Agent de change [et M»» née PIERRETJ\n',
#  '23, av. de Messine (vm") (bureaux: 48, rue de Pro¬\n',
#  'vence) (ix*) [35 136.13] — et jgj deBrancas, E jj=\n',
#  'éS [0] Sèvres (Seine-et-Oise), — et villa Ellon, à\n',
#  'Lion-sur-Mer (Calvados).\n',
#  '\n',
#  '\n',
#  'ADAM (Juliette LAMBER) (M“* Edmond), abbaye de\n',
#  'Gif (Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  'ADAN (Emile), ÿ [etMm,],75,r. deCourcelles(vm")UA\n',
#  'ADDA SALVATERRA (M11* d’), 37, avenue Montaigne\n',
#  '(vin").\n',
#  '\n',
#  '\n',
#  'ADELINE, née F AU (M” Edmond), 31, rue Pierre-\n',
#  'Charron (xvi*) — et {£à de Sérigny, 0 J: ^\n',
#  '[Or] Cour-Cheverny (Loir-et-Cher).\n',
#  '\n',
#  '\n',
#  'ADELINE (M““ Raoul), née FROGER des CHESNES,\n',
#  'pavillon de La Louetière, E â [Or] Cour-\n',
#  'Chcverny (Loir-et-Cher).\n',
#  '\n',
#  '\n',
#  'ADELINE (Gaston) [et M"" née DELONDRE], 55, rue\n',
#  'Pierre Charron (vin") —■ et {^3 de Moussonvilliers,\n',
#  "E ]ÿ= S'-Maurice-les-Charençais, 5 kil. (Orne) gji\n",
#  '[0] La Ferté-Vidame (Eure-et-Loir). H-UA\n',
#  '\n',
#  '\n',
#  "ADELON, née HAENTJEN'S (M- Henry), 24, rue\n",
#  'de Courcelles (vm*) [35 517.06].\n',
#  '\n',
#  '\n',
#  'ADELON (Marcel), même adresse.\n',
#  '\n',
#  '\n',
#  'ADELSWARD (B””»" Axel d\'), née WUHRER,20, rue\n',
#  'Daru (vm") — et à Nice.\n',
#  '\n',
#  '\n',
#  'ADELSWARD (B***" Gustave d\'), née de POURTALÈS\n',
#  '63, boulevard de Courcelles (vin*) [35 508.32] — et\n',
#  '(£3 du Plessis-Mornay, E Rochefort-en-Yveliues,\n',
#  '1f= [35 24], Donrdan (Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  "ADEN'IS de LA ROZERIE (A.-H), Conseiller Maître\n",
#  'à la Cour des Comptes, 0. K, 3, rue de Monceau (vin0),\n',
#  '\n',
#  '\n',
#  'ADHÉMAR (C""" d’), née MARIANT, 33, rue Was¬\n',
#  'hington (vm*).\n',
#  '\n',
#  '\n',
#  'ADHÉMAR (V“ Olivier d’), K [etV1*"*\' née VERDET]\n',
#  '86, rue do Yarenne (vu*)— et à de Saint-Hubert,\n',
#  'E Sorgues-sur-l’Ouvèze (Vaucluse — et éêS de\n',
#  'Teillan, E Marsillargues (Hérault).\n',
#  '\n',
#  '\n',
#  'ADHÉMAR (Vf Robert d’), à Lille (Nord).\n',
#  '\n',
#  '\n',
#  'AFFRE de SAINT-ROME (Cl°“* Denis) [née de NOGA-\n',
#  'RET], 147, rue de Rennes (vi*) — et à Soisy-sous-Mont¬\n',
#  'morency, E îf= (Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  'AGACHE (Alfred), 14, rue Weber (xvi*). UA\n',
#  '\n',
#  '\n',
#  'AGHION (M. et Mm" Jules), 24, rue Clément-Marot,\n',
#  '(vm") [35 501.87]. CF\n',
#  '\n',
#  '\n',
#  'Agneau (d’) voir: Carpentier d’AGNEAU.\n',
#  '\n',
#  '\n',
#  'Agneaux (d’) voir: de S" Marie d’Agneaux.\n',
#  '\n',
#  '\n',
#  "AGN'ELLET (M. et Ilm‘ Augustin), 50, av. Victor-\n",
#  'Hugo (xvi*).\n',
#  '\n',
#  '\n',
#  'AGN\'ELLET (M11* Emma), 59, rue de Prony (xvn")\n',
#  '— et villa à Menthon-Saint-Bernard, E [Z- (Haute-\n',
#  'Savoie), fg [P.-L.-M.] Annecy.\n',
#  '\n',
#  '\n',
#  'AGNES (Eugène), 59, rue Chardon-Lagache (xvi»),\n',
#  '\n',
#  '\n',
#  'AGO.N (la Générale M“* d’), née TIEUSONNYER, 78,\n',
#  'avenue Henri-Martin (xvi*) — et *& de Sampange,\n',
#  'E Nevers (Nièvre).\n',
#  '\n',
#  '\n',
#  'AG0PIAN-PACHA (M»"), née KHORASSANDJ1,\n',
#  '98, boulevard Malesherbes (vui").\n',
#  '\n',
#  '\n',
#  'AGOPIAN-PACHA (L.), môme adresse. Y\n',
#  '\n',
#  '\n',
#  'AGOl\'LT (M**d’) [et M\',"néede MONTRICH AHD], gft\n',
#  'de Vandœuvre, E Coulans (Sarthe) àZ [0|. Le\n',
#  'Mans (Sarthe).\n',
#  '\n',
#  '\n',
#  'AGOl\'LT (C\'" d’), ancien député [et C1""” née\n',
#  'd’ESTAMPES], 19, boulevard de La Tour-Maubourg\n',
#  '(vu") et — {gs de Beauplan, E 35. Voreppe Isère .\n',
#  '\n',
#  '\n',
#  'AG R AIN née de GESTAS de LESPÉROUX, (M*“ d’),\n',
#  '63 bis, rue de Yarenne — (vu*) et A de Rressey,\n',
#  "E Arc-sur-Tille 3 kil. (Côte-d'Or) [P.-L.-M.].\n",
#  'd’Arc-sur-Tille et Magny.\n',
#  '\n',
#  '\n',
#  'AGRAI.N (G** Jean d’) [et Cl,“* née Geneviève\n',
#  'R0UT1NY], mêmes adresses — et villa St-Vallier\n',
#  'à Nice.\n',
#  '\n',
#  '\n',
#  'AG R AIN (V“ Henri d’), mômes adresses.\n',
#  '\n',
#  '\n',
#  'AGR\n',
#  '\n',
#  '\n',
#  '33\n',
#  '\n',
#  '\n',
#  'ALF\n',
#  '\n',
#  '\n',
#  'AGRAIN (11\'» d’), Lieutenant au 1" Dragons [et\n',
#  'M\'" née de JESSÉ-LEYAS], —même de Bressey\n',
#  'et à Joigny (Yonne) [Jï 30J.\n',
#  '\n',
#  '\n',
#  "AGl'EN (P.-L. d’) [et M”*], 74, rue Michel-Ange, [Ht\n",
#  '239.81]—et fljj le Prieuré Saint-Michel, à Saint-\n',
#  'Pair-sur-la-Mer (Manche).\n',
#  '\n',
#  '\n',
#  'AGUERA (F. G. de), 8, rue Magellan (Viir). RR-UA\n',
#  "Aguesseau (d') : voir de Skguh d’AcuEssEAU.\n",
#  'AGUIAR (M” Guillaume PINTO d’), 31, rue Pierre-\n',
#  'Charron (XVIe).\n',
#  '\n',
#  '\n',
#  'AGUIAR (Louis PINTO d’), même adresse. AG-GF\n',
#  'AICARD (M. Jean), 40, rue de Luxembourg, et villa\n',
#  'les Lauriers-Roses à La Garde (Var).\n',
#  '\n',
#  '\n',
#  'AIGNAN, née MOSSELMAN (M”* Léon), 60, rue\n',
#  'François-lor (viii*).\n',
#  '\n',
#  '\n',
#  'AIGNAN (Gabriel) [et M““ née Mariquita del VALUE\n',
#  'de MENA], 5, rue Montaigne (vnr)—et à Douvres-\n',
#  'la-Délivrande (Calvados). SH-CM-UA\n',
#  '\n',
#  '\n',
#  "Aighepokt (d1) : voir d'Ai.F,YRAC (d1).\n",
#  '\n',
#  '\n',
#  'AILLIÈRES, née GÉRARD (M™ Fernand d’), 16, rue\n',
#  "Bayard (vin») — et jà d'Aiüières, a jg\n",
#  '[0] Mamers (Sarthe).\n',
#  '\n',
#  '\n',
#  'AILLIÈRES (M. Louis d‘), mêmes adresses. J\n',
#  '\n',
#  '\n',
#  'AILLIÈRES (Le Colonel Etienne d’), Commandant le\n',
#  '10° Cuirassiers, H, [et M“° née de SAINT-LAUMER],\n',
#  '123, rue de Lille (vu0) et 8, boulevard du Nord,\n',
#  'à Lyon (Rhône).\n',
#  '\n',
#  '\n',
#  'AILLIÈRES (M. Jean d’) [et M»° née de FRÉVILLE\n',
#  'deLORME],214, boni. Saint-Germain (vu») [P.-A.-T].\n',
#  'AILLY (B»—”1 Jacques d’J née Thérèse de JUMILHAC\n',
#  '30, rue Boissière (xvr) — 0*3 d’Ailly, 123 Roanne\n',
#  '(Loire), Le Coteau, 4 kil. tfë [P.-L.-M.] Le\n',
#  "Coteau, l'Hôpital et Roanne, 4 kil.—et M d’Alosse,\n",
#  '1SI Marcilly-en-Villette, 4 kil. (Loiret), @1\n',
#  '[Or] La Ferlé St-Aubin et St-Cyr-en-Yal, 12 kil.\n',
#  'AILLY lie VERNE CIL (M. d’), O. #, Sgndiedes Agents\n',
#  'de change [et Mm» née TRICHARD], 30, avenue\n',
#  'Montaigne (vin*).\n',
#  '\n',
#  '\n',
#  "A INVAL (Vu d’), Lieutenant d’Artillerie [et V'----\n",
#  'née HA Y des XETUM1ÈRESJ, 44, rue François-\n',
#  'I,r (vin») fp.-â-t.).\n',
#  '\n',
#  '\n',
#  'AKEIÏMANN (M.) [et M“» née Germaine RENIER], 3,\n',
#  'rue Le Nôtre (xvr).\n',
#  '\n',
#  '\n',
#  'ALADRO KASTRIOTI (S. A. S. le P°* don Juan de),\n',
#  'ancien Ministre Plénipotentiaire d’Espagne ien\n',
#  'son hôtel), 9, square Lamartine (xvr). B-UA\n',
#  'ALAMAGNïj (Edouard), 26, rue Bayard (viir),\n',
#  '[iH 331 Tl] — fià de Cm aise, ES) [£= Mont¬\n',
#  'brison (Loire). Sp\n',
#  '\n',
#  '\n',
#  'ALAVOINE (Auguste) [et Mm°], Ê des Ormeaux,\n',
#  "IS1 R= Benodet, [0' Quimper (Finistère). A\n",
#  'Albebti.ni : voir Uiaz-Albertini.\n',
#  '\n',
#  '\n',
#  'ALBEKTI (Léopold) [et M“* née REITLINGER], 73,\n',
#  'boulevard Haussmann (vnr).\n',
#  '\n',
#  '\n',
#  'ALBERT-LAMBERT (M.), Sociétaire de la Comédie-\n',
#  'Française, O. I. ||, [et M“” née Angèle BASSA-\n',
#  'LER], 224, rue de Rivoli IJ- 243.89].\n',
#  'ALBERT-MORIX (Jean) [et M- née JANNIN], jfo\n',
#  'de Gravelles, a Etrechy (Seine-et-Oise). UA-Y\n',
#  '\n',
#  '\n',
#  "ALBIGNAC (M” d’) [et M'-» née d’OIfFEUILLE], 6,\n",
#  'impasse des Gendarmes, à Versailles — et ^\n',
#  'd’Orthe, a ]ÿ= St-MartindeConnée(Mayenne),^\n',
#  '[OJ Sillé-le-Guillaume. ^\n',
#  '\n',
#  '\n',
#  "ALBON (M1* d’) [et M'-« née de SETTANCOURT-\n",
#  'VAUBECOURT], 17, rue Vaneau (vu°) — et ^\n',
#  'd’Avauge, a Pontcharra- sur-Tardine (Rhône),\n',
#  'M [P-L-M] St-Romaiii-de-Popey. H-J-U\n',
#  '\n',
#  '\n',
#  'ALBRECHT do MARTENS, [et Mm” née de LAVA], 3,\n',
#  "rue St Didier (xvr) — et gZz d'Epaux, a jj= gg\n",
#  'Chàleau-Thierry (Aisne).\n',
#  '\n',
#  '\n',
#  'ALBUFÉRA (SUCHËT, Duc d’) [et D»"» née de CAM¬\n',
#  'BACÉRÈS], 35, rue St-Bominique (vu°) — et M de\n',
#  'Montgoborta jÿ=^|[N]Yillers-Cotterêts (Aisne) J-U\n',
#  "ALBUFÉRA (SI CHET, M'1 d’), [et M -- née Anna\n",
#  "MASSENA de RIVOLI, P-° d'ESSLING], 40, av.\n",
#  'Hoche (vin») [A 511.49], et 10, rue Jean-Goujon\n',
#  '(vnr), — et à de Montgobert, a Villers-Cotte-\n',
#  'rets Cœuvres et Valsery, 3 kil., M [N| Villers-\n',
#  'Cotterets, 10 kil. ou Longpont 7 kil. (Aisne)-Bet\n',
#  'villa Masséna, 1, rue de France, à Nice (Alpes-\n',
#  'Maritimes). J-U\n',
#  '\n',
#  '\n',
#  'ALBl’QUERQUE (B°” de), 4, sq. du Roule (vin*). UA\n',
#  "ALBYVILLE (C*« d') [et C'«— née de SERCEY],\n",
#  'éêü <in Chatelier, a Binan (Côtes-du-Nord) — et\n',
#  'ÉÊâ de Ilomigny, a Sains (Somme)\n',
#  '\n',
#  '\n',
#  'ALCANTARA ((>»■■« AI var d’), née de GAUDE-\n',
#  'CHART, 2, rue de la Planche (vu») — et O de\n',
#  'Qiierrieu, a Querrieu (Somme), [N] Amiens.\n',
#  "ALCANTARA (Cte Jean d’) et [(>■■' née T EINT DE\n",
#  'ROODENBEKE, mêmes adresses.\n',
#  '\n',
#  '\n',
#  'ALCEDO (M-- d’) [et M - née de BANUELOS], villa\n',
#  'Alcedo, à Biarritz (Basses-Pyrénées) — et,\n',
#  'Castrelos, Yigo (Espagne). AT-G-U\n',
#  '\n',
#  '\n',
#  'ALEM (M. Pierre) H M. A. [et M”* née Marie-Thé¬\n',
#  'rèse de BOSKEDON], 1, place des Perchamps (xvr).\n',
#  "ALENÇON (S. A. R. Mgr. le Duc d'j, 11, rue Beau-\n",
#  'jon (vnr).\n',
#  '\n',
#  '\n',
#  'ALÈS de CORBET (Vu d’) [et Yu**e née deBEAUCÉ],\n',
#  '2, square de La Tonr-Maubonrg(vir) — et jêj du\n',
#  'Houssay, a Segré (Maine-et-Loire). A-H\n',
#  '\n',
#  '\n',
#  'ALEXANDER (M.etMm0 Charles), 64, avenue du Bois-\n',
#  'de-Boulogne (xvr).\n',
#  '\n',
#  '\n',
#  'ALEXANDRY d’ORENGIANI (B01 Michel d’), Lieute¬\n',
#  'nant au 13‘ Cuirassiers [et B»”— née de NEUVILLE],\n',
#  '8, rue Pierre-Charron (xvr) — et du Puits,\n',
#  'a Coise-St-Jean-Piedgauthier, t-g St-Pierre-\n',
#  'd’Albigny (Savoie).\n',
#  '\n',
#  '\n',
#  'ALF.XIS (S. A. I. le Grand-Duc), 38, avenue Gabriel,\n',
#  '\n',
#  '\n',
#  '(VIII-).\n',
#  '\n',
#  '\n',
#  'A LE Y B \\C fRoa René drd [et B0ttna née de COLOMBEL],\n',
#  '78, rue des Saints-Pères ivn*).\n',
#  '\n',
#  '\n',
#  'ALEYRAG d’AlGKEPONT. (Bond’),et de Prélefort,\n',
#  'Saint-A y (Loiret) t&S[0r] Meung-sur-Loire —\n',
#  'et villa de Monternot, igj [P-L-M.J Belle-\n',
#  '\n',
#  '\n',
#  'ville-sur-Saéne (Rhône).\n',
#  '\n',
#  '\n',
#  'ALFAS SA (Samuel) [et Mm* née HILLEL], 46, rue\n',
#  'Pierre-Charron (vme) [3? 519.94]. GF\n',
#  '\n',
#  '\n',
#  'ALG\n',
#  '\n',
#  '\n',
#  '36\n',
#  '\n',
#  '\n',
#  'AME\n',
#  '\n',
#  '\n',
#  'ALGAN (Le Colonel Henri), 0. ch, K [et M"* née\n',
#  'CLÉMENT], lOi, rue Lauriston (xvf).\n',
#  '\n',
#  '\n',
#  'ALGAURA (Edouard de) [et M"* née d’ALBAU], 165,\n',
#  'avenue de Wagram [7. 557.85],\n',
#  '\n',
#  '\n',
#  'AL1C0T (M—), 33, rue Saint-Guillaume (vif).\n',
#  'ALICOT (Michel), ancien Député [et M"’ née BON-\n',
#  'NARIC], même adresse.\n',
#  '\n',
#  '\n',
#  'ALIGNY (PICOT de MORAS, B“» d’) [et I!--- née\n',
#  'MENANS], 31, quai d’Orsay (vu*) — et A de\n',
#  'Montmirey-la-Ville, K Moissey (Jura). A-H\n',
#  '\n',
#  '\n',
#  'ALIGNY PICOT de MORAS (B- André d’), Lieute¬\n',
#  "nant d'Arl illerie ! et [t”n^ née Thérèse de PARIEL],\n",
#  '11, rue Saint-Dominique (vil») — et A de Montmi\n',
#  'rcy-la-Ville, Kl Moissey (Jura) |j= 7. Montmirey-\n',
#  'lc-Clihteau — et M de Fabrègues, K éâ\n',
#  '\n',
#  '\n',
#  'Aurillac (Cantal). A\n',
#  '\n',
#  '\n',
#  'ALIGRE, née de PRÉAULX (M\'“ d", 89, faubourg\n',
#  'St-Honoré (vm“), [7. 516.39] —et afo de La Rivière,\n',
#  '53 [£= âl Ponlgouin (Eure-et-Loire) — et ^ des\n',
#  'Vaux,KÎf= Belhomert (Eure-et-Loir),[0] Pont-\n',
#  'gouiu et La Loupe.\n',
#  '\n',
#  '\n',
#  'Aligre (d’) : voir Pomereu d’Aligre.\n',
#  '\n',
#  '\n',
#  'AL1NT.0URT (Cu d’), [et C""° née G1LL0TLX]\n',
#  'G ELIOT], 17, avenue d’Eylau (xvf) [ik 693.68\n',
#  '— et à Plainfaing (Vosges). B-H\n',
#  '\n',
#  '\n',
#  'Alinev d’Elya : voir d’Elva.\n',
#  '\n',
#  '\n',
#  'ALLAI RE (Colonel Ernest), 0. tjf, 16, rue Mari-\n',
#  'gnati (vnf). AL\n',
#  '\n',
#  '\n',
#  'ALLAI RE (Jules), K, Juge au Tribunal delà Seine,\n',
#  '16, rue de Marignan (vin*). AL\n',
#  '\n',
#  '\n',
#  'ALLAI RE (Mm* Etienne), 101, rue du Bac (vif).\n',
#  'ALLARD, née AUBINEAU (Yu“* d’), 23, rue du\n',
#  'Cherche-Midi (vf).\n',
#  '\n',
#  '\n',
#  'ALLARD (Jules) [et Mm” née LACOSTE de SAINT-\n',
#  'AMAND], 10, rue La Terrasre (xvf) — et jêj du\n',
#  'Prieuré de Gaillonnet, K Meulan (Seine-et-Oise).\n',
#  'ALLARD du CHOLLET (C“), 0. A y, *, * [et\n',
#  'Cl’“* née HARTOG], 114 bis, boulevard Malesherbes\n',
#  '(xvtf).\n',
#  '\n',
#  '\n',
#  'ALLARD de GAILLOX (B- E.) [et B-"-- née FLO¬\n',
#  'CON], 5, quai Malaquuis (Vf) [3* 817.07]. AG-H\n',
#  'ALLEMAGNE (B”» Paul d’) [ut B°-»>- née d’ABBADIE\n',
#  'd’ARRAST], 88 bis, rue Joulïroy (xvif).\n',
#  'ALLEMAGNE (Edmond d’) [et M“* née liAZIKE], 15,\n',
#  'rue d’Astorg (VHP) — et ^ de Polisv, K Po\n',
#  'lisy, £g Polisot (Aube). AL\n',
#  '\n',
#  '\n',
#  'Allemans (d’) : voir du Lau (»’).\n',
#  '\n',
#  '\n',
#  'ALLEZ (Edouard) [et M”’ née HOULLIER], 19, rue\n',
#  'Leroux (xvf) [TR 522.80] — et sà de Faiconne, 181\n',
#  'gg [0] Nanterre (Seine-et-Oise). AC-H\n',
#  '\n',
#  '\n',
#  'ALLEZ (M”* Adrien), 21, avenue, de l’Alina (v np)\n',
#  '[7. 519.87].\n',
#  '\n',
#  '\n',
#  'ALLEZ (Lucien), 39, rue d’Artois (vrip). AC-H\n',
#  'ALLEZ (M. et M"1 Emile-A.), 5 bis, rue de Rerri\n',
#  '(vnf ) [7. 529.73] — et de Belesbat, K Boutigny\n',
#  '(Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  'ALLFRÉE, née ROGUANOEF (M“*Helen-Féodorovna),\n',
#  '82, rue de Varcnnc (vil”) — et 61, Myddlctou Square,\n',
#  'London (Angleterre).\n',
#  '\n',
#  '\n',
#  'ALLFREE (Alexandre-Charles), mêmes adresses.\n',
#  '\n',
#  '\n',
#  'ALLIBERT (Jacques) [et M"1” née de BAMMEYILLEJ,\n',
#  '10, rue de Marignan (vnf) [3î 525.82], AG-H\n',
#  'ALL1ZÉ (M. Henry), Ministre de France à Stockholm\n',
#  '[et Mm* née 11EBBETTE], 30, rue Boissière (xvf)\n',
#  'et à Stockholm-, légation de France (Suède).\n',
#  'ALMEIDA (C1\'”1" d’),30, avenue Henri-Martin (xvf)\n',
#  '— et Villa Almeida, à Avon (Seine et Marne).\n',
#  '\n',
#  '\n',
#  'ALOISI (M. et M“" POMPEO), 28, avenue du Troca-\n',
#  'déro (xvf).\n',
#  '\n',
#  '\n',
#  'ALPHAND (M. Charles), Vice Consul, attaché aux\n',
#  'Affaires Étrangères [et M“* née Margerin de GRÉ-\n',
#  'MONT], 11, avenue de L11 Grande Armée (xvf).\n',
#  'ALPHEN SALVADOR (Mm* Emile), 9, rue Le Tasse\n',
#  '(xvf) — et à de la Cornmaiiderle, SI A3 jÿ=\n',
#  'Ballan (Indre-et-Loire).\n',
#  '\n',
#  '\n',
#  'ALPHEN-SALVADOR, mêmes adresses.\n',
#  '\n',
#  '\n',
#  'ALSACE (C** Maurice d’), 20, rue Washington (vnf)\n',
#  '\n',
#  '\n',
#  'J-RR\n',
#  '\n',
#  '\n',
#  'ALSACE (C** Philippe d’) [etC‘““* née de BRIENEN],\n',
#  '4, rue Dumont-d’Urville (xvf) [7î 520.64] — et\n',
#  'Montgraham, S ]£= Souancé i Eure-et-Loir), ^8\n',
#  'Nogent-le-Rotrou. J-RR\n',
#  '\n',
#  '\n',
#  'Alsace (»’) : voir aussi d’Hénin (d’).\n',
#  '\n',
#  '\n',
#  "Altena (d’) : voir de Borciigiuve d'Altena.\n",
#  'Altenbourg (d’) : voir de Ghampreux (d-).\n',
#  '\n',
#  '\n',
#  'ALT11AUS (Le Colonel B*” Augusto de), O. Sfr, Atta¬\n',
#  'ché militaire d i Pérou en France et en Italie, 72,\n',
#  'avenue Kléber (xvf).\n',
#  '\n',
#  '\n',
#  'ALTON (C1* d’), éês de la Bertraie, K S [Or]\n',
#  'Clefs, 4 kil. (Maine-et-Loire).\n',
#  '\n',
#  '\n',
#  'ALTON |V1" Charles d’) [et Y1"”” née de LA ROQUE-\n',
#  "ORDAN], 4, rue ('.revaux (xvf) — Chalet-Branet,\n",
#  'S >8 [Or] Buch (Gers) — et même fa . H-J\n',
#  'ALTON-SHÉE (G1”** d’), 12, rue Pergolèse (xvf).\n',
#  'ALTON-SHEE (Cte P. d’), même adresse.\n',
#  '\n',
#  '\n',
#  'ALVEAIl (Marcel-T. de) [et M- née PACIN1], 119,\n',
#  'avenue de Wagram (xvif) [7î 583.76].\n',
#  '\n',
#  '\n',
#  'AO-AE-B-H-ÜA\n',
#  'ALYES de ARAUJO (llippolyto) [et M“* née da\n',
#  'PORGIUXCULA], 57, avenue Kléber (xvf).\n',
#  "AMAND-VILLEFOUT (M.) ch, Secrétaire d'Ambas¬\n",
#  'sade [et M"1\'née CIIIBOIRGJ, 14, rue Dupout-des-\n',
#  'Loges (vif) [7. 702.461.\n',
#  '\n',
#  '\n',
#  "AMAT (D' Charles), ch, 0. A. «, [et M- née A. DU¬\n",
#  'BOIS], 13, rue Lôon-Cogniet [7. 549.46],\n',
#  '\n',
#  '\n',
#  'Amécourt (d’) : voir de Ponton (d’).\n',
#  '\n',
#  '\n',
#  'Amblard de Beaumont (voir de Beaumont).\n',
#  '\n',
#  '\n',
#  "AMBOIX de LARBONT iLe Général à') C. ch [et\n",
#  'M“* née de POUBTALÉS], 11, avenue Hoche (vnf )\n',
#  '— et flà du Val-Larbont, K flg La Bastide-\n',
#  'de-Sérou, distance 1 kil. (Ariége), U\n',
#  '\n',
#  '\n',
#  'AMBOIX de LARBONT (Paul d’), mêmes adresses.\n',
#  'AMBOIXdeI.ABBONT (M. Roger d’), mêmes adresses.\n',
#  'AMBRIÈRES (A. d’), Capitaine au 10• Hussards, [et\n',
#  'M"" née LE COl\'PPEY], 60, rue Pierre Charron.\n',
#  'Ambrines (d’) : voir de Valicourt d’AMimiNES.\n',
#  'Amécourt (d’) : voir de Ponton d’AMÉcoiiRT,\n',
#  'AMELLNE (M-, Ernest) née FERRARI de CAMPO-\n',
#  'LEONT, 29, rue Chaptal (ix*) et à Yillers-sur-Mer\n',
#  '(Calvados).\n',
#  '\n',
#  '\n',
#  'AME\n',
#  '\n',
#  '\n',
#  '31\n',
#  '\n',
#  '\n',
#  'AMELINE de LA BRISELAINE, née ABEILLE (M—\n',
#  'H.), 9, rue Portalis (vin*).\n',
#  '\n',
#  '\n',
#  'AMELINE de LA BRISELAINE (Roger), même adr.\n',
#  '\n',
#  '\n',
#  'AMELOT de LA ROUSS1L1IE, née CHOPPIN d’AR-\n',
#  'NOL VILLE (C1*1** Br*), 9, boulevard de La Tour-\n',
#  'Maubourg (vir).\n',
#  '\n',
#  '\n',
#  'AMELOT de LA UOUSSILHE (C1*), Secrétaire d’Am¬\n',
#  'bassade [et O*” née CORBIN], 3, boni, de La Tour\n',
#  'Maubourg (vii*) •— et ^ de Mortefontaine, E\n',
#  'Plailly (Oise) Mortefontaine, gg [NJ. Survilliers.\n',
#  '\n',
#  '\n',
#  'H-UA\n',
#  '\n',
#  '\n',
#  'AMELOT de LA ROUSSILHE (V>-> [et V--»- née de\n',
#  'SEGUR-LAMOIGNON], 9, b. de La Tour-Maubourg\n',
#  '(vif) — ffo de Méry, E fe= 4§ï[N ot °] Méry-sur.\n',
#  'Oise (Seine-et-Oise) — et Domaine de Belleval, K)\n',
#  'Î5= Beaucaire (Gard), ig [P-L-M] Arles. A\n',
#  '\n',
#  '\n',
#  'AMILA KVARI (LL. AA. RR.) (P°- et P°-°>, 64, ave¬\n',
#  "nue du Bois-de-Boulogne (xvt'J,.\n",
#  '\n',
#  '\n',
#  'AMI LL V (Cu Maurice d’) [et C""* née Germaine de\n',
#  'LAAGEJ, S, rue de Marignan (vu*) — et ^\n',
#  'd’Amilly, K Berd’huis (Orne), jÿ= à Nogent-le-\n',
#  'Rotrou (Eure-et-Loir) -— et Pavillon des Evées,\n',
#  '13 Jÿ= & [35 3] Senonches (Eure-et-Loir).\n',
#  '\n',
#  '\n',
#  'AMODIO (M-de), 4.4.4, [et SP- née WAINWRIGHT],\n',
#  '88, avenue Kléber (xvi*) [75 678.41]— de 8t.-\n',
#  'Maurice-du-Désert ( 75 au flà ), Kl â La Ferté-\n',
#  'Macé (Orne).\n',
#  '\n',
#  '\n',
#  "ASIODRU i l>' Laurent), Député et Conseiller général\n",
#  'de Seine-et-Oise [et M—], 66, avenue des Champs-\n',
#  'Elysées (vin*) [7* 518.44] — et A de Chamarande,\n',
#  'E^éS [Or] (Seine-et-Oise).\n',
#  '\n',
#  '\n',
#  'ANCEAL (SI- Eugène) née HEODERERT, 114, ave¬\n',
#  'nue des Champs-Elysées (vin”) [75 506.31].\n',
#  '\n',
#  '\n',
#  "ANCEL (M”' Adolphe), 103, rue La Boétie, (vin*)\n",
#  '[75 521.37].\n',
#  '\n',
#  '\n',
#  'ANCEL (Raoul) [et M“* née COPPINGER], 19, rue de\n',
#  'Bassano (xw=) — et de Gournay, Eâl [O]\n',
#  'Harfleur (Seine-Inférieure) \\y Gainneville: A\n',
#  '\n',
#  '\n',
#  'ANCEL (Georges), 191, boni. St-Gcrmain (vii*) —et\n',
#  'ÊÊ) des Petit-Colmoulins, K) flg [O] Harfleur\n',
#  '(Seine-Inférieure). A-Y\n',
#  '\n',
#  '\n',
#  'Avdernay (d’) voir de Vassart d’Andernay.\n',
#  '\n',
#  '\n',
#  'ANDERSON (Captain J.-H.), 33, av. Montaigne (viir),\n',
#  '— et Albany, 2, Piccadilly, à Londres. RR-UA-Y\n',
#  '\n',
#  '\n',
#  "ANDIGNÉ, née de BARBENTANE (M'*' d’), 77, rue\n",
#  'de Lille (vu*). [75130.10] — âjtj de Monet, 153\n',
#  'Beaufort-en-Vallée (Maine-et-Loire), è-4 [Or]\n',
#  'La Ménitré, Brion-lumelle et Beaufort — et {gj de\n',
#  'Barbentane, la )- - Barbentane (Bouches-du-Rhône).\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ (M"“ d’), mêmes adresses — et *£* (je\n',
#  'Condillac, Kl M La Coucourde (Drôme).\n',
#  '\n',
#  '\n',
#  'ANDIGNE (M‘‘d’) [et M‘“ née Madeleine GODDARD],\n',
#  '77, rue de Lille (vu*) [75130.10] — de Monet,\n',
#  'E) Beaufort-en-Vallée (Maine-et-Loire), {jglÉtl.\n',
#  'La Ménitré et Jumelles-Brion — {fis de Giraud, El\n',
#  "Le Sambuc (Bouches-du-Rhône), l'Armelliére-\n",
#  'Giraud, [P-L-M] l’Arnelliére-Giraud et Arles-\n',
#  'sur-Rhône — et de Richebourg, El La Bassée\n',
#  '(Pas-de-Calais) H-J-RR\n',
#  '\n',
#  '\n',
#  'AND\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ (C‘* d’), officier de cavalerie démission¬\n',
#  'naire, Conseiller municipal de Paris, Conseiller\n',
#  'général de la Seine, 49, rue de Boulainvilliers\n',
#  '(xvi*) — et 2, rue SchelTer (xvi*)— et mêmes O .\n',
#  '\n',
#  '\n',
#  'CM-RR-H-J\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ, née de CROIX (C1*"* de), 3, rue de La\n',
#  'Chaise (vil*) — îgj de Grip, SI Durtal\n',
#  '(Maine-et-Loire), â [Or], Moraunes et Durtal —\n',
#  'de Barneville, E £f= ^1 [O], Honfleur (Cal¬\n',
#  'vados)— et êêj de Franc-Slarct, E Vezin(Belgique),\n',
#  'Marche-les-Dames tôE) Nainur.\n',
#  '\n',
#  '\n',
#  "ANDIGNÉ (C“ Jean d’), [et Cl“'“ née de VILLE-\n",
#  'CHAIZE], 3, rue La Chaise (VII») — et mêmes {£s\n',
#  '\n',
#  '\n',
#  'A-H-J\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ (C** Henri d’) [et Cl**‘» née d’EVRY],\n',
#  '10, rue Clément Marot (vin*) — ^ de R esteau,\n',
#  'E Chemiré-le-Gaudin (Sarthe), *75 (O) La\n',
#  'Suze — et {ga de Thomasin, E If2 Chantenay\n',
#  '(Sarthe), (O) Noyen.\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ (C‘* Maurice), 68, av. de la Grande-Armée\n',
#  '(xvi*)—et A delà Jousselinière, E Beaupréau,\n',
#  'lOkil. (Maine-et-Loire), ^ [Ét et Or]. Chaloimes-\n',
#  'sur-Loire). UA\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ (V- Louis, d’) [et V1*»** née COLEMAN]\n',
#  'veuve de COURCY-MAY], 6, rue de Berri (vm-j\n',
#  '[75 528.76] — et même {gj. AG-B-H-J-RR\n',
#  '\n',
#  '\n',
#  'ANDIGNÉ (C‘“ Geoffroy d’) [et C1*”* née CHANDON\n',
#  'de BRIAILLES], 13, rue de Berri (vm*) [75 537.41]\n',
#  '— et afo de la Blanchaye, E jÿ= éS [0] Sogrê\n',
#  '(Maine-et-Loire). H-J-RR\n',
#  '\n',
#  '\n',
#  'ANDIGNE (C** Robert d’), Lieutenant au 14* Hus¬\n',
#  'sards, à Alençon [et C1*"* née LEFÈVRE], —\n',
#  'même {gj J\n',
#  '\n',
#  '\n',
#  "ANDI.AU (C1»*'* d’), 170, faub. Saint-Honoré (vm*).\n",
#  '\n',
#  '\n',
#  'ANDLAU (Ct0 d’) [et C1*1** née de CHABROL-\n',
#  'CHAMEANE], 4, rue de Marignan (vin») — M de\n',
#  'Yoré, E Ucmalard 3 kil. (Orne), jâg [0] Re-\n',
#  'malard, 4 kil. et Condé-sur-Huisne, 11 kil.\n',
#  '\n',
#  '\n',
#  'A-H-RR-U\n',
#  '\n',
#  '\n',
#  'ANDLAU (C1* Antoine d’), même adresse. J\n',
#  '\n',
#  '\n',
#  "ANDLAU (C‘“ Jean d'), mêmes adresses.\n",
#  '\n',
#  '\n',
#  'ANDRAL, née DELIES (SI”*), 26, Cours la Reine\n',
#  '(vm*), — et {fij de Ghâteauvieux, E lf= éS [Or]\n',
#  'Saiut-Aignan (Loir-et-Cher).\n',
#  '\n',
#  '\n',
#  "ANDRASSY, née C1**'* PALFFY (C'»“»), 68, boni, de\n",
#  'Courcelles (xvn*).\n',
#  '\n',
#  '\n',
#  'ANDRAULT (C.), Conseiller honoraire à la Cour\n',
#  "d'Appel, 30, quai du Louvre — et au Petit-Bois-\n",
#  'prés Melle (Deux-Sévrc-).\n',
#  '\n',
#  '\n',
#  'ANDRÉ (R°- d‘) [et B»"“" née de BlUCQl.\'EMONT],\n',
#  '3, rue Auguste-Vacquerie (xvi*) — et ^3 de la\n',
#  "Souque, e {#= eS[Or]Rabaslens-surTarn (Tarn'\n",
#  '\n',
#  '\n',
#  'H\n',
#  '\n',
#  '\n',
#  'ANDRÉ (B»"** Émile d’), 76, rue de la Pompe (xvi°).\n',
#  '\n',
#  '\n',
#  'ANDRÉ (B** Albert d’) [et B"°* née GUILLAUD],\n',
#  '86, avenue de Yllliers (xvi*).\n',
#  '\n',
#  '\n',
#  'ANDRÉ, née JOLY de BAMMEVILLE (SI- Alfred),\n',
#  '49, rue La Boétie (vm*) [75 531.53] — et {êî de\n',
#  'Crassier, E îp 75gg Divonnc-les-Bains (Ain).\n',
#  '\n',
#  '\n',
#  'AND\n',
#  '\n',
#  '\n',
#  'APC\n',
#  '\n',
#  '\n',
#  '38\n',
#  '\n',
#  '\n',
#  'ANDRÉ, née JAQUEMART (M- Édouard), 138, boni.\n',
#  '\n',
#  '\n',
#  'Haussmann (vnr) [35 317.96],\n',
#  '\n',
#  '\n',
#  'ANDRE (L.) [et M“* née RIGAULT], 3, rue La Boétie\n',
#  '[vin»).\n',
#  '\n',
#  '\n',
#  'ANDRÉ (Alexandre) [et M-*née ROBERT de MASSY],\n',
#  '20, rue d’Aguesseau (viii«) [3- 237.81] — et de\n',
#  'La Frogerie, 8 Ligny-le Ribault (Loiret).\n',
#  "ANDRÉ, née L'HÉRITIER (Mm* Georges), de\n",
#  'Lesmont, la js= Lesmont (Aube), ê3 [E] l’iney\n',
#  'et Brienne-le-Chàteau.\n',
#  '\n',
#  '\n',
#  'ANDRE (René) [et M"* née LE MIRE], 3, avenue\n',
#  'Victor-Hugo (XVIe).\n',
#  '\n',
#  '\n',
#  'Andreis : voir De Andreis.\n',
#  '\n',
#  '\n',
#  "ANDREZEL (Charles d'), dfc, Lieutenant de vaisseau,\n",
#  '[et M”" née de FROTTÉ], 17, rue Yernet (vnr),\n',
#  'ANDRIEIIN (L.), #, Ancien Député, ancien Préfet\n',
#  'de Police, ancien Ambassadeur [et M™ née\n',
#  'KOECHLIN], 42, rue Scheffer (xvil [35693.82] — et\n',
#  'iêB du Casset, 8 M [P-L-M] Montluel (Ain.)\n',
#  'ANETHAN (B*"* Alix d’), 12 rue Oudinot (vu*).\n',
#  'ANGELIS (M“ d’), Ministre plénipotentiaire [et M”»\n',
#  'née du BOUZET de CAUSSINS de MARIN], 8, rue\n',
#  'Meissonier (xvifl — et à Saint-Florent (Corse).\n',
#  'ANGÉLY ïC‘» Albert d’), à Sérillac, 8 Beaumont-\n',
#  'sur-Sarthe (Sarilie). UA\n',
#  '\n',
#  '\n',
#  'ANGÉLY (Emile d’) [et Mne née de CONFLANS], 7,\n',
#  '\n',
#  '\n',
#  '- rue Alboni (xvie) — et ^ La Héraye, 8 Ta-\n',
#  'vers, gg Beaugency, (Loiret),\n',
#  '\n',
#  '\n',
#  'ANGÉLY (Mne Maurice d’), 64, rue de Rennes (vie).\n',
#  'ANGLADE (Achille), #, [etM- néePETITGUÉNOT],\n',
#  '32, avenue Montaigne (vm*) — et jgj de Saint-\n',
#  'Eutrope, 8 Montlhéry (Seiue-et-Oise). AL\n',
#  '\n',
#  '\n',
#  'ANGLADE (M. René) [et M”» BOSSERONT d’], 113,\n',
#  'rue de Courcelles (xvii,)It- et ^ l’Andiran, 8\n',
#  '^ ggj Nérac (Lot-et-Garonne).\n',
#  '\n',
#  '\n',
#  "ANGLEMONT, née THOMAS (V>-- Christian d'), 14,\n",
#  'rue Greuze (xvi»>.\n',
#  '\n',
#  '\n',
#  '.ANGLEMONT (Vle Henry d’) [et V>» "» née de MA-\n',
#  'CHADO], 14, rue Greuze (x\\T).\n',
#  '\n',
#  '\n',
#  'ANGLESEY (M”* d’), 17 bis, rue Mansart à Ver¬\n',
#  'sailles (Seineet-Oisei.\n',
#  '\n',
#  '\n',
#  'Anglure (d’| : voir de Noblet (TAnglure.\n',
#  '\n',
#  '\n',
#  'ANGOT (Alfred) [et M”* née AGELASTO], 176, rue\n',
#  'de l’Université (vu*) [35 700.07] (Jeudi).\n',
#  '\n',
#  ...]

# %% [markdown]
# # CRF TEST

# %%
import random
from collections import Counter

from IPython.display import display

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer

import sklearn_crfsuite
from sklearn_crfsuite import metrics

import spacy

from utils.export import export_to_excel
from utils import tags_format
from utils.features import generate_features

np.random.seed(42)
random.seed(42)

nlp = spacy.load('it_core_news_sm')

tags = [
    'FNAME',
    'LNAME',
    'ECC',
    'GOV'
]
tags_prefixed = ["-".join([prefix, tag]) for tag in tags for prefix in 'IB']
tags_prefixed.append('O')
print(tags_prefixed)
# Out:
# ['I-FNAME', 'B-FNAME', 'I-LNAME', 'B-LNAME', 'I-ECC', 'B-ECC', 'I-GOV', 'B-GOV', 'O']

# %%
#Put the people in a dataframe

buffer = ""
people = []
for line in raw_data:
    if(line == "\n"):
        if(len(buffer) > 0):
            people.append(buffer.replace('\n', ''))
            buffer = ""
    else:
        buffer += line
idx = np.arange(len(people))
df = pd.DataFrame({"idx": idx, "text" : people})
df = df.set_index("idx")
df.head()
# Out:
#                                                   text
# idx
# 0                                                    A
# 1                      Aage (cl’) voir Colmet (I'Aage.
# 2    ABRADIE-d’ARRAST (Michel-Robert d’), 5S bis, r...
# 3    ABBATUCCI, née de FORESTA (M-), 103, rue LaBoé...
# 4    ABBATUCCI (C1""*), 32, rue Washington (vni'j.A...

# %%
# Raphael's code to toeknize:

# We tokenize the text into words
df_tokens = df['text'].apply(lambda text: [
    str(token.text) for token in nlp(text, disable=['parser', 'tagger', 'ner'])])

# We stack the tokens to get a new token index
df_tokens = df_tokens.apply(pd.Series).rename_axis('tok_idx', axis=1).stack().to_frame('token')

# Finally, we join with the previous dataframe to get the fulltext column
df_tokens = df_tokens.join(df)
df_tokens = df_tokens[['text', 'token']]
display(df_tokens.head())
# Out:
#                                         text token
# idx tok_idx
# 0   0                                      A     A
# 1   0        Aage (cl’) voir Colmet (I'Aage.  Aage
#     1        Aage (cl’) voir Colmet (I'Aage.     (
#     2        Aage (cl’) voir Colmet (I'Aage.    cl
#     3        Aage (cl’) voir Colmet (I'Aage.     ’

# %%
#Export to excel
export_to_excel(df_tokens, './propr_to_annotate.xlsx', tags=tags_prefixed)

# %%
# Reload

df_annotations_small = pd.read_excel('./propr_to_annotate.xlsx', index_col=[0,1])
df_annotations_small['tag'] = df_annotations_small['tag'].str.upper()

is_annotated = (df_annotations_small['tag'].fillna(False) # Fill all NaN with False
                .apply(lambda x: True if x else False) # Make filled tag True
                .reset_index().groupby('idx') # Transform into dataframe and group by entry
                .apply(lambda x: all(x['tag']))) # Check that all tags are filled
df_annotations_small = df_annotations_small.loc[is_annotated[is_annotated].index] # Only keep entries with all tags filled

annotations_small = df_annotations_small.groupby(level=[0])[['token', 'tag']].agg(list).rename(columns={'token': 'tokens', 'tag': 'tags_iob2'})
annotations_small.head()

# %%
train_idx, test_idx = train_test_split(annotations_small.index, test_size=0.5)
print(f"There is {len(train_idx)} training samples and {len(test_idx)} test samples.")

# %%
# Features for the current word
default_features = {
        'bias': None,
        'word.lower': lambda word: word.lower(),
        'word.lastChar': lambda word: word[-1:]
        # TODO add other features
    }
# Features to be computed for surrounding words
default_surrounding_features = {
        # TODO add features
}

# %%
tokens, features = annotations_small[['tokens', 'features']].iloc[0].values
print(tokens[0])
print(features[0])
print()
print(tokens[2])
print(features[2])
print()
print(tokens[-1])
print(features[-1])

# %%
train = annotations_small.loc[train_idx]
test = annotations_small.loc[test_idx]

# TODO you can change the encoding scheme to see if it performs diffently
tags_col = 'tags_io'

X_train = train['features'].values
y_train = train[tags_col].values
X_test = test['features'].values
y_test = test[tags_col].values

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=3e-1,
    c2=1e-4,
    max_iterations=1000,
    all_possible_transitions=True
)
crf.fit(X_train, y_train);

# %%
labels = list(crf.classes_)
labels.remove('O')

y_pred = crf.predict(X_test)
print(f"Weighted f1_score {metrics.flat_f1_score(y_test, y_pred, average='weighted', labels=labels):.3f}")
# group B and I results
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))

# %% [markdown]
# # Splitting people

# %%
def getAddress(data):
    address=""
    for i, o in enumerate(data):
        if(o.replace(" ", "").isdigit() or 'bis' in o):
            for addr in data[i:]:
                address += addr.replace("\n", " ")
    if(len(address) < 1):
        return "unknown"
    return address.split('(')[0]

# %%
buffer = ""
all_people = []
for line in raw_data:
    if(line == "\n"):
        if(len(buffer) > 0):
            all_people.append(buffer.split(','))
            buffer = ""
    else:
        buffer += line
all_people
# Out:
# [['A\n'],
#  ["Aage (cl’) voir Colmet (I'Aage.\n"],
#  ['ABRADIE-d’ARRAST (Michel-Robert d’)',
#   ' 5S bis',
#   ' rue\nJouffroy (xvu*) — et d’Elhorriaga',
#   ' S Saint-\nJcan-de-Luz (Basses-Pyrénées).\n'],
#  ['ABBATUCCI',
#   ' née de FORESTA (M-)',
#   ' 103',
#   ' rue La\nBoétie (vin*) [35 321.S7] — et fljj Rey de Foresta',
#   " SI\n[s ' â [A] Montmorency (Seine-et-Oise).\nABBATUCCI (C“ Jacques)",
#   ' 103',
#   ' rue La Boétie (mi‘)\n[35 521.57] — et même A . Sp-RR\n'],
#  ['ABBATUCCI (C1""*)',
#   ' 32',
#   " rue Washington (vni'j.\nABEILLE (Adolphe)",
#   '27',
#   ' Faubourg-Saint-Honoré (vm*)\net haras de Viroflay',
#   ' CK! feâ Virollay [35 3)\n'],
#  ['(Seine-et-Oise). RR-UA-T\n'],
#  ['ABOILARI) Georges)',
#   ' U. #',
#   '[et M“" née BONUS]',
#   ' 46',
#   '\navenue de Breteuil (vu*) [35 707.11] — et de\nPeyrieu',
#   ' Kl \\p= eS Peyrieu (Ain). AC-M-YC\nABOVILLE (V‘* H. d’)',
#   ' O.iK',
#   " Colonel du 131' de ligne\nà Orléans [et V*",
#   '“‘ née de GOUVELLO de KÉ-\nRIAVAL]',
#   ' à d® Kerentré',
#   ' K {s= aË [0] Auray\n(Morbihan) — et de Rouville',
#   ' K à\n[P.L.M.] Malesherbes (Loiret).\n'],
#  ['Paris-Mondain — 1908\n'],
#  ['ABOVILLE (B** Christian d’) [et B*»”" née I1ENNE-\nCART]',
#   ' 23',
#   ' rue de Grenelle (vu*)— et A deGlux',
#   '\nK Chàteau-Chinon fs= St-Prix-sous-Beuvray',
#   ' 1 kil.\n(Nièvre)',
#   ' Etang',
#   ' 22 kil. (Saône-et-Loire) ou gg.\n'],
#  ['de E’achin-le-Chàtelet',
#   ' 10 kil. — et ^ de Brouay',
#   '\nK ]ÿ= Audrieu (Calvados).\n'],
#  ['Alt RA Ml (II* Henri) [et M«« née KNITTEL]',
#   ' 28',
#   ' rue\nCopernic (xvi*)',
#   ' 35 667.01.\n'],
#  ['ABRANTÈS',
#   " née JL'XOT (LE RAY",
#   ' v--° d’)',
#   ' 12',
#   ' ave-\nnue Henri-Martin (xvi*) — et sêâ de Bailleul',
#   ' K)\nGorron (Mayenne)',
#   ' ^ [O] St-Denis-de-Gastines.\n'],
#  ['ABRANTÈS (Duc d’)',
#   " Capitaine d'infanterie hors\ncadres",
#   ' à F État-major du Gouverneur de Xicer\n[et !)**• nee Nicole',
#   ' de MAIGRET]',
#   ' 12',
#   ' avenue Henri-\nMartin (xvi*) —- même de Bailleul — et villa\n'],
#  ['“ Myosotis " Vallon des Fleurs à Nice.\n'],
#  ['ABRANTÈS (M** d’}',
#   ' Lieutenant au 14e hussards à\nAlençon (et Mi',
#   '# née Hélène LANGSDORFF]',
#   ' 12',
#   '\navenue Henri-Martin (xvi*) — et même M.\n'],
#  ['ABRANTÈS (Cte d’}',
#   " Lieutenant au îS6* d'infanterie\nà St-Lô (Manche)",
#   ' mêmes adresses.\n'],
#  ['3\n'],
#  ['ABZ\n'],
#  ['34\n'],
#  ['A GH\n'],
#  ['ABZAC (C1""* Paul d’)',
#   ' 181',
#   ' rue de La Pompe (xvi*).\nfACHER de MONTGASCON ll!°» d’) [et B”""\' née Jeanne\nde COURCY]',
#   ' 18',
#   ' avenue d’Antin (vui")',
#   '— et ià\nde Villequier',
#   ' E M [Q]',
#   ' Caudebec-en-Caux (Seine-\nInférieure) Villequier.\n'],
#  ["ACHERY de SAS DON'N'IN'O (P“ d’)",
#   ' Ex-camérier\nsecret',
#   ' 62',
#   ' avenue de la Grande-Armée (xvn‘) — et\nde Soisy-sous-Montmorency',
#   ' 121 35 *3 [N]\n'],
#  ['Soisy-sous-Montmorency (Seine-et-Oise).\n'],
#  ["ACHON (B°n René d')",
#   " Capitaine au l*r chasseurs [et\nB'*” née de LAMOLÈRE",
#   " Cu”* d'HUST]",
#   ' 124',
#   ' rue\nde Provence (vm*)',
#   ' — et de la Roche-de-\nGennes',
#   ' El Gennes (Maine-et-Loire)',
#   ' M [Or]',
#   '\n'],
#  ['Les Rosiers-sur-Loire.\n'],
#  ["AGLOQLE (Mm*) née DU CH AN O Y'",
#   ' 26',
#   ' avenue Mar¬\nceau (xvi" )— et jÎ5 de La Borde',
#   ' E Saint-An-\ntoiue-du-Rocher',
#   ' (35 au £•£ .N” S)',
#   ' M Mettray\n(Indre-et-Loire).\n'],
#  ["ACLOQL'E (M»« AWnée SEBERT",
#   ' 9',
#   ' place des Etats-\nUnis (xvi*)-[35 698.92].\n'],
#  ["ACI.OQl'E (Maurice)",
#   ' 19',
#   " rue de Presbourg (xvi') — et\nvilla Monténégro [35 590]",
#   ' à Cannes (Alpes-Mari¬\ntimes). AC-Y\n'],
#  ['ACOLLÀS (René)',
#   ' K',
#   ' Conseillerréférendaire à la Cour\ndes Comptes [et Mm* née de MOY]',
#   ' 29',
#   ' avenue\nFriedland (vin*) [35 547.26]\n'],
#  ['Acquasanta (d’) voir de Narducci.\n'],
#  ['ADAM (Achille)',
#   ' Député du Pas-de-Calais',
#   ' 21',
#   ' avenue\nd’Antin (vin*) [35 311.04] — et 10',
#   ' rue Victor-Hugo',
#   '\nà Boulogne-sur-Mer (Pas-de-Calais)',
#   ' —et « La Soli¬\ntude »',
#   ' à Saint-Quentin-en-Tourmont',
#   ' par Rue\n(Somme). AC-B-HRRUA\n'],
#  ['ADAM (M“* Achille)',
#   ' née VERBERKMOÉS — et *£$\nde Verneuil',
#   ' E î;~ Si [Or] Verneuil-sur-Indre\n(Indre-et-Loire).\n'],
#  ['ADAM (M“* Eugène)',
#   ' 2 bis',
#   ' rue de La Baume (vin")\n[35 520.00] — et 24',
#   ' rue de Confiai»',
#   " à'Poissy",
#   '\n35 (Seine-et-Oise).\n'],
#  ['ADAM (Henri)', ' mêmes adresses. AC\n'],
#  ['ADAM (Mm* Hippolytel',
#   ' 47 bis',
#   ' rue Ampère (xvn")\n[35 525.33] — et & des Mazurettes',
#   ' E é3\n'],
#  ['[N] Boulogne (Pas-de-Calais)', '\n'],
#  ['ADAM (M- Léon) née JÉROME PICHON', ' 33', ' av.\nd’Antin (vnr).\n'],
#  ['ADAM (M. et M“* Georges)',
#   ' 23',
#   ' av. de Messine (vin")\n— et 14',
#   ' rue Circulaire',
#   ' à Versailles.\n'],
#  ['ADAM (Louis)',
#   ' Agent de change [et M»» née PIERRETJ\n23',
#   ' av. de Messine (vm") (bureaux: 48',
#   ' rue de Pro¬\nvence) (ix*) [35 136.13] — et jgj deBrancas',
#   ' E jj=\néS [0] Sèvres (Seine-et-Oise)',
#   ' — et villa Ellon',
#   ' à\nLion-sur-Mer (Calvados).\n'],
#  ['ADAM (Juliette LAMBER) (M“* Edmond)', ' abbaye de\nGif (Seine-et-Oise).\n'],
#  ['ADAN (Emile)',
#   ' ÿ [etMm',
#   ']',
#   '75',
#   'r. deCourcelles(vm")UA\nADDA SALVATERRA (M11* d’)',
#   ' 37',
#   ' avenue Montaigne\n(vin").\n'],
#  ['ADELINE',
#   ' née F AU (M” Edmond)',
#   ' 31',
#   ' rue Pierre-\nCharron (xvi*) — et {£à de Sérigny',
#   ' 0 J: ^\n[Or] Cour-Cheverny (Loir-et-Cher).\n'],
#  ['ADELINE (M““ Raoul)',
#   ' née FROGER des CHESNES',
#   '\npavillon de La Louetière',
#   ' E â [Or] Cour-\nChcverny (Loir-et-Cher).\n'],
#  ['ADELINE (Gaston) [et M"" née DELONDRE]',
#   ' 55',
#   ' rue\nPierre Charron (vin") —■ et {^3 de Moussonvilliers',
#   "\nE ]ÿ= S'-Maurice-les-Charençais",
#   ' 5 kil. (Orne) gji\n[0] La Ferté-Vidame (Eure-et-Loir). H-UA\n'],
#  ['ADELON',
#   " née HAENTJEN'S (M- Henry)",
#   ' 24',
#   ' rue\nde Courcelles (vm*) [35 517.06].\n'],
#  ['ADELON (Marcel)', ' même adresse.\n'],
#  ['ADELSWARD (B””»" Axel d\')',
#   ' née WUHRER',
#   '20',
#   ' rue\nDaru (vm") — et à Nice.\n'],
#  ['ADELSWARD (B***" Gustave d\')',
#   ' née de POURTALÈS\n63',
#   ' boulevard de Courcelles (vin*) [35 508.32] — et\n(£3 du Plessis-Mornay',
#   ' E Rochefort-en-Yveliues',
#   '\n1f= [35 24]',
#   ' Donrdan (Seine-et-Oise).\n'],
#  ["ADEN'IS de LA ROZERIE (A.-H)",
#   ' Conseiller Maître\nà la Cour des Comptes',
#   ' 0. K',
#   ' 3',
#   ' rue de Monceau (vin0)',
#   '\n'],
#  ['ADHÉMAR (C""" d’)', ' née MARIANT', ' 33', ' rue Was¬\nhington (vm*).\n'],
#  ['ADHÉMAR (V“ Olivier d’)',
#   ' K [etV1*"*\' née VERDET]\n86',
#   ' rue do Yarenne (vu*)— et à de Saint-Hubert',
#   '\nE Sorgues-sur-l’Ouvèze (Vaucluse — et éêS de\nTeillan',
#   ' E Marsillargues (Hérault).\n'],
#  ['ADHÉMAR (Vf Robert d’)', ' à Lille (Nord).\n'],
#  ['AFFRE de SAINT-ROME (Cl°“* Denis) [née de NOGA-\nRET]',
#   ' 147',
#   ' rue de Rennes (vi*) — et à Soisy-sous-Mont¬\nmorency',
#   ' E îf= (Seine-et-Oise).\n'],
#  ['AGACHE (Alfred)', ' 14', ' rue Weber (xvi*). UA\n'],
#  ['AGHION (M. et Mm" Jules)',
#   ' 24',
#   ' rue Clément-Marot',
#   '\n(vm") [35 501.87]. CF\n'],
#  ['Agneau (d’) voir: Carpentier d’AGNEAU.\n'],
#  ['Agneaux (d’) voir: de S" Marie d’Agneaux.\n'],
#  ["AGN'ELLET (M. et Ilm‘ Augustin)", ' 50', ' av. Victor-\nHugo (xvi*).\n'],
#  ["AGN'ELLET (M11* Emma)",
#   ' 59',
#   ' rue de Prony (xvn")\n— et villa à Menthon-Saint-Bernard',
#   ' E [Z- (Haute-\nSavoie)',
#   ' fg [P.-L.-M.] Annecy.\n'],
#  ['AGNES (Eugène)', ' 59', ' rue Chardon-Lagache (xvi»)', '\n'],
#  ['AGO.N (la Générale M“* d’)',
#   ' née TIEUSONNYER',
#   ' 78',
#   '\navenue Henri-Martin (xvi*) — et *& de Sampange',
#   '\nE Nevers (Nièvre).\n'],
#  ['AG0PIAN-PACHA (M»")',
#   ' née KHORASSANDJ1',
#   '\n98',
#   ' boulevard Malesherbes (vui").\n'],
#  ['AGOPIAN-PACHA (L.)', ' môme adresse. Y\n'],
#  ["AGOl'LT (M**d’) [et M'",
#   '"néede MONTRICH AHD]',
#   ' gft\nde Vandœuvre',
#   ' E Coulans (Sarthe) àZ [0|. Le\nMans (Sarthe).\n'],
#  ['AGOl\'LT (C\'" d’)',
#   ' ancien député [et C1""” née\nd’ESTAMPES]',
#   ' 19',
#   ' boulevard de La Tour-Maubourg\n(vu") et — {gs de Beauplan',
#   ' E 35. Voreppe Isère .\n'],
#  ['AG R AIN née de GESTAS de LESPÉROUX',
#   ' (M*“ d’)',
#   '\n63 bis',
#   ' rue de Yarenne — (vu*) et A de Rressey',
#   "\nE Arc-sur-Tille 3 kil. (Côte-d'Or) [P.-L.-M.].\nd’Arc-sur-Tille et Magny.\n"],
#  ['AGRAI.N (G** Jean d’) [et Cl',
#   '“* née Geneviève\nR0UT1NY]',
#   ' mêmes adresses — et villa St-Vallier\nà Nice.\n'],
#  ['AG R AIN (V“ Henri d’)', ' mômes adresses.\n'],
#  ['AGR\n'],
#  ['33\n'],
#  ['ALF\n'],
#  ["AGRAIN (11'» d’)",
#   ' Lieutenant au 1" Dragons [et\nM\'" née de JESSÉ-LEYAS]',
#   ' —même de Bressey\net à Joigny (Yonne) [Jï 30J.\n'],
#  ["AGl'EN (P.-L. d’) [et M”*]",
#   ' 74',
#   ' rue Michel-Ange',
#   ' [Ht\n239.81]—et fljj le Prieuré Saint-Michel',
#   ' à Saint-\nPair-sur-la-Mer (Manche).\n'],
#  ['AGUERA (F. G. de)',
#   ' 8',
#   " rue Magellan (Viir). RR-UA\nAguesseau (d') : voir de Skguh d’AcuEssEAU.\nAGUIAR (M” Guillaume PINTO d’)",
#   ' 31',
#   ' rue Pierre-\nCharron (XVIe).\n'],
#  ['AGUIAR (Louis PINTO d’)',
#   ' même adresse. AG-GF\nAICARD (M. Jean)',
#   ' 40',
#   ' rue de Luxembourg',
#   ' et villa\nles Lauriers-Roses à La Garde (Var).\n'],
#  ['AIGNAN',
#   ' née MOSSELMAN (M”* Léon)',
#   ' 60',
#   ' rue\nFrançois-lor (viii*).\n'],
#  ['AIGNAN (Gabriel) [et M““ née Mariquita del VALUE\nde MENA]',
#   ' 5',
#   ' rue Montaigne (vnr)—et à Douvres-\nla-Délivrande (Calvados). SH-CM-UA\n'],
#  ["Aighepokt (d1) : voir d'Ai.F", 'YRAC (d1).\n'],
#  ['AILLIÈRES',
#   ' née GÉRARD (M™ Fernand d’)',
#   ' 16',
#   " rue\nBayard (vin») — et jà d'Aiüières",
#   ' a jg\n[0] Mamers (Sarthe).\n'],
#  ['AILLIÈRES (M. Louis d‘)', ' mêmes adresses. J\n'],
#  ['AILLIÈRES (Le Colonel Etienne d’)',
#   ' Commandant le\n10° Cuirassiers',
#   ' H',
#   ' [et M“° née de SAINT-LAUMER]',
#   '\n123',
#   ' rue de Lille (vu0) et 8',
#   ' boulevard du Nord',
#   '\nà Lyon (Rhône).\n'],
#  ['AILLIÈRES (M. Jean d’) [et M»° née de FRÉVILLE\ndeLORME]',
#   '214',
#   ' boni. Saint-Germain (vu») [P.-A.-T].\nAILLY (B»—”1 Jacques d’J née Thérèse de JUMILHAC\n30',
#   ' rue Boissière (xvr) — 0*3 d’Ailly',
#   ' 123 Roanne\n(Loire)',
#   ' Le Coteau',
#   ' 4 kil. tfë [P.-L.-M.] Le\nCoteau',
#   " l'Hôpital et Roanne",
#   ' 4 kil.—et M d’Alosse',
#   '\n1SI Marcilly-en-Villette',
#   ' 4 kil. (Loiret)',
#   ' @1\n[Or] La Ferlé St-Aubin et St-Cyr-en-Yal',
#   ' 12 kil.\nAILLY lie VERNE CIL (M. d’)',
#   ' O. #',
#   ' Sgndiedes Agents\nde change [et Mm» née TRICHARD]',
#   ' 30',
#   ' avenue\nMontaigne (vin*).\n'],
#  ['A INVAL (Vu d’)',
#   " Lieutenant d’Artillerie [et V'----\nnée HA Y des XETUM1ÈRESJ",
#   ' 44',
#   ' rue François-\nI',
#   'r (vin») fp.-â-t.).\n'],
#  ['AKEIÏMANN (M.) [et M“» née Germaine RENIER]',
#   ' 3',
#   '\nrue Le Nôtre (xvr).\n'],
#  ['ALADRO KASTRIOTI (S. A. S. le P°* don Juan de)',
#   '\nancien Ministre Plénipotentiaire d’Espagne ien\nson hôtel)',
#   ' 9',
#   ' square Lamartine (xvr). B-UA\nALAMAGNïj (Edouard)',
#   ' 26',
#   ' rue Bayard (viir)',
#   '\n[iH 331 Tl] — fià de Cm aise',
#   ' ES) [£= Mont¬\nbrison (Loire). Sp\n'],
#  ['ALAVOINE (Auguste) [et Mm°]',
#   ' Ê des Ormeaux',
#   '\nIS1 R= Benodet',
#   " [0' Quimper (Finistère). A\nAlbebti.ni : voir Uiaz-Albertini.\n"],
#  ['ALBEKTI (Léopold) [et M“* née REITLINGER]',
#   ' 73',
#   '\nboulevard Haussmann (vnr).\n'],
#  ['ALBERT-LAMBERT (M.)',
#   ' Sociétaire de la Comédie-\nFrançaise',
#   ' O. I. ||',
#   ' [et M“” née Angèle BASSA-\nLER]',
#   ' 224',
#   ' rue de Rivoli IJ- 243.89].\nALBERT-MORIX (Jean) [et M- née JANNIN]',
#   ' jfo\nde Gravelles',
#   ' a Etrechy (Seine-et-Oise). UA-Y\n'],
#  ["ALBIGNAC (M” d’) [et M'-» née d’OIfFEUILLE]",
#   ' 6',
#   '\nimpasse des Gendarmes',
#   ' à Versailles — et ^\nd’Orthe',
#   ' a ]ÿ= St-MartindeConnée(Mayenne)',
#   '^\n[OJ Sillé-le-Guillaume. ^\n'],
#  ["ALBON (M1* d’) [et M'-« née de SETTANCOURT-\nVAUBECOURT]",
#   ' 17',
#   ' rue Vaneau (vu°) — et ^\nd’Avauge',
#   ' a Pontcharra- sur-Tardine (Rhône)',
#   '\nM [P-L-M] St-Romaiii-de-Popey. H-J-U\n'],
#  ['ALBRECHT do MARTENS',
#   ' [et Mm” née de LAVA]',
#   ' 3',
#   "\nrue St Didier (xvr) — et gZz d'Epaux",
#   ' a jj= gg\nChàleau-Thierry (Aisne).\n'],
#  ['ALBUFÉRA (SUCHËT',
#   ' Duc d’) [et D»"» née de CAM¬\nBACÉRÈS]',
#   ' 35',
#   ' rue St-Bominique (vu°) — et M de\nMontgoborta jÿ=^|[N]Yillers-Cotterêts (Aisne) J-U\nALBUFÉRA (SI CHET',
#   " M'1 d’)",
#   ' [et M -- née Anna\nMASSENA de RIVOLI',
#   " P-° d'ESSLING]",
#   ' 40',
#   ' av.\nHoche (vin») [A 511.49]',
#   ' et 10',
#   ' rue Jean-Goujon\n(vnr)',
#   ' — et à de Montgobert',
#   ' a Villers-Cotte-\nrets Cœuvres et Valsery',
#   ' 3 kil.',
#   ' M [N| Villers-\nCotterets',
#   ' 10 kil. ou Longpont 7 kil. (Aisne)-Bet\nvilla Masséna',
#   ' 1',
#   ' rue de France',
#   ' à Nice (Alpes-\nMaritimes). J-U\n'],
#  ['ALBl’QUERQUE (B°” de)',
#   ' 4',
#   " sq. du Roule (vin*). UA\nALBYVILLE (C*« d') [et C'«— née de SERCEY]",
#   '\néêü <in Chatelier',
#   ' a Binan (Côtes-du-Nord) — et\nÉÊâ de Ilomigny',
#   ' a Sains (Somme)\n'],
#  ['ALCANTARA ((>»■■« AI var d’)',
#   ' née de GAUDE-\nCHART',
#   ' 2',
#   ' rue de la Planche (vu») — et O de\nQiierrieu',
#   ' a Querrieu (Somme)',
#   " [N] Amiens.\nALCANTARA (Cte Jean d’) et [(>■■' née T EINT DE\nROODENBEKE",
#   ' mêmes adresses.\n'],
#  ['ALCEDO (M-- d’) [et M - née de BANUELOS]',
#   ' villa\nAlcedo',
#   ' à Biarritz (Basses-Pyrénées) — et',
#   '\nCastrelos',
#   ' Yigo (Espagne). AT-G-U\n'],
#  ['ALEM (M. Pierre) H M. A. [et M”* née Marie-Thé¬\nrèse de BOSKEDON]',
#   ' 1',
#   " place des Perchamps (xvr).\nALENÇON (S. A. R. Mgr. le Duc d'j",
#   ' 11',
#   ' rue Beau-\njon (vnr).\n'],
#  ['ALÈS de CORBET (Vu d’) [et Yu**e née deBEAUCÉ]',
#   '\n2',
#   ' square de La Tonr-Maubonrg(vir) — et jêj du\nHoussay',
#   ' a Segré (Maine-et-Loire). A-H\n'],
#  ['ALEXANDER (M.etMm0 Charles)',
#   ' 64',
#   ' avenue du Bois-\nde-Boulogne (xvr).\n'],
#  ['ALEXANDRY d’ORENGIANI (B01 Michel d’)',
#   ' Lieute¬\nnant au 13‘ Cuirassiers [et B»”— née de NEUVILLE]',
#   '\n8',
#   ' rue Pierre-Charron (xvr) — et du Puits',
#   '\na Coise-St-Jean-Piedgauthier',
#   ' t-g St-Pierre-\nd’Albigny (Savoie).\n'],
#  ['ALF.XIS (S. A. I. le Grand-Duc)', ' 38', ' avenue Gabriel', '\n'],
#  ['(VIII-).\n'],
#  ['A LE Y B \\C fRoa René drd [et B0ttna née de COLOMBEL]',
#   '\n78',
#   ' rue des Saints-Pères ivn*).\n'],
#  ['ALEYRAG d’AlGKEPONT. (Bond’)',
#   'et de Prélefort',
#   '\nSaint-A y (Loiret) t&S[0r] Meung-sur-Loire —\net villa de Monternot',
#   ' igj [P-L-M.J Belle-\n'],
#  ['ville-sur-Saéne (Rhône).\n'],
#  ['ALFAS SA (Samuel) [et Mm* née HILLEL]',
#   ' 46',
#   ' rue\nPierre-Charron (vme) [3? 519.94]. GF\n'],
#  ['ALG\n'],
#  ['36\n'],
#  ['AME\n'],
#  ['ALGAN (Le Colonel Henri)',
#   ' 0. ch',
#   ' K [et M"* née\nCLÉMENT]',
#   ' lOi',
#   ' rue Lauriston (xvf).\n'],
#  ['ALGAURA (Edouard de) [et M"* née d’ALBAU]',
#   ' 165',
#   '\navenue de Wagram [7. 557.85]',
#   '\n'],
#  ['AL1C0T (M—)',
#   ' 33',
#   ' rue Saint-Guillaume (vif).\nALICOT (Michel)',
#   ' ancien Député [et M"’ née BON-\nNARIC]',
#   ' même adresse.\n'],
#  ['ALIGNY (PICOT de MORAS',
#   ' B“» d’) [et I!--- née\nMENANS]',
#   ' 31',
#   ' quai d’Orsay (vu*) — et A de\nMontmirey-la-Ville',
#   ' K Moissey (Jura). A-H\n'],
#  ['ALIGNY PICOT de MORAS (B- André d’)',
#   " Lieute¬\nnant d'Arl illerie ! et [t”n^ née Thérèse de PARIEL]",
#   '\n11',
#   ' rue Saint-Dominique (vil») — et A de Montmi\nrcy-la-Ville',
#   ' Kl Moissey (Jura) |j= 7. Montmirey-\nlc-Clihteau — et M de Fabrègues',
#   ' K éâ\n'],
#  ['Aurillac (Cantal). A\n'],
#  ['ALIGRE',
#   ' née de PRÉAULX (M\'“ d"',
#   ' 89',
#   ' faubourg\nSt-Honoré (vm“)',
#   ' [7. 516.39] —et afo de La Rivière',
#   '\n53 [£= âl Ponlgouin (Eure-et-Loire) — et ^ des\nVaux',
#   'KÎf= Belhomert (Eure-et-Loir)',
#   '[0] Pont-\ngouiu et La Loupe.\n'],
#  ['Aligre (d’) : voir Pomereu d’Aligre.\n'],
#  ['AL1NT.0URT (Cu d’)',
#   ' [et C""° née G1LL0TLX]\nG ELIOT]',
#   ' 17',
#   ' avenue d’Eylau (xvf) [ik 693.68\n— et à Plainfaing (Vosges). B-H\n'],
#  ['Alinev d’Elya : voir d’Elva.\n'],
#  ['ALLAI RE (Colonel Ernest)',
#   ' 0. tjf',
#   ' 16',
#   ' rue Mari-\ngnati (vnf). AL\n'],
#  ['ALLAI RE (Jules)',
#   ' K',
#   ' Juge au Tribunal delà Seine',
#   '\n16',
#   ' rue de Marignan (vin*). AL\n'],
#  ['ALLAI RE (Mm* Etienne)',
#   ' 101',
#   ' rue du Bac (vif).\nALLARD',
#   ' née AUBINEAU (Yu“* d’)',
#   ' 23',
#   ' rue du\nCherche-Midi (vf).\n'],
#  ['ALLARD (Jules) [et Mm” née LACOSTE de SAINT-\nAMAND]',
#   ' 10',
#   ' rue La Terrasre (xvf) — et jêj du\nPrieuré de Gaillonnet',
#   ' K Meulan (Seine-et-Oise).\nALLARD du CHOLLET (C“)',
#   ' 0. A y',
#   ' *',
#   ' * [et\nCl’“* née HARTOG]',
#   ' 114 bis',
#   ' boulevard Malesherbes\n(xvtf).\n'],
#  ['ALLARD de GAILLOX (B- E.) [et B-"-- née FLO¬\nCON]',
#   ' 5',
#   ' quai Malaquuis (Vf) [3* 817.07]. AG-H\nALLEMAGNE (B”» Paul d’) [ut B°-»>- née d’ABBADIE\nd’ARRAST]',
#   ' 88 bis',
#   ' rue Joulïroy (xvif).\nALLEMAGNE (Edmond d’) [et M“* née liAZIKE]',
#   ' 15',
#   '\nrue d’Astorg (VHP) — et ^ de Polisv',
#   ' K Po\nlisy',
#   ' £g Polisot (Aube). AL\n'],
#  ['Allemans (d’) : voir du Lau (»’).\n'],
#  ['ALLEZ (Edouard) [et M”’ née HOULLIER]',
#   ' 19',
#   ' rue\nLeroux (xvf) [TR 522.80] — et sà de Faiconne',
#   ' 181\ngg [0] Nanterre (Seine-et-Oise). AC-H\n'],
#  ['ALLEZ (M”* Adrien)',
#   ' 21',
#   ' avenue',
#   ' de l’Alina (v np)\n[7. 519.87].\n'],
#  ['ALLEZ (Lucien)',
#   ' 39',
#   ' rue d’Artois (vrip). AC-H\nALLEZ (M. et M"1 Emile-A.)',
#   ' 5 bis',
#   ' rue de Rerri\n(vnf ) [7. 529.73] — et de Belesbat',
#   ' K Boutigny\n(Seine-et-Oise).\n'],
#  ['ALLFRÉE',
#   ' née ROGUANOEF (M“*Helen-Féodorovna)',
#   '\n82',
#   ' rue de Varcnnc (vil”) — et 61',
#   ' Myddlctou Square',
#   '\nLondon (Angleterre).\n'],
#  ['ALLFREE (Alexandre-Charles)', ' mêmes adresses.\n'],
#  ['ALLIBERT (Jacques) [et M"1” née de BAMMEYILLEJ',
#   '\n10',
#   ' rue de Marignan (vnf) [3î 525.82]',
#   ' AG-H\nALL1ZÉ (M. Henry)',
#   ' Ministre de France à Stockholm\n[et Mm* née 11EBBETTE]',
#   ' 30',
#   ' rue Boissière (xvf)\net à Stockholm-',
#   ' légation de France (Suède).\nALMEIDA (C1\'”1" d’)',
#   '30',
#   ' avenue Henri-Martin (xvf)\n— et Villa Almeida',
#   ' à Avon (Seine et Marne).\n'],
#  ['ALOISI (M. et M“" POMPEO)', ' 28', ' avenue du Troca-\ndéro (xvf).\n'],
#  ['ALPHAND (M. Charles)',
#   ' Vice Consul',
#   ' attaché aux\nAffaires Étrangères [et M“* née Margerin de GRÉ-\nMONT]',
#   ' 11',
#   ' avenue de L11 Grande Armée (xvf).\nALPHEN SALVADOR (Mm* Emile)',
#   ' 9',
#   ' rue Le Tasse\n(xvf) — et à de la Cornmaiiderle',
#   ' SI A3 jÿ=\nBallan (Indre-et-Loire).\n'],
#  ['ALPHEN-SALVADOR', ' mêmes adresses.\n'],
#  ['ALSACE (C** Maurice d’)', ' 20', ' rue Washington (vnf)\n'],
#  ['J-RR\n'],
#  ['ALSACE (C** Philippe d’) [etC‘““* née de BRIENEN]',
#   '\n4',
#   ' rue Dumont-d’Urville (xvf) [7î 520.64] — et\nMontgraham',
#   ' S ]£= Souancé i Eure-et-Loir)',
#   ' ^8\nNogent-le-Rotrou. J-RR\n'],
#  ['Alsace (»’) : voir aussi d’Hénin (d’).\n'],
#  ["Altena (d’) : voir de Borciigiuve d'Altena.\nAltenbourg (d’) : voir de Ghampreux (d-).\n"],
#  ['ALT11AUS (Le Colonel B*” Augusto de)',
#   ' O. Sfr',
#   ' Atta¬\nché militaire d i Pérou en France et en Italie',
#   ' 72',
#   '\navenue Kléber (xvf).\n'],
#  ['ALTON (C1* d’)',
#   ' éês de la Bertraie',
#   ' K S [Or]\nClefs',
#   ' 4 kil. (Maine-et-Loire).\n'],
#  ['ALTON |V1" Charles d’) [et Y1"”” née de LA ROQUE-\nORDAN]',
#   ' 4',
#   " rue ('.revaux (xvf) — Chalet-Branet",
#   '\nS >8 [Or] Buch (Gers) — et même fa . H-J\nALTON-SHÉE (G1”** d’)',
#   ' 12',
#   ' rue Pergolèse (xvf).\nALTON-SHEE (Cte P. d’)',
#   ' même adresse.\n'],
#  ['ALVEAIl (Marcel-T. de) [et M- née PACIN1]',
#   ' 119',
#   '\navenue de Wagram (xvif) [7î 583.76].\n'],
#  ['AO-AE-B-H-ÜA\nALYES de ARAUJO (llippolyto) [et M“* née da\nPORGIUXCULA]',
#   ' 57',
#   ' avenue Kléber (xvf).\nAMAND-VILLEFOUT (M.) ch',
#   ' Secrétaire d\'Ambas¬\nsade [et M"1\'née CIIIBOIRGJ',
#   ' 14',
#   ' rue Dupout-des-\nLoges (vif) [7. 702.461.\n'],
#  ["AMAT (D' Charles)",
#   ' ch',
#   ' 0. A. «',
#   ' [et M- née A. DU¬\nBOIS]',
#   ' 13',
#   ' rue Lôon-Cogniet [7. 549.46]',
#   '\n'],
#  ['Amécourt (d’) : voir de Ponton (d’).\n'],
#  ['Amblard de Beaumont (voir de Beaumont).\n'],
#  ["AMBOIX de LARBONT iLe Général à') C. ch [et\nM“* née de POUBTALÉS]",
#   ' 11',
#   ' avenue Hoche (vnf )\n— et flà du Val-Larbont',
#   ' K flg La Bastide-\nde-Sérou',
#   ' distance 1 kil. (Ariége)',
#   ' U\n'],
#  ['AMBOIX de LARBONT (Paul d’)',
#   ' mêmes adresses.\nAMBOIXdeI.ABBONT (M. Roger d’)',
#   ' mêmes adresses.\nAMBRIÈRES (A. d’)',
#   ' Capitaine au 10• Hussards',
#   ' [et\nM"" née LE COl\'PPEY]',
#   ' 60',
#   ' rue Pierre Charron.\nAmbrines (d’) : voir de Valicourt d’AMimiNES.\nAmécourt (d’) : voir de Ponton d’AMÉcoiiRT',
#   '\nAMELLNE (M-',
#   ' Ernest) née FERRARI de CAMPO-\nLEONT',
#   ' 29',
#   ' rue Chaptal (ix*) et à Yillers-sur-Mer\n(Calvados).\n'],
#  ['AME\n'],
#  ['31\n'],
#  ['AMELINE de LA BRISELAINE',
#   ' née ABEILLE (M—\nH.)',
#   ' 9',
#   ' rue Portalis (vin*).\n'],
#  ['AMELINE de LA BRISELAINE (Roger)', ' même adr.\n'],
#  ['AMELOT de LA ROUSS1L1IE',
#   ' née CHOPPIN d’AR-\nNOL VILLE (C1*1** Br*)',
#   ' 9',
#   ' boulevard de La Tour-\nMaubourg (vir).\n'],
#  ['AMELOT de LA UOUSSILHE (C1*)',
#   ' Secrétaire d’Am¬\nbassade [et O*” née CORBIN]',
#   ' 3',
#   ' boni',
#   ' de La Tour\nMaubourg (vii*) •— et ^ de Mortefontaine',
#   ' E\nPlailly (Oise) Mortefontaine',
#   ' gg [NJ. Survilliers.\n'],
#  ['H-UA\n'],
#  ['AMELOT de LA ROUSSILHE (V>-> [et V--»- née de\nSEGUR-LAMOIGNON]',
#   ' 9',
#   ' b. de La Tour-Maubourg\n(vif) — ffo de Méry',
#   ' E fe= 4§ï[N ot °] Méry-sur.\nOise (Seine-et-Oise) — et Domaine de Belleval',
#   ' K)\nÎ5= Beaucaire (Gard)',
#   ' ig [P-L-M] Arles. A\n'],
#  ['AMILA KVARI (LL. AA. RR.) (P°- et P°-°>',
#   ' 64',
#   " ave¬\nnue du Bois-de-Boulogne (xvt'J",
#   '.\n'],
#  ['AMI LL V (Cu Maurice d’) [et C""* née Germaine de\nLAAGEJ',
#   ' S',
#   ' rue de Marignan (vu*) — et ^\nd’Amilly',
#   ' K Berd’huis (Orne)',
#   ' jÿ= à Nogent-le-\nRotrou (Eure-et-Loir) -— et Pavillon des Evées',
#   '\n13 Jÿ= & [35 3] Senonches (Eure-et-Loir).\n'],
#  ['AMODIO (M-de)',
#   ' 4.4.4',
#   ' [et SP- née WAINWRIGHT]',
#   '\n88',
#   ' avenue Kléber (xvi*) [75 678.41]— de 8t.-\nMaurice-du-Désert ( 75 au flà )',
#   ' Kl â La Ferté-\nMacé (Orne).\n'],
#  ["ASIODRU i l>' Laurent)",
#   ' Député et Conseiller général\nde Seine-et-Oise [et M—]',
#   ' 66',
#   ' avenue des Champs-\nElysées (vin*) [7* 518.44] — et A de Chamarande',
#   '\nE^éS [Or] (Seine-et-Oise).\n'],
#  ['ANCEAL (SI- Eugène) née HEODERERT',
#   ' 114',
#   ' ave¬\nnue des Champs-Elysées (vin”) [75 506.31].\n'],
#  ["ANCEL (M”' Adolphe)", ' 103', ' rue La Boétie', ' (vin*)\n[75 521.37].\n'],
#  ['ANCEL (Raoul) [et M“* née COPPINGER]',
#   ' 19',
#   ' rue de\nBassano (xw=) — et de Gournay',
#   ' Eâl [O]\nHarfleur (Seine-Inférieure) \\y Gainneville: A\n'],
#  ['ANCEL (Georges)',
#   ' 191',
#   ' boni. St-Gcrmain (vii*) —et\nÊÊ) des Petit-Colmoulins',
#   ' K) flg [O] Harfleur\n(Seine-Inférieure). A-Y\n'],
#  ['Avdernay (d’) voir de Vassart d’Andernay.\n'],
#  ['ANDERSON (Captain J.-H.)',
#   ' 33',
#   ' av. Montaigne (viir)',
#   '\n— et Albany',
#   ' 2',
#   ' Piccadilly',
#   ' à Londres. RR-UA-Y\n'],
#  ['ANDIGNÉ',
#   " née de BARBENTANE (M'*' d’)",
#   ' 77',
#   ' rue\nde Lille (vu*). [75130.10] — âjtj de Monet',
#   ' 153\nBeaufort-en-Vallée (Maine-et-Loire)',
#   ' è-4 [Or]\nLa Ménitré',
#   ' Brion-lumelle et Beaufort — et {gj de\nBarbentane',
#   ' la )- - Barbentane (Bouches-du-Rhône).\n'],
#  ['ANDIGNÉ (M"“ d’)',
#   ' mêmes adresses — et *£* (je\nCondillac',
#   ' Kl M La Coucourde (Drôme).\n'],
#  ['ANDIGNE (M‘‘d’) [et M‘“ née Madeleine GODDARD]',
#   '\n77',
#   ' rue de Lille (vu*) [75130.10] — de Monet',
#   '\nE) Beaufort-en-Vallée (Maine-et-Loire)',
#   ' {jglÉtl.\nLa Ménitré et Jumelles-Brion — {fis de Giraud',
#   ' El\nLe Sambuc (Bouches-du-Rhône)',
#   " l'Armelliére-\nGiraud",
#   ' [P-L-M] l’Arnelliére-Giraud et Arles-\nsur-Rhône — et de Richebourg',
#   ' El La Bassée\n(Pas-de-Calais) H-J-RR\n'],
#  ['AND\n'],
#  ['ANDIGNÉ (C‘* d’)',
#   ' officier de cavalerie démission¬\nnaire',
#   ' Conseiller municipal de Paris',
#   ' Conseiller\ngénéral de la Seine',
#   ' 49',
#   ' rue de Boulainvilliers\n(xvi*) — et 2',
#   ' rue SchelTer (xvi*)— et mêmes O .\n'],
#  ['CM-RR-H-J\n'],
#  ['ANDIGNÉ',
#   ' née de CROIX (C1*"* de)',
#   ' 3',
#   ' rue de La\nChaise (vil*) — îgj de Grip',
#   ' SI Durtal\n(Maine-et-Loire)',
#   ' â [Or]',
#   ' Moraunes et Durtal —\nde Barneville',
#   ' E £f= ^1 [O]',
#   ' Honfleur (Cal¬\nvados)— et êêj de Franc-Slarct',
#   ' E Vezin(Belgique)',
#   '\nMarche-les-Dames tôE) Nainur.\n'],
#  ['ANDIGNÉ (C“ Jean d’)',
#   " [et Cl“'“ née de VILLE-\nCHAIZE]",
#   ' 3',
#   ' rue La Chaise (VII») — et mêmes {£s\n'],
#  ['A-H-J\n'],
#  ['ANDIGNÉ (C** Henri d’) [et Cl**‘» née d’EVRY]',
#   '\n10',
#   ' rue Clément Marot (vin*) — ^ de R esteau',
#   '\nE Chemiré-le-Gaudin (Sarthe)',
#   ' *75 (O) La\nSuze — et {ga de Thomasin',
#   ' E If2 Chantenay\n(Sarthe)',
#   ' (O) Noyen.\n'],
#  ['ANDIGNÉ (C‘* Maurice)',
#   ' 68',
#   ' av. de la Grande-Armée\n(xvi*)—et A delà Jousselinière',
#   ' E Beaupréau',
#   '\nlOkil. (Maine-et-Loire)',
#   ' ^ [Ét et Or]. Chaloimes-\nsur-Loire). UA\n'],
#  ['ANDIGNÉ (V- Louis',
#   ' d’) [et V1*»** née COLEMAN]\nveuve de COURCY-MAY]',
#   ' 6',
#   ' rue de Berri (vm-j\n[75 528.76] — et même {gj. AG-B-H-J-RR\n'],
#  ['ANDIGNÉ (C‘“ Geoffroy d’) [et C1*”* née CHANDON\nde BRIAILLES]',
#   ' 13',
#   ' rue de Berri (vm*) [75 537.41]\n— et afo de la Blanchaye',
#   ' E jÿ= éS [0] Sogrê\n(Maine-et-Loire). H-J-RR\n'],
#  ['ANDIGNE (C** Robert d’)',
#   ' Lieutenant au 14* Hus¬\nsards',
#   ' à Alençon [et C1*"* née LEFÈVRE]',
#   ' —\nmême {gj J\n'],
#  ["ANDI.AU (C1»*'* d’)", ' 170', ' faub. Saint-Honoré (vm*).\n'],
#  ['ANDLAU (Ct0 d’) [et C1*1** née de CHABROL-\nCHAMEANE]',
#   ' 4',
#   ' rue de Marignan (vin») — M de\nYoré',
#   ' E Ucmalard 3 kil. (Orne)',
#   ' jâg [0] Re-\nmalard',
#   ' 4 kil. et Condé-sur-Huisne',
#   ' 11 kil.\n'],
#  ['A-H-RR-U\n'],
#  ['ANDLAU (C1* Antoine d’)', ' même adresse. J\n'],
#  ["ANDLAU (C‘“ Jean d')", ' mêmes adresses.\n'],
#  ['ANDRAL',
#   ' née DELIES (SI”*)',
#   ' 26',
#   ' Cours la Reine\n(vm*)',
#   ' — et {fij de Ghâteauvieux',
#   ' E lf= éS [Or]\nSaiut-Aignan (Loir-et-Cher).\n'],
#  ['ANDRASSY',
#   " née C1**'* PALFFY (C'»“»)",
#   ' 68',
#   ' boni',
#   ' de\nCourcelles (xvn*).\n'],
#  ['ANDRAULT (C.)',
#   " Conseiller honoraire à la Cour\nd'Appel",
#   ' 30',
#   ' quai du Louvre — et au Petit-Bois-\nprés Melle (Deux-Sévrc-).\n'],
#  ['ANDRÉ (R°- d‘) [et B»"“" née de BlUCQl.\'EMONT]',
#   '\n3',
#   ' rue Auguste-Vacquerie (xvi*) — et ^3 de la\nSouque',
#   " e {#= eS[Or]Rabaslens-surTarn (Tarn'\n"],
#  ['H\n'],
#  ['ANDRÉ (B»"** Émile d’)', ' 76', ' rue de la Pompe (xvi°).\n'],
#  ['ANDRÉ (B** Albert d’) [et B"°* née GUILLAUD]',
#   '\n86',
#   ' avenue de Yllliers (xvi*).\n'],
#  ['ANDRÉ',
#   ' née JOLY de BAMMEVILLE (SI- Alfred)',
#   '\n49',
#   ' rue La Boétie (vm*) [75 531.53] — et {êî de\nCrassier',
#   ' E îp 75gg Divonnc-les-Bains (Ain).\n'],
#  ['AND\n'],
#  ['APC\n'],
#  ['38\n'],
#  ['ANDRÉ', ' née JAQUEMART (M- Édouard)', ' 138', ' boni.\n'],
#  ['Haussmann (vnr) [35 317.96]', '\n'],
#  ['ANDRE (L.) [et M“* née RIGAULT]', ' 3', ' rue La Boétie\n[vin»).\n'],
#  ['ANDRÉ (Alexandre) [et M-*née ROBERT de MASSY]',
#   '\n20',
#   ' rue d’Aguesseau (viii«) [3- 237.81] — et de\nLa Frogerie',
#   ' 8 Ligny-le Ribault (Loiret).\nANDRÉ',
#   " née L'HÉRITIER (Mm* Georges)",
#   ' de\nLesmont',
#   ' la js= Lesmont (Aube)',
#   ' ê3 [E] l’iney\net Brienne-le-Chàteau.\n'],
#  ['ANDRE (René) [et M"* née LE MIRE]', ' 3', ' avenue\nVictor-Hugo (XVIe).\n'],
#  ['Andreis : voir De Andreis.\n'],
#  ["ANDREZEL (Charles d')",
#   ' dfc',
#   ' Lieutenant de vaisseau',
#   '\n[et M”" née de FROTTÉ]',
#   ' 17',
#   ' rue Yernet (vnr)',
#   '\nANDRIEIIN (L.)',
#   ' #',
#   ' Ancien Député',
#   ' ancien Préfet\nde Police',
#   ' ancien Ambassadeur [et M™ née\nKOECHLIN]',
#   ' 42',
#   ' rue Scheffer (xvil [35693.82] — et\niêB du Casset',
#   ' 8 M [P-L-M] Montluel (Ain.)\nANETHAN (B*"* Alix d’)',
#   ' 12 rue Oudinot (vu*).\nANGELIS (M“ d’)',
#   ' Ministre plénipotentiaire [et M”»\nnée du BOUZET de CAUSSINS de MARIN]',
#   ' 8',
#   ' rue\nMeissonier (xvifl — et à Saint-Florent (Corse).\nANGÉLY ïC‘» Albert d’)',
#   ' à Sérillac',
#   ' 8 Beaumont-\nsur-Sarthe (Sarilie). UA\n'],
#  ['ANGÉLY (Emile d’) [et Mne née de CONFLANS]', ' 7', '\n'],
#  ['- rue Alboni (xvie) — et ^ La Héraye',
#   ' 8 Ta-\nvers',
#   ' gg Beaugency',
#   ' (Loiret)',
#   '\n'],
#  ['ANGÉLY (Mne Maurice d’)',
#   ' 64',
#   ' rue de Rennes (vie).\nANGLADE (Achille)',
#   ' #',
#   ' [etM- néePETITGUÉNOT]',
#   '\n32',
#   ' avenue Montaigne (vm*) — et jgj de Saint-\nEutrope',
#   ' 8 Montlhéry (Seiue-et-Oise). AL\n'],
#  ['ANGLADE (M. René) [et M”» BOSSERONT d’]',
#   ' 113',
#   '\nrue de Courcelles (xvii',
#   ')It- et ^ l’Andiran',
#   ' 8\n^ ggj Nérac (Lot-et-Garonne).\n'],
#  ['ANGLEMONT',
#   " née THOMAS (V>-- Christian d')",
#   ' 14',
#   '\nrue Greuze (xvi»>.\n'],
#  ['.ANGLEMONT (Vle Henry d’) [et V>» "» née de MA-\nCHADO]',
#   ' 14',
#   ' rue Greuze (x\\T).\n'],
#  ['ANGLESEY (M”* d’)',
#   ' 17 bis',
#   ' rue Mansart à Ver¬\nsailles (Seineet-Oisei.\n'],
#  ['Anglure (d’| : voir de Noblet (TAnglure.\n'],
#  ['ANGOT (Alfred) [et M”* née AGELASTO]',
#   ' 176',
#   ' rue\nde l’Université (vu*) [35 700.07] (Jeudi).\n'],
#  ['ANGULO (Rafaël)',
#   ' K [et M“» née SANCHEZ de\nMOVELLAN]',
#   '7',
#   ' avenue de l’Alma (vm*) [35 308.72]',
#   '\n— et jgj de Rouvres',
#   ' 8 4Ü Vigneux (Seine-\net-Oise) [35 38] Villeneuve-St-Georges. H-Y\n'],
#  ['ANGULO Y GARCIA (Gregorio)',
#   ' 17',
#   " avenue de l'Alma\n(vin*) — et û El Cid",
#   ' 8 eë La Baule (Loire-\nInférieure»',
#   '\n'],
#  ['ANINAT (Benjamin) [et M“* liée SEMINARIO]',
#   ' 20 bis\nrue Iioissière (xvr).\n'],
#  ['ANINAT (M** Antoine)',
#   ' née de VIALE-RIGO',
#   ' 20',
#   ' rue\ndu Bouquet-de-Longchamp (xvi*).\n'],
#  ['ANISSON du PEBRON (Roger)',
#   ' Ancien député',
#   ' 13',
#   '\navenue Hoche (vm*) [35 804.46] — et (fil de St-\nAubin',
#   ' 8 Allouville-llellefosse',
#   ' 5 kil. (Seine-\nInférieure)',
#   ' ^ [0] Foucart et Alvimare',
#   ' 6 kil.\n'],
#  ['A-H-RR-U-UA\n'],
#  ['ANISSON du PERRON (Jacques)',
#   ' Capitaine au\nlO’ChasseursfiMouhm) [et M“*néedeBOISGELIN]',
#   '\n13',
#   ' avenue Hoche (vm*) — et même à — etfljjde\nSt-Fargeau',
#   '8 ^ M [35 6] St-Fargeau (Yonne).\n'],
#  ['H-RR\n'],
#  ['Anlezv (d’| : Voir de Damas (I’Am.fzy.\n'],
#  ["Annflet (d’) : Voir Rurthe d'A.NNELEi.\n"],
#  ['ANNENKOFF (M”* Dagmarf',
#   ' 24',
#   ' avenue du Troca-\ndéro',
#   ' (xvi*) [35 694.47].\n'],
#  ['ANSAC (M11* d’)', ' 32', ' avenue Hoche (vui‘).\n'],
#  ["Ansac (d’) : Voir aussi M'* de Chabf.rt (d').\n"],
#  ['ANTERROCHES (C‘« d’) [et C>-- née MATHIEU]',
#   '\nS',
#   ' rue de Monceau (vm*) — et {gj de Champeaux',
#   '\ni^i Palinges (Saône-et-Loire) — et A d’Anlerro-\nches',
#   ' 8 Æ Murat (Cantal).\n'],
#  ['ANTERROCHES (Y1* d’) [et V[-*nce des ROTOURS]',
#   '\n64',
#   ' boulevard .Malesherbes (vm*).\n'],
#  ['ANTHENAISE',
#   ' née de PERItUSSE des CARS (Y*»“ d’)',
#   '\n24',
#   ' Cours la Reine (vm*) — et fgj de la Jaillière',
#   '\n8 Varades (Loire-Inférieure)',
#   ' M [Or] Iugran-\ndes-sur-Loire.\n'],
#  ['Anthenav (d’) : Voir aussi Renoist iTAntiienay.\n'],
#  ['ANTHENAY (B”“ Georges d’)',
#   ' Ancien Receveur des\nFinances [etB°“*]',
#   '10',
#   ' avenue de AVagram (vm*)—\net {fe de La Chapelle',
#   ' 8 Troyes (Aube).\n'],
#  ['ANTRES (B*»»» Ph. d’)', ' 21', ' avenue Niel (xvil*).\n'],
#  ['Antues (d’) : Voir de Heeckeiien ü’Anthes.\n'],
#  ['ANTHOUARD de YRAINCOURT (C‘«d\') [et c°*"° née\nde MONSEIGNAT]',
#   ' 19',
#   ' avenue d’Iéna (xvi»)',
#   ' — et\n(fil de Yraincourt',
#   ' 8 Clerinout-en-Argoime\n(Meuse). A-H\n'],
#  ['ANTHOUARD de WASSERVAS (R°- Albert d’)',
#   ' Secré¬\ntaire (TAmbassade',
#   ' K [et B*"* née deROMEL\'F)',
#   '\n146',
#   ' boulevard Haussmann (vm*).\n'],
#  ['ANTIOCHE (C‘“ d’)',
#   ' iK',
#   ' 23',
#   ' rue Barbnbde-Jouy (vu*)\n— M de Selorre',
#   ' 8 St-Yan',
#   ' 1 kil. (Saône-et-\nLoire)',
#   ' âl [P-L-M.] Saint-Yan',
#   ' 4 kil. et Paray-le-\nMonial',
#   ' 12 kil. — et A de Nernier',
#   ' 8 ]?= Nernier\n(Haute-Savoie)',
#   ' [P-L-M] Genève',
#   ' 23 kil. et\nBons-Saint-Didier',
#   ' 18 kil.',
#   ' bateau à vapeur',
#   ' Ner¬\nnier. H-U\n'],
#  ['ANTIOCHE (MIU d’)', ' mêmes adresses.\n'],
#  ['ANTOCOLSKI i',
#   'M- Marc)',
#   ' née d’APOTOFF',
#   ' — et La\nllaromietta',
#   ' Locarno (Lago Maggiore) (Italie).\n'],
#  ["ANTONETTI (C'« Pierre) [et née KNAPP]", '\n'],
#  ['6', ' rue Arsène-Houssaye (vnr).\n'],
#  ['ANTONIX MERCIÉ',
#   " Membre de l'Institut",
#   ' C. K',
#   '\n13',
#   ' avenue de l’Observatoire (vi») [35811.96] —\net Villa Antonin-Mercié',
#   ' Croix Daurade',
#   ' 8jÿ=(â\n[Or] Toulouse (Haute-Garonne). UA\n'],
#  ["Antonio d'Orléans (S. A. R. don) voir Duc de Gal-\nliéra.\n"],
#  ['AOLST (M* d’) [et M"* née VERGER]',
#   " 47. faub. St-\nHonoré (vm*)—et jfgj de S'-Léger",
#   ' 8 [ï= Croisille\n(Pas-de-Calais). A-H-UA\n'],
#  ['APCHIER LE MAUGIN (G\'*"* A. d’). 6',
#   ' rue Sédillot\n(vu*) — et à Grasse (Alpes-Maritimes) — et à\ndu Malzieu',
#   ' 9-J fs- Le Malzieu (Lozère)',
#   ' i£3 [M]\nSMMiély d’Apchier.\n'],
#  ['APC\n'],
#  ['39\n'],
#  ['ARG\n'],
#  ['APCHIER LE MAUGIN (C‘e d’)„ Secrétaire tïAmbas¬\nsade',
#   ' 8',
#   ' rue Séilillot (vu”).\n'],
#  ["APCHIER LE MAUGIN (V1* d')",
#   ' Capitaine au 4*.\nDragons',
#   ' à Chambéry [et Y1""" née ROZAT de\nMANDRES]',
#   ' 6',
#   ' rue Sédillot (vu*) (p.-à-l.) — et\nA*} de Malzieu',
#   " K) Malzieu-ia-Yille M St-Chely-\nd'Apchier (Lozère) — et villa des Charmilles",
#   ' à\nChambéry (Savoie!.\n'],
#  ["APCHIER LE MALGIN (Y1' Jehan d')",
#   ' Vice-Consul\nde France',
#   ' 6',
#   ' rue Sédillot (vif) — et A du\nMalzieu',
#   ' El lf= Malzieu-Yille',
#   ' é§ Saint-Chély-\nd’Apchier (Lozère).\n'],
#  ['APERT (IP Eugène) [et M"* née NOÉL]',
#   ' 11',
#   ' rue Ma\nrignan (vni“) [ F. SS1.68] — et {fig de Terrides',
#   ' Si\nLabourgade',
#   ' Larrazel à 5 kil. (Tarn-et-\nGaronne).\n'],
#  ["APLETSCHËIEFF (Alexandre-André d’) [et M”'née de\nBERGMANN]",
#   ' 99',
#   ' rue de Courcelles (xvn°). H\nAPPERT (Colonel Henri)',
#   ' K [et Mm* née ROLAND-\nGOSSELIN]',
#   ' 47',
#   ' avenue de l’Alma (vm°).\n'],
#  ['ARAGO (François)',
#   ' 0. Député des Alpes-Mari¬\ntimes [et I1" née DUPUY]',
#   ' 46',
#   ' avenue du Bois-\nde-Boulogne (xvi°) — et fl*} de Fauguerolles',
#   ' S\nFauguerolles (Lot-et-Garonne) AC-CF\n'],
#  ['ARAGUAYA (C',
#   'e et Cle',
#   '',
#   'e d’)',
#   ' 127',
#   ' boulevard Hauss-\nmann{(vwe). UA\n'],
#  ['ARAMON (M" d’) [et MUe née de LA BASTIDE]',
#   ' 2',
#   ' rue\nGoethe (xvie) [3:564.16] — **} d’Aramon',
#   ' S\n[P.LM.] Aramon (Gard). J\n'],
#  ['ARAMON (G** Guillaume d’)',
#   ' [et Cte',
#   '’e née de MONT-\nSAULNIN]',
#   ' 34',
#   ' rue de Chaillot (vin*) [35561.39] —\net {fi} de Bernay',
#   ' ifi! La Guerche (Cher) et — {fi}\nde la Grande-Garenne',
#   ' IS fs= Neuvy-sur-\nBarangeon (Cher). H-J\n'],
#  ['ARAMON (Cle Jacques d1) [et O»"» née FISHER]',
#   '\n1',
#   ' boni',
#   ' de La Tour-Maubourg (vu1) [35701.04] — et\n{fi} d’Anizy',
#   "s ^=^[N] Anizy-Ie-Chàteau(Aisne). J\nARAMON (Cle Bertrand d') [ot CteMe née Suzanne\nSTERN]",
#   ' 28',
#   ' rus de Berri (vin») — et mêmes\nadresses. J\n'],
#  ['ARAMON (C',
#   'e Paul d’)',
#   ' [et C',
#   'eeee née Rita BELL]',
#   '\n1',
#   ' boni. Latour-Maubourg (vu*) — et même {£} .\n'],
#  ['J-T\n'],
#  ['Araiijo : voir Pimo de Arauo.\n'],
#  ['ARBOIS de JLBAINYILLE (d’)',
#   " Membre de l'Institut",
#   '\nO {K',
#   ' 84',
#   ' boni. Montparnasse (x',
#   'iv) — et {fi} de\nJubainville',
#   ' K Martigny-les-Gerbonvaux (Vosges).\nARBOIS de JUBAINVILLE (Léopold d’) [et Mmi née\nCERISE]',
#   ' 2',
#   ' place des Saussaies (vin") — et\nmême {fis .\n'],
#  ['ARBOIS de JUBAINVILLE (Paul d’) [et M- née\nMICHELET] — même .\n'],
#  ['Arbouse (d1) : voir de Veyny d’Arbocse.\nARCHAMBAULT-GUYOT (Maurice)',
#   ' Avocat à la Cour\n[et M“* née P1CH0T]',
#   ' 61',
#   ' rue de Miromesnil (vm*)\n[35548.83] — et {fi} Les Grandes Bourdinières',
#   ' £3\nRomorantin (Loir-et-Cher). AL\n'],
#  ['ARCHDEACON',
#   ' née de ROCQUTGNY du FAYEL\n(M“* Edmond-S.)',
#   ' 15',
#   ' avenue des Champs-Elysées\n(vup) — et {fi} de Cheney',
#   ' K Tonnerre (Yonne).\n'],
#  ['ARCHDEACON (Jules) [etM"> née Madeleine PARANT]',
#   '\n63',
#   ' avenue do Villiers (xvu*) [35 516.47] — et {fifl de\nMenucourt',
#   ' £3 Vaux (Scinc-et-Oise). B-RR\n'],
#  ['ARCHDEACON (Ernest)',
#   ' Avocat « lu Cour',
#   ' [et M“*\nnée de FONTAINES]',
#   ' 77 rue de Prony (xvn°>\n[35511.22]',
#   ' - AC\n'],
#  ['ARCHDEACON (Jacques)',
#   ' 38',
#   ' rue Marbeuf (vm*) —\net {fi} de Beaumarchais',
#   ' K Autrèche (Indre-et-\nLoire) . AL\n'],
#  ["ARCHIAC (C>- DEXMIER d')",
#   ' Ancien Officier de\nCavalerie',
#   ' K 46',
#   " rue de Miromesnil (vm')",
#   ' — {fi}\nde Villiers-St-Paul',
#   ' El {f= Nogent les-Vierges',
#   '\n3 kil. (Oise)',
#   ' M [N] Creil et Villers-St-Paul — et\n{fi} d’Argiliy',
#   ' g| â [E et P L M] Nuits-St-\nGeorges (Côte-d’Or) Argilly. J-UA\n'],
#  ['ARCHINARD (Louis)', ' C. # [etMme]', ' 9', ' rue Brémon-\ntier (xvne).\n'],
#  ['ARCICOLLAR (M“ d’) [et M‘»‘ née de CANDAMO]',
#   '\n44',
#   ' rue de la Faisanderie (.XVIe) [35 680.98]. AC-U\nARCOS (Santiago de)',
#   ' Artiste peintre',
#   ' Gentilhomme\nde S. M. Catholique [et M“e née de CUADRA]',
#   ' 56',
#   '\nrue de Bassano (vin*). T3A\n'],
#  ['Arcosse (d’) : voir Fossé-d’Arcosse.\n'],
#  ["Arcy (d’) : voir de Bnv-d'AiRCY.\n"],
#  ['ARCY (B011 d’) [et B"“* née de R00DENBEKE)',
#   '\n173',
#   ' boulevard Pereire (xvne).\n'],
#  ['ARDENNE DE TIZAC (M. d’)',
#   ' Conservateur du musée\nCernuschi [et Mme néo Andrée JACQUET]',
#   ' 7',
#   ' ave¬\nnue Velasquez [35 323.31]',
#   '\n'],
#  ['ARENBERG <P°* Auguste d’)',
#   ' ancien Député',
#   ' Con¬\nseiller général du Cher',
#   ' Membre de tInstitut',
#   ' 20',
#   '\nnie de la Yille-L’Ëvèque (vm“) [35 112.69] — et\n{fi} de Menetou-Salon',
#   ' K îS [Or] Alenetou-\nSalon (Cher)',
#   ' — {fiz d’Arlay',
#   ' K Arlay',
#   ' M\nDomblans',
#   ' 5 kil. (Jura). H-J-U-UA\n'],
#  ['ARENBERG (Pee Pierre d’)',
#   " [et P'*",
#   '',
#   'e née de GRA-\n5IONT de LESPARRE] 20',
#   ' rue de la Ville-l’Evêque\n(vme) [35 112.69] — et mêmes {fi} .AO-H J-RR\nARENBERG (Pce Ernest d’)',
#   ' 10',
#   ' rue d’Astorg (vm*).\nARFEUILLE (Cte*“ d’) née de LA PERRIÈRE',
#   ' {£}\nd’Arfeuille',
#   ' [Si Remy-en-Rolat (Allier) — et {£} de\nLafont',
#   ' K Brou-Vernet (Allier)',
#   '[Or et P-L-.M|\nGannat.\n'],
#  ['A RG AND ON A',
#   ' P°e de la GLORIETA (Francisco de)',
#   '\nMinistre plénipotentiaire de Bolivie',
#   " [et M“” née\nde L'RIOSTE]",
#   ' 33',
#   ' avenue Victor-Hugo (xvi*)\n[35545.58].\n'],
#  ['AISGENCE (M’’ d’)',
#   ' 1 bis',
#   ' rue de Chaillot (xvi”) —\n{fi} du Grand-Lucé',
#   " K jÿ= èS [0] le Grand-Lucé\n(Sarthe) — et {fi} de 'Louvoie",
#   ' es fÿ= â [O].\nSavigné-l’Evêque (Sarthe).\n'],
#  ['ARGENCE (C1* Frédéric d’) [et Cte"e née BARROT]',
#   '\n12',
#   ' rue Logelbach (xvu”) (p.-à.-t.) — et jfifl de Rou-\nvoie',
#   ' K |?= eâ [OJ Savigné-l’Évèque (Sarthe).\nARGENCE de PITTI-FERRANDI («■•“ LE GOUESLIER\nd’)',
#   ' 11',
#   ' rue de Lisbonne (vine) — Manoir à Pont-\nl’Evèque (Calvados) — et villa Hélène',
#   ' 30',
#   ' rue de\nParis',
#   ' àTrouville.\n'],
#  ['ARG\n'],
#  ['40\n'],
#  ['ARN\n'],
#  ['ARGENCE (Robert-G. d’)',
#   ' 21',
#   ' avenue du Trocadéro\n(xvp) — mêmes adresses.\n'],
#  ["ARGENSON (M» d’) [et M >* née d’HARCOL'RT]",
#   ' 11',
#   '\nruo Barbet-de-Jouy (vu*) [D 716.59] — et ^ des\nOrmes',
#   ' k{f= Ormes-sur-Yienne (Vienne). H-J-U\n'],
#  ["ARGENSON (G- d’) [et G.. LANJl'INAIS]", ' 11', '\n'],
#  ['rue Barbct-de-Jouy (vit*) [1115.30 — et même A . J\n'],
#  ["ARGENT (Cle d') [et C**“ née de LHOMEL]",
#   ' 1',
#   ' rue\nLincoln (vin*) — (le Bouville',
#   ' E3 d§ [Or]\nCloyes (Eure-et-Loir). A-B\n'],
#  ['ARGENT (V1* d’) [et Vte',
#   '',
#   '< née Yvonne de SADE]',
#   ' 19',
#   '\nrue de Yarenne (vu*) — et même {ÊS -\n'],
#  ['ARGENTI',
#   " née RALLI (M”>* L.I'.j",
#   ' 42',
#   ' avenue Ga¬\nbriel (VIII*).\n'],
#  ['ARGENTI (Auguste)', ' même adresse.\n'],
#  ['Assis (d’) : voir Horaire d Assis.\n'],
#  ['ARGUELLES', ' née MOXTERO (11- de)', ' 5', ' avenue\nHoche (vin*).\n'],
#  ['ARIËS (Dr)', ' 51', ' rue Ampcre .(XVII*) [J 533.89].\n'],
#  ['ARISTARCHY BEY (Grégoire)',
#   ' Ministre plénipo¬\ntentiaire',
#   ' 15',
#   ' rue Treilhard (vm*).\n'],
#  ['ARISTE',
#   ' née M1GN0TTE ÎM- Ch. d’)',
#   ' 43',
#   ' boni.\nMalesherbes (vm*) — et à Ghambourcy (Seine-et-Oise).\n'],
#  ["■ ARJl'ZON",
#   ' née CL\'VELIER (G1*’" d’)',
#   ' 13',
#   ' avenue\nBosquet (vil*) — et à Dreux (Eure-et-Loir).\n'],
#  ["ARJL'ZON (C‘* d’) [et G'-- née Mary YVADDINGTON]",
#   '\n16 1er',
#   ' avenue Bosquet (vu*) — {êa de St-Uemy',
#   '\nEl ^ St-Remy-sur-Avre (Eure-et-Loir)',
#   ' gg [0]\nSt-Gerinaiu-St-Remy — villa St-Remy',
#   ' Houlgate\n(Calvados) — et à Dreux (Eure-et-Loir). A H-J-UA\n'],
#  ['ARJL\'ZON (Y‘= d’) [et V1"”* née de VILMORIN]',
#   ' 12',
#   '\nrue Dupont-des-Loges (vu*) [ Z 120.01] —à Dreux\n(Eure-et-Loir) — à Verrières-le-Buisson (Seine-et-\nOise) — et villa « La Colline » à Antibes (Alpes-\nMaritimes). A\n'],
#  ['Arjuzox : voir Carol d’Arjlzom.\n'],
#  ['Arleüx (d’) : voir Morel d’Am.rcx.\n'],
#  ['ARLINCÔURT (G1* Jacques d’) [et G-- née PEL-\nLENC]',
#   ' 28',
#   ' rue Murillo (vm*)— et du Saussart',
#   '\nE [3* 2] gg [N] Serifontaine (Oise).\n'],
#  ['H-RR-UA\n'],
#  ['ARLINGOLRT (Cl* et Gl',
#   '“* Adrien d’)',
#   ' la',
#   ' rue\nBoissière (xvi*) — et chalet des Mouettes',
#   ' à Trou-\nville (Calvados).\n'],
#  ['ARLOT de SAINT-SALD (G- d’) [et G»— née de\nROCHECHOLART]',
#   ' 4',
#   ' avenue du Trocadéro (xvi*)\n(p.-à.-t.) — {êa de la Valouze',
#   ' K gg [Or] La\nRoche-Ghalais-St-Aigulin (Dordogne) — et â de\nClisson',
#   ' O â [Et] Bressuire (Deux-Sèvres) —\net 82',
#   ' rue du Lancera',
#   ' à Bordeaux (Gironde).\n'],
#  ['ARLOT de SAINT-SALD (C‘“ Jacques d’)',
#   " Secrétaire\nd’ambassade [et G1*'** née de LAFAYE]",
#   ' 29',
#   ' rue\nde Berne (vin*).\n'],
#  ['AUMAILLÉ',
#   ' née de SËGLR (C1*”* d’)',
#   ' 9',
#   ' square de\nMessine (vin*) — et 62',
#   ' rue Aguado',
#   ' à Dieppe.\n'],
#  [".ARMAILLÉ (G** d’) [et G1*1** née Raymonde do NI¬\nCOLAY']",
#   ' 63',
#   ' rue de Varenno (vu*) — et fit de la\nMenantiére',
#   ' Kl : Montrevault ',
#   '-èu Varades\n(Maine-et-Loire). A-H\n'],
#  ['ARMAILLÉ (V‘* d’) [et V>*«* née de MARSAY]',
#   ' 3',
#   '\nboulevard de la Tour-Maubourg (vu*) — du\nTremblay',
#   ' K [P-L-M] Vandenesse (Nièvre)\n'],
#  ['— et à Loches (Indre-et-Loire). H-J-RR\n'],
#  ['Aiiman de Caillavet : voir de Caillavet.\n'],
#  ['ARMANCOLRT (C“ d’) [et G--* née de BEALRE-\nPAIRE de L0UVAGNY’]',
#   ' 63',
#   ' rue des Sts-Pères\n(vi»> — et 3',
#   ' rue des Vieux-Rapporteurs',
#   ' à Chartres.\n'],
#  ['ARMAND (G»*—) née de GONTALT-BIRON',
#   ' 49',
#   ' rue\nSaint-Dominique (vu*) [3*125.30]',
#   '\n'],
#  ['ARMAND (G1*)',
#   ' ancien Capitaine de Cavalerie [et\nC‘*”e née de BRANTES]',
#   ' 20',
#   ' rue Hamelin (xvi*)\n[Ut 693.20] — {êj d’Arcis-sur-Aube',
#   ' K [El\n'],
#  ['Arcis-sur-Aube (Aube) — et ^ d’Ailleville',
#   ' K f?=\nM [E] Bar-sur-Aube (Aube). A-AC-UA\n'],
#  ['ARMAND (C** Albert)',
#   ' (K [et C1*"* Marie ARMAND',
#   '\nnée BEl’F]',
#   ' 11',
#   ' rue Laid»',
#   ' à Marseille [ 7. 112]\n'],
#  ['(Réception vendredi) — de Toursainte',
#   ' à Mar¬\nseille — et La Torse',
#   ' à Aix (Bouches-du-Rhône).\n'],
#  ['E-ÜA\n'],
#  ['ARMAND (Edmond)',
#   ' 41',
#   ' rue Pierre-Charron — et\nSÊS d’Eperlecques) K St-Omer (Pas-de-Calais).\n'],
#  ['ARMAND (Maurice)', ' Lieutenant au 9* Cuirassiers', '\nmêmes adresses.\n'],
#  ['ARMAND (M. et M"* Auguste)', ' 48', ' avenue d’Iéna\n(xvi*) [Ti685.51)\n'],
#  ["ARMAND-DELILLE (T)' P.-F.) [et M”e née LATHAM]",
#   '\n20',
#   ' rue de Tilsitt (XVIIe).\n'],
#  ['ARMANDY {Le Général Cle) [et Cle“* E. dL 34',
#   ' rue\nde Bassano (vin*) — et {gj des Cinq-Cantons',
#   ' K\n[p=^l Carpenlras (Vaucluse) UA\n'],
#  ['ARMEZ (M. Louis)',
#   ' Ingénieur civil',
#   ' Député des Côles-\ndu-Nord [et M“* née Gl’ILLON]',
#   ' 25',
#   ' rue de Bour¬\ngogne (vne)—et jJj du Bourgblanc',
#   ' K Plourivo',
#   '\nëâ Paimpol (Côtes-du-Nord).\n'],
#  ['ARMSTRONG (Thomas de SAINT-GEORGES de)',
#   ' C.\nqopqoR',
#   ' Ancien député',
#   ' gentilhomme de la Cour\nde S. M. le Roi de Portugal [et M“* née de FARIA]',
#   '\n40',
#   ' avenue Kléber (xvie). H\n'],
#  ["Arnal (d') : voir de Serres (d’).\n"],
#  ['ARNAL',
#   ' née DAGLIN (M"* Albert)',
#   ' 53',
#   ' rue de Pon-\nthieu (vine)',
#   ' - et (S d’Auberive',
#   ' K\n(Haute-Marne).\n'],
#  ['ARNAUD (C',
#   'e Raoul d’) O. I. tzS',
#   ' C. K',
#   ' [et Cu”* liée\nMARTIN-DESLANDES]',
#   '44',
#   ' avenue Marceau(vm*l.\n'],
#  ['AG\n'],
#  ['ARNAUD de L’ARIÈGE (Joseph)',
#   ' 19',
#   ' quai du\n4-Septembre',
#   ' à boulogue-sur-Seiue.\n'],
#  ['ARNAUD JEANTI (M. et M“* Georges)', ' 14', ' avenue de\nMessine (vm*).\n'],
#  ['ARNAUD-JEANTI',
#   ' née LA CHAUSSÉE (M-* L.)',
#   ' 11',
#   '\nrue Arsène-lloussaye (vin*).\n'],
#  ['ARNAUD JEANTI (Yl. et M"* Gaston)',
#   ' 10',
#   ' rue Léonce\nReynaud (xvi*) — et à Carolles',
#   ' K Sartilly (Man¬\nche).\n'],
#  ["Arnex (d'| : voir de Rory J’Arnex.\n"],
#  ['ARNOULD (Dr) [et M— liée DUBARRY',
#   ' 24',
#   ' rue\nd’Assas (vi») [I 102.20]',
#   '\n'],
#  ["ARNOULD (Casimir-Victor) [et Mm* née de PERCY']",
#   '\n12',
#   ' avenue Victor-llugo (xvi*).\n'],
#  ['ARN\n'],
#  ['41\n'],
#  ['AST\n'],
#  ["ARXOl'LT • (Edmond)", ' 12', ' Villa Spontini (xvf)\n[35697.44].\n'],
#  ['ARNOULT (Léon)', ' 167', ' bon!. Malesherbes (xvtf); AG\n'],
#  ['ARNOUS (Mm" L.)',
#   ' née ANDRÉ de LA CHARENTE',
#   '\n8',
#   ' place dTéna (xvi°) — et de Montchaude',
#   ' K\nfi [Or] Rarbczieux (Charente) — et fl-jj de la\nBoulnie',
#   ' si Sancerre (Cher).\n'],
#  ['ARNOUX (C1* et C\'""» cl\')', '. 1', ' avenue Marceau (xvf)\n'],
#  ['17» 529.10].\n'],
#  ["Arnouville (d'j : voir Ciioppin (d').\n"],
#  ['AROSA (Achille)',
#   ' S',
#   ' avenue Victor-Hugo (xvf) — et\njgj de Martigny',
#   ' la \\y~ fi [0] Arques-la-Iiataille\n(Seine-Inférieure). AC\n'],
#  ['AROSA (Paul) [et M“" née ROOSEVELT]', ' 26', ' rue\nBrunei (xvif). AG\n'],
#  ['ARQUINVILLIERS (R°° d’) [et R°->- née de CASA-\nB1ÀNCA]',
#   ' 83',
#   ' avenue du ISois-de-Boulogne (xvt").\n[35683-46] — et ffo de la Carrière',
#   ' SI î?= 35 Saint-\nAvertin (Indre-et-Loire)',
#   ' fi [Or et Et] Tours.\n'],
#  ['Arroara (d’) : voir de Trabadklo.\n'],
#  ['ARROU (Dr Joseph)',
#   ' Chirurgien des Hôpitaux [et\nM“* née FÉLIX-VOISIN]',
#   ' 9',
#   ' rue Bayard (viir).\n'],
#  ['Ars (d’) : voir de Bréhond d’ARS.\n'],
#  ["ARSIGNY (C“ d’) [et <>•■• née d’AIGNAl'X]",
#   ' il',
#   ' rue\nFrançois-Ponsard (xvf) [if Im. 677.44]— et "g* de\nGlatigny',
#   ' s }f= Souday [4 k]',
#   ' fi Mondoubleau et\nle Plessis-Dorin (Loir-et-Cher).\n'],
#  ['Arsï (d’) : voir de Goiy d’ARCY.\n'],
#  ['ARTEMARE (M™ d’)',
#   ' née ROUSSEAU des MÉLO-\nTRIES',
#   ' 2',
#   ' square de La Tour Maubourg (vu*)— éêî\ndu Haut-Philaine',
#   ' [>2 fi Blois (Loir-et-Cher).\n'],
#  ['ARTEMARE (Henri d\') [et M\'"* née de BUZOXNIÈRE]', '\nmêmes adresses.\n'],
#  ['ARTEMARE (M. Pierre d’) [et Mm* née Yvonne DE-\nBROU]',
#   ' 2',
#   ' square de La Tour-Maubourg (vif)W\net même ^gj .\n'],
#  ['ARTENSAC',
#   ' née de LAMBERTERIE <C-°-° de CAL¬\nMEES d’)',
#   ' — jgj de Montvalcnt',
#   ' IS1 Martel\n(Lot)',
#   ' fi [Or]',
#   ' Montraient',
#   ' 2 ldi.\n'],
#  ['ARTHEZ-LASSALLE (Armand d’) [et Mm* née de\nRAYMOND de LALANDE]',
#   ' 11',
#   ' rue Boissière (xvt*)',
#   '\n'],
#  ['— et jà d’Aberats', ' El fi Saint-Palais\n'],
#  ['(Basses-Pyrénées). H-UA\n'],
#  ['ARTHUR-MERCIER',
#   ' Docteur en Médecine [et M1',
#   '10 née\nLAMY]',
#   ' 15',
#   ' avenue Mac-Mahon (xvir) [35 582.16].\n'],
#  ['ARTHUY’S (B°” d’) [et B”*** née Denise TA VEAU de\nLAYIGERIE]',
#   ' 30',
#   ' rue de Saint-Pétersbourg (vin*)\n'],
#  ['— et jgj de St-Étienne', ' KJ St-Servan fi\nSt-Malo (Ille-et-Vilaine).\n'],
#  ['ARTICLE (J.-Bertrand)',
#   ' 62',
#   ' avenue du Bois de\nBoulogne (xvt") — et jgz d’Hautelort (Dordogne).\n'],
#  ['AC-CF\n'],
#  ['ARTOIS (Vu Edmond d) [et Vl*”* nee PUMJLES\nd’HERBINGHEM]',
#   ' 84',
#   ' rue d’Amsterdam <ix°).\n'],
#  ['ARTOIS de BOURXONVILLE (Armand d’)',
#   ' O. I. y',
#   '\nHomme de lettres',
#   ' conservateur à la bibliothèque\nMazarine [et M“» née Jeanne-Marie HERVET]',
#   ' 23',
#   '\nquai Conti (Datais de l’Institut) (vi*) — et ifo la\nMozuticre Varennes-Jarcy',
#   ' ISJ Mandres (Seine et\nOise) hr: fi [P-L-M] Combs la-Ville.\n'],
#  ["ARTl'S (Louis) [et M“” née PIAT]",
#   ' 105',
#   ' boulevard\nHaussmann (vin").\n'],
#  ['ARVENGAS (René)',
#   ' Chef tfEscadron (l’Artillerie\n[et Mme née Louise MASSIAS]',
#   ' 14 bis',
#   ' rue Jadin\n(xvii*) — et (£j de la Iloussaye',
#   ' Kl 1900“]\nMarcilly-en-Villelte',
#   '" fi La Fcrtê-Saint-Aubin\n(Loiret). TJA\n'],
#  ['ASSAILLY (Cl*“" Octave d’) née CUNIN-GR1DAINE',
#   '\n10',
#   ' rue de Marignan (vin*) — et de la Sal-\nmondière',
#   ' K Niort',
#   ' dist. 9 kil.',
#   ' fi halte d’Ar\n'],
#  ['thenay (Deux-Sèvres).\n'],
#  ['ASSAILLY (C1"" A. d’)',
#   ' née MALLET',
#   ' 27',
#   ' rue\nCambacérès (vin*) — et même (g) .\n'],
#  ['ASSAILLY . Y*»"* Arthur née OLIVIER des BOR¬\nDEAUX',
#   ' à Pont-de-PArche (Eure).\n'],
#  ['ASSAS (M“ d’) [et M"\' née de CAMItRAY]',
#   ' 103',
#   ' rue\nLa Boétie (vin") [35 521.57] — et xgz d\'Ortiés',
#   ' ESI\njÿ= 35fiSalbris (Loir-et-Cher) — et de Castel¬\nnau',
#   ' K Nant (Aveyron).\n'],
#  ['ASSAY (C1""* Léonce d’)',
# ...
#   ' 4 kil. (Somme).\nBEAUMOYT (C‘* Pierre de)',
#   ' Capitaine au 20“ Chas¬\nseurs (à Vendôme) [et C’*"* née Yolande de GOU\nLAIYE]',
#   ' 60',
#   ' rue de Y’arenne (vu*) — même A - J\nBEAUMOYT (C“ Cari de)',
#   " ancien Officier de Cavalerie\n[et C'”“* née de BOLSGELIY]",
#   ' 11',
#   ' rue Massera',
#   '! (vu*)\n— et de la Brosse',
#   ' K [Or et Et] Chàteau-\nrenault (Indre-et-Loire)',
#   ' TP. Saint-Laurent-en-\nGatines',
#   ' 2 kil. H-J\n'],
#  ['BEAUMOYT (O Etienne) [et G. née de TAISYE]', '\n'],
#  ['198', ' boulevard Saint-Germain (vu*) et mêmes\nadresses.\n'],
#  ['BEAUMOYT (C** René de) [et (>•■’ née de TRÉVE-\nNEUC]',
#   ' 27',
#   ' rue de Bassano (vin*) — de Pla-\nçamen',
#   ' K [î= Moelan (Finistère)',
#   ' M [0] Quim-\nperlé —et Y’ilia des Terrasses',
#   ' à Hennebont (Mor¬\nbihan). H-J\n'],
#  ['BEAUMOYT (C‘* de). Officier de Cavalerie',
#   ' [et C\'*"*\nnée Juliettede TREDF.RY]',
#   ' 3',
#   'rue du Général-Appert\n(XVI*) [I. 547.431 . AC-J-RR\n'],
#  ['BEAUMOYT (V1* Frédéric de)',
#   ' Ministre plénipoten¬\ntiaire',
#   ' 0. K [et Y»\'" née LE LASSELR]',
#   ' et\nTAuberderie',
#   ' K M [O] l’Étang-la-Yille (Seine-et-\nOise)',
#   ' Marly-le-Roi. J\n'],
#  ['BEAUMOYT',
#   ' née FRION d’HY’EYCOURT (C-- Er¬\nnest de)',
#   ' 134',
#   ' rue de Grenelle (vu*).\n'],
#  ['BEA\n'],
#  ['84\n'],
#  ['BEA\n'],
#  ['BEAUMONT (G*» Charles de) [et 0---° née de MA¬\nLET]',
#   ' 134',
#   ' rue de Grenelle (vil*) (p.-à-t.) — et\nde Chàtigny',
#   ' 121 f?= Fondettes (Indre-et-Loire)',
#   '\néS [Or] Tours et Fondettes-St-Cyr.\n'],
#  ['BEAUMONT (C1* Maxime de)',
#   ' Lieutenant au 14’ Chas¬\nseurs',
#   ' Si du Plessis',
#   ' 12 jÿ= [Or et Et] Noyant\n(Maine-et-Loire).\n'],
#  ['BEAUMONT (G1* Iules de) [et C1»”” née de LA J AILLE]',
#   '\n97',
#   ' rue du Bac (vu*) (p.-à-t.) — {Jj de \\iantais',
#   ' 2\n{£=',
#   ' Kémalard éB [0] Regmalard (Ortie).\nBEAUMONT (Cl* Charlès de)',
#   ' Capitaine breveté\nd’État-Major',
#   ' Officier d\'ordonnance du Général\ncommandant le corps d’armée d’Algérie [et C1\'*"\nnée Alice de I’AILL0T]',
#   '98',
#   'rue de Miromesnil (vin*)\n— et {£9 du Sart',
#   ' 2 Yersigny (Aisne)',
#   ' ]ÿ= Nou-\nvion-le-Comte.\n'],
#  ['BEAUMONT (G1* Christian de)',
#   ' 7',
#   ' rue de Bourgogne\n(vu*) — et {Ja du Plessis',
#   ' 2 Noyant (Maine-et-\nLoire).\n'],
#  ["BEAUMONT (M“ Amblard de) [et M1** née de BRY\nd’ARCY']",
#   ' 8',
#   ' cité Yaneau (p.-à-t.) (vu») — et {Jj de\nLa Bénatonnière',
#   ' 2 ^ Talmont (Vendée)',
#   ' éS\n[Or] La Mutte-Achard.\n'],
#  ['BEAUMONT (C1* et G\'"" de)',
#   ' 78',
#   ' av. de Milliers (xvir).\nBEAUMONT (C“ Hugues de) [et Cu“* née Louise\nMARCHESNE]',
#   ' 19',
#   ' avenue de Tourville (vu*). AL\nBEAUMONT (Gaston du BOSCQ de) [et M"* née CHE¬\nVALIER]',
#   ' 13',
#   ' rue Greuze (xvt»> — et duMesnil-\nYitey',
#   ' 121 ÎF tE [Ou]',
#   ' Airel (Manche).\nBEAUMONT (M. et Mm» Émile)',
#   ' 67',
#   ' avenue des Champs-\nElysées (vin*) [7* 317.31].\n'],
#  ['BEAUMONT (Gaston)', ' même adresse.\n'],
#  ['Beaumont (de.) : voir aussi u’Autichaup.\n'],
#  ['Beaumont (de) : voir aussi Eue de Beaumont',
#   "\nBEAUPRE (O de) [et O--* née d'UBEKEM d’ACOZ]",
#   '\n3',
#   ' rue Freycinet (xvi*) — 49',
#   ' rue Haute',
#   ' Gand (Bel¬\ngique) et O de Bette',
#   'n',
#   ' 2 M [NJ Bettem\n(Belgique).\n'],
#  ['BEAUPRÉ (Y** de) Conseiller référendaire à la Cour\ndes comptes [et Vu“* née de RE1SET]',
#   ' 3',
#   ' rue de\nFreycinet (xvi*). H-UA\n'],
#  ['BEAUPRE (G** Louis)',
#   ' 20',
#   ' rue de la Bienfaisance',
#   '\n(vin*)—et iJÊs de Saint-Urbain',
#   ' 2 Rosières-aux-\nSalines (Meurthe-et-Moselle).\n'],
#  ['BEAUPREAU <G>-- REDON de)',
#   ' née BORDIER du\nBIGNON',
#   ' 17',
#   ' rue Marbeuf (vm‘| — et A de\nRive-du-Bois 2 éS Neuville-au-Bois (Loiret).\nBEAUPREAU (MUo REDON de)',
#   ' mêmes adresses.\nBeaupuy de Génis : voir de Génis.\n'],
#  ['BEAURECUEIL (Cl* et Cl*“* de)', ' 48', ' rue de Yarenne\n'],
#  ['(VH*).\n'],
#  ['BEAUREGARD (G\'* Charles DURAND de) [et C1*"*\nnée de MORAC1N]',
#   ' 56',
#   ' boulevard Haussmaim\n(ix*). UA\n'],
#  ['BEAUREGARD (Henri de)',
#   ' Député des Deux-Sèvres\n[et M" née de SALVAING de B01SS1EU|',
#   ' 27',
#   '\navenue Bosquet (vu*) — et jgj de la Pastellière',
#   '\nSI &= èS [Et] Cerizay (Deux-Sèvres). H\n'],
#  ['BEAUREGARD (Gabriel de) [et M"\' née de PUY"\nN ODE]',
#   ' 23',
#   ' avenue Rapp (vu») — et {£5 de Uhà-\ntenay',
#   " K [p g [Et] La Châtaigneraie (Vendée).\nBeachegabu (de): voir aussi Costa de Beauregard.\nBEAUREPAIRE (G1* de) [et G--- née d'OFFHMONT]",
#   '\nl',
#   'rue Lincoln (vin*) —et 1',
#   ' rue des Écuyers',
#   'à Saint-\nGermain-en-Laye (Seine-et-Oise). AC-H\n'],
#  ['BEAUREPAIRE (Yu de) [et V>nce Marguerite de\nBAR]', ' mêmes adresses. J\n'],
#  ['BEAUREPAIRE (V1* de) [et Yl“” née ESP1VENT de\nLA YILLESBOISNET]',
#   ' 11',
#   ' rue St-Hilaire',
#   ' à Poitiers\n— et (SÊs ào l’Ermitière',
#   ' 2 fei [Et] Machecoul\n(Loire-Iuf.)\n'],
#  ['BEAUREPAIRE de LOUVAGNY (C1* de)',
#   ' Chef d\'esca¬\ndrons au 2» Dragons [et C1*"* née de LESP1NASSE\nde BOURNAZELJ',
#   ' 94',
#   ' boulevard de La Tour-Mau-\nbourg (vu*) — et {g} de Mondespie',
#   ' 2 Tt\nSt-Philippe-d’Aiguilhe (Gironde) gg [Or] Gastillon.\nBEAUREPAIRE de LOUVAGNY (G** Joseph de) [et\nC1*1** née de LA CELLE]',
#   ' 5',
#   ' rue du Pré-aux-CIercs\n(vu») — et de Lalande',
#   ' 2 Toucy (Yonne) jÿ=\nLeugny.\n'],
#  ['BEAUREPAIRE de LOUVAGNY (V‘* de) [et Y-" née\nde GRANDMAISON]',
#   ' 55',
#   ' rue de Prony (xvir) — et\nflà de Quesnay-Guesnon',
#   ' 2 Italleroy',
#   ' Jj= Longraye',
#   '\n6 kil.',
#   ' £g [Ou] Bayeux (Calvados).\n'],
#  ['BEAUSSANT (Ernest)',
#   ' ancien Préfet [et M"e]',
#   ' 13',
#   ' rue\nd’Alger (t»r) — et 14',
#   ' rue Gargoullaud',
#   ' à La Ro¬\nchelle. UA\n'],
#  ['BEAUSSIER (Cts de)',
#   ' 75',
#   ' rue de Chaillot — et Villa\nLadislas',
#   ' à Hyères (Yar). Sp\n'],
#  ['BEAUSSIER',
#   ' née de MARRAIS (V1*”» de)',
#   ' 104',
#   ' rue\ndu Bac (vit*)— et A de Caratel',
#   ' 2 Châ-\nteaubriant (Loire-Inférieure)',
#   ' gg [Or] Louisfert.\nBeauvais (de) : voir de Lesterps de Beauvais.\nBEAUVAIS (Augustin de)',
#   ' Auditeur à la Cour des\nComptes',
#   ' 5',
#   ' boulevard ltaspail (vu*). UA\n'],
#  ['BEAUVAIS (Joseph de) [et M"° nce du GARÉ de\nTOUILLE]', '\n'],
#  ['BEAUVAL (CLARION de)',
#   ' Directeur de la Banque\nde France',
#   ' 79',
#   ' boulevard de Clichy (ix*).\nBEAUVAL',
#   ' née de GONTAUT-BIRON (P-*- de)',
#   ' 25',
#   '\nrue Georges Bizet (xvi”) — et £5 de Sainte-Assise',
#   '\n2 Seine-Port (Seiue-et-Marue)',
#   ' M [P-L-M]\nCesson.\n'],
#  ['BEAUYAU iP°» de)', ' mêmes adresses. J-U\n'],
#  ['BEAUYERGER',
#   ' née de SAINT-JOSEPH (B*-* de)',
#   '\n153',
#   ' bout. Haussmaim (vin”) — et A de La Mar-\nsaudière',
#   ' 2 Chevry-Cossigny (Seine-et-Marne)',
#   '\néS [E] Gretz-Armainvilliers.\n'],
#  ['BEAUYERGER (B°» de) [et B»””» née CLAUY]',
#   ' 133',
#   "\nboulevard Haussmaim (vni*) — et même *7* . H\nBEAUVILAIN (Albert) [et M”* née GABRl'YA|",
#   '\n145',
#   ' rue de la Pompe (xvi*).\n'],
#  ['BEAUY1ULÉ (M. de)', ' âe Dromesnil', ' 2 Hornoy\n(Somme). A\n'],
#  ['BEAUV1SAGE (Maxime de)', ' 145', ' avenue de Milliers\n< vu»). SH\n'],
#  ['BEA\n'],
#  ['55\n'],
#  ['BEJ\n'],
#  ['BEAUVOIR (M" de)',
#   ' 0. * [et M” née de LOWEN-\nTHAL]',
#   ' 18',
#   ' rue Caumartin (ix") — et j-ju de San-\ndricourt',
#   ' 1SI â [N] Méru (Oise) [y- Sandricourt.\n'],
#  ['B-J-T\n'],
#  ['BEAUVOIR (O" Henri de)',
#   ' Officier de Cavalerie-',
#   ' à\nNoyon [et (>•*• née LE VERDIER]',
#   ' 29',
#   ' rue Saint-\nEloy à Noyon [75 n* 10]',
#   ' H-J\n'],
#  ['BEAUYOIS-DEYAUX (André) [et M""1 née des CHA¬\nPELLES]',
#   ' 78',
#   ' avenue Henri-Martin (xvf) [75\n693.60]',
#   ' AG\n'],
#  ['BÉCAYS-LACAUSSADE (Albert de) [et M”’ née\nJOLY de BAMMEVILLE]',
#   ' 19',
#   ' rue François l"\n(vin») — et JÊ5 de Lacaussade',
#   ' E3 Montflanquin\n(Lot-et-Garoniiej. H\n'],
#  ['BECCI (C** Gabriel)',
#   ' Avocat à la Cour',
#   " Lieutenant\nde réserve [et C*'”” née Henriette de BOISLAU-\nREN'T]",
#   ' 86',
#   ' rue de Varenne (vu1) [75 706.60] —\net Éfia de St-Germain',
#   ' K ]ÿ= ë8 Lisieux',
#   ' et 25',
#   '\nrue des Chanoines',
#   ' à Bayeux (Calvados). AC CM\nBECDEL1ÈYRE (C‘" Edmond de) [et C1""* née\nd’IN\'DY]',
#   ' 18',
#   ' avenue de La Bourdonnais (vu*) —\n{gj du Brossay',
#   ' [SI [O] Guéméné-Penfao',
#   '\n'],
#  ['6 kil. (Loire-Inférieure) — et villa « Les Fau¬\nvettes » à la Baule-sur-Mer (Loire-Inférieure).\nBÉCHET (M— Emile) [née RAIMBERT]',
#   ' 3',
#   ' rue de\nMarignan (vin») — et jg) de Bois-Bertrand',
#   ' [33 |s=\n^g|0r et Et] Chàteaudun',
#   ' 7 kil. (Eure-et-Loir).\nBÉCHET (Roger) [et Mm» née de WARENGH1EN]',
#   '\n6',
#   " rue Edmond Valentin (vif) — et même îêS ■ RR\nBECHET (Gaston) [et M—' née ROYER]",
#   ' 75',
#   ' avenue\ndes Champs-Elysées (viif) — et ^ de Changy-\n'],
#  ['les-Bois', ' SI T5 Varennes', ' 3 kil. (Loiret) à\n'],
#  ['[P-L-MJ Nogent-sur-Yernisson. H-UA\n'],
#  ['BÉCHET', ' née CHARDON (M— C.)', ' 87', ' rue St-Lazare\n'],
#  ["(IX').\n"],
#  ['BÉCHET (M.et M“* Léon)',
#   ' 87',
#   ' rue Saint-Lazare (ix»)\n[J* 313-43]',
#   ' E\n'],
#  ['BÉCHET (Paul) [et M— née BOL8801) de LACÉ\nPÉDE]',
#   ' 95',
#   ' avenue Victor-Hugo (xvi«).\nliEl 11111 ANN (Alfred) [et M”’ née RA YNAL]',
#   ' 19',
#   " rue\nd'Aumale (ix°).\n"],
#  ['BECHMANN (Georges)',
#   ' Ingénieur en Chef des Ponts\net Chaussées',
#   ' O. S [et M"\']',
#   ' 68',
#   ' rue Pierre Char¬\nron (vnf) [3s 676.07] —et villa «. Les Pelouses >>\nà Saint-Cloud-Montretout (Seine-et-Oise).\n'],
#  ['BECKER (G.)',
#   ' 38',
#   ' rue Chardon-Lagache (xvf). UA\nBecq de Fouquières : voir de Fouqüiéres.\nBECQUART (Emile) [et M-°° née Laure PETIT]',
#   ' 3',
#   '\nrue La Pérouse (xvf) [7-519.58] — et pavillon de\nSaint-Pierre. Kl [ÿ= üS (N) Vieux-Moulin (Oise).\n'],
#  ['UA\n'],
#  ['BECQUEREL (Henri)',
#   " Membre de l'Institut",
#   ' C. K\n[et II”-née LORlÉUX]',
#   ' 6',
#   ' rue Dumont-d’Urville\n(xvf) — et à Chàtillon-sur-Loing (Loiret).\nBECQUEY-BEAUPRÉ (Col.)',
#   ' O. *',
#   ' 19',
#   'rue Raru (vm).\nBECQUINCOIRT',
#   ' née LE SUR de RIBEMONT (Me-\nAlexandre de)',
#   ' II',
#   ' rue Tronchet (vnf) — et A de\nNeslc',
#   ' K ]ÿ= Ncsle (Somme).\n'],
#  ['BÉDOILE (M"10 E.) [née GUYET]',
#   ' 46',
#   ' avenue dn Bois-\nde-Boulogne (xvfj [75 520.11] — et de\nJuziers-le-Bourg',
#   ' K ](p ^ [0] Juziers (Seine-\net-Oise).\n'],
#  ['BEER (Jules)',
#   ' 34',
#   ' rue des Mathurins (vnf) — et M\nde Voisins',
#   ' K Louveciennes (Seine-et-Oise). UA\nREER (Guillaume) [et M” née GOLDSCHMIDT]',
#   '\nmêmes adresses [71312.97] AC\n'],
#  ['BEER (Edmond) [et Mm" née KOHN]',
#   ' 68',
#   ' avenue d’Iéua\n(xvf) [7- 510.38] — et même à . AC-H\n'],
#  ['BEGE',
#   ' née ADELINE (M”*)',
#   ' g-j de la Borde',
#   ' K\nCour-Cheverny (Loir-et-Cher).\n'],
#  ['BEGÉ (Maurice) [et M”* née HALNGUERLOT]', ' même\n(&.. J\n'],
#  ['BEGÉ (Raymond)', ' ggj d’Herbault', ' K Bracieux\niLoir-et-Cher). J-Sp\n'],
#  ['BEGÉ jjEdgard)', ' de Villeneuve', ' K Vernon\n(Loir-et-Cher). J\n'],
#  ['BEGON de LA ROUZIÈRE (C1* et C>-- Gaston de)',
#   '\n11',
#   ' rue Legendre (xvif). H\n'],
#  ['BEGOUEN (C""\')',
#   ' née de CHOLET',
#   ' 19',
#   ' rue d’Avron\nà Fontainebleau (Seine-et-Marne).\nBÉGUIN-BILLECOQ (Louis)',
#   ' Attaché au Ministère des\naffaires étrangères [et M" née Clotilde MILLON\ndo MONHERLANT]',
#   ' 43',
#   ' rue de Boulainvilliers (xvf)\n— et « La Treille » à Nemours (Seine-et-Marne).\nRÉGULE iL.) [et M” née de CLA1RVAL]',
#   ' 10',
#   ' ave¬\nnue de Villars (vif) — villa Henriette à Ste-Luee',
#   '\nK jÿ= â![Or] (Loire-Infér.) — et villa Plaisance',
#   '\nà la Chapelle-Saint-Mesmier',
#   ' K [Or](Loiret).\n'],
#  ["BÉH1ER (M. et Mm' A.)",
#   ' 43',
#   ' rue dn Colisée (vnf). H\nREHR (B“)',
#   ' 26',
#   ' rue d’Artois (vnf).\n'],
#  ['BEHRENDT (M. et M"° Max)',
#   ' 35',
#   ' avenue Kléber\n(xvf) [75698.24]',
#   " ' AC\n"],
#  ['BEHRENS (Walter)',
#   ' Yice-présidenl de la Chambre\nde commerce britannique a Paris [et M” née\nBEDDINGTON]',
#   ' 121',
#   ' avenue des Champs-Elysées\n(vuf) [75536.26]. B-H\n'],
#  ['BEIGISEDER (David) [et M” née COSTE]',
#   ' 123',
#   ' ave¬\nnue de Villiers (xvif) [75552.64].\n'],
#  ['BEISTEGLT (M»° C. B. de)',
#   ' liée RENIIEZ',
#   ' 136',
#   ' ave¬\nnue des Champs-Elysées [vnf) [75521.96]',
#   '\nBEISTEGUI (Charles de)',
#   ' 37',
#   " avenue d’Iéna (xvf).\nBEISTEGLT (Juan-A. de). Envoyé Extraordinaire et\nMinistre Plénipotentiaire du Mexique; auprès de\nS.-M. le Roi d'Espagne [et M” née DOLORÈS de\nYTURBE]",
#   ' 87',
#   ' avenue d’iéna (xvf) [75 520.90).\n'],
#  ['AC-B-RR-UA\n'],
#  ['BÉJARRY (G“ Amédée de)',
#   ' de',
#   ' Sénateur [et C*”* née\nElisabeth de SA1NT-FERRIOL]',
#   ' 56',
#   ' rue Notre-\nDame-des-Champs (p. à-t.) (vf) —et de Roche-\nLouherie',
#   " r-' |p 1.a Réorthe",
#   ' 6 kil. (Vendée)\n[Et] Bourne™nu\n'],
#  ['BÉJARRY (Cu Armand de) [et C"*” née HËLL-\nMAN]',
#   ' 17',
#   ' rue de Matignon (vnf) (p.-à-t.) —et\nde Candes',
#   ' K [p Moutsoreau (Maine-et-Loire)',
#   '\nëi [Or] Saumur.\n'],
#  ['BEJOT (M”” Paul)',
#   ' 53',
#   ' rue de Monceau (vnf) [75\n535.15]',
#   ' — et de Nointel 75 K fe=Presles',
#   ' 1 kil.\n(Scine-et-Oise)',
#   ' gg (N] Nointel.\n'],
#  ['BEJ\n'],
#  ['56\n'],
#  ['BEL\n'],
#  ['BËJOT (Jacques) [et M“” née BEDOILE]',
#   ' 30',
#   ' avenue\nde Messine (vm”) [35 303.64] — et même M.\n'],
#  ['B-UA\n'],
#  ['BÉJOT (Henri Jules)',
#   ' Agent de change [et M”” née\nVERDÉ-DELISLE]',
#   ' 28',
#   ' rue Beaujon (vin”) | J5543.76|\n— et Domaine de Nointel',
#   ' ES Presles (Seine-et-\nOise). B-H-UA\n'],
#  ['BÉJOT (Georges)',
#   ' #',
#   ' 36',
#   ' av. des Champs-Elysées\n(vin”) — et {fis de Millemont',
#   ' El La Quene-des-\nIvelines (S.-et-Oise). UA\n'],
#  ['BÉJOT (Edmond)',
#   " Conseiller général des Vosges [et\nMm” née d’HAl'DIGOLRT de TAKTIGNYj",
#   ' 7',
#   ' rue\nMontaigne (vin”) •— et de Mortagne',
#   ' K ÏF=\nBrouvelienres iVosges)',
#   ' |E] Bruyères.\n'],
#  ['B-H-RR-UA\n'],
#  ['BËJOT (Paul)',
#   ' Capitaine au 72‘ tfInfanterie —\n27',
#   ' rue Saint-Louis',
#   ' Amiens. Y\n'],
#  ["BEL 'J.-.M.!",
#   ' Ancien élève',
#   ' de t Ecole Polytechnique',
#   '\nIngénieur civil des Mines',
#   ' Explorateur',
#   ' expert\nprès le Conseil de Préfecture [et M"”]',
#   ' 73',
#   ' boni.\nSaint-Michel (v”) et 11 bis',
#   ' rue de l’Hôtel de Ville\nà Antibes (Alpes-Maritimes).\n'],
#  ['BELABRE (M“* de)',
#   ' 1',
#   ' rue Pierre-Charron (xvi*) —\n& de Belabre',
#   ' E ]£= Belabre (Indre) — et\nde Contremoret',
#   " E j£= Saint-Martin-d'Auxigny\n(Cher)",
#   ' âl [Or] Bourges.\n'],
#  ['BELCASTEL (B”“ de) [et B”™* née de SAINT-JO¬\nSEPH]',
#   ' 7',
#   ' square La TourMaubourg (vil”) — et\nde Belcastel [35 au {^]',
#   ' E Lavaur (Tarn)',
#   '\nÊg [M] Lavaur et Saint-Sulpice-la-Pointe. J\n'],
#  ['Beliioir (de) : voir Toixhois de Bf.luoih.\n'],
#  ['BELIN (M. etMm*)', '38', ' rue de Berri (vin”).\n'],
#  ['BEL1NAY (B“ de BONAFOS ’ de) [et B””— née de\nWOLlîOCK]',
#   ' 13',
#   ' rue de Siam (xvi”) — et A du\nPlessix',
#   ' E Guinguen',
#   ' â Guichen-bourg-des-\nComptes (Ille-et-Vilaine). AC\n'],
#  ['BEL1ZAL (V“ de) [e^ Vl””« d’ASSAY]',
#   ' 21',
#   ' avenue\nde Tourville (vit”).\n'],
#  ['BELLAIGLE (A.)', ' tK', ' 11', ' rue Saint-Guillaume (vu”).\n'],
#  ['BELLAIGLE (Camille)',
#   ' A [et M”” née HOSKIER]',
#   '\n47',
#   ' rue de Bellechasse yii-0\n'],
#  ['BELLAIGLE (A. de) [et M- née Dl FOLRNEL]',
#   ' 1',
#   ' rue\nde Narbonne (vu”) et 17',
#   ' quai Villeneuve à Gray\n(Haute-Saône).\n'],
#  ['BELLAIGLE (M J. de)', ' mêmes adresses.\n'],
#  ['BELLAIGLE de BECHAS',
#   " née de BEAUCHESNE\n(Cl'‘””S. de)",
#   ' villa Sédaiges',
#   'à.Montmorency (Seine-\nct-Oise).\n'],
#  ['BELLAIGLE de BUGIIAS (Y*’ Félix de)',
#   ' Capitaine\nbreveté d\'Etat-major [et V1"”* née GALLTIER de\nLANGUE]',
#   ' 50',
#   ' avenue Bosquet (vu”).\n'],
#  ['BELLAIGLE de BECHAS (V- Henri de) [et V-»\nnée BERÇASSE]',
#   ' 43',
#   ' rue de Lille (vu”).\n'],
#  ['BELLANGEK',
#   ' née MESLAY (M"1” Ernest)',
#   ' 4',
#   ' rue St-\nFlorentin (i*r) — et de Rrul’Avoine',
#   ' C-7\n|0] Chàteau-Goutier (Mayenne).\n'],
#  ['BELLANGEK (Louis)', ' mêmes adresses.\n'],
#  ['Bellanoer (de) : voir Fressinet do B.\n'],
#  ['BELLE (Gaston)',
#   ' O.#',
#   ' Ministre plénipotentiaire',
#   ' [et\nM“” née PAIXHANS]',
#   ' 27',
#   ' avenue Rapp (vit’l— et\n(ÊS de Uozières',
#   ' E3 Îî= Septinonts (Aisne)',
#   ' M |N]\nBerzy-le-Sec. DA\n'],
#  ['BELLE (Henri)',
#   ' 0. èfc',
#   ' Ministre plénipotentiaire.\nBELLE (Stéphane)',
#   ' 13',
#   ' rue Yaneau (vil”).\n'],
#  ...]

# %%
# Keep only names and addresses:
names = []
addresses = []
for people in all_people:
    if(len(people) > 1):
        names.append(people[0])
        addresses.append(getAddress(people))

df_people = pd.DataFrame({"name": names, "address": addresses})

# %%
df_people
# Out:
#                                                     name  \
# 0                    ABRADIE-d’ARRAST (Michel-Robert d’)
# 1                                              ABBATUCCI
# 2                                      ABBATUCCI (C1""*)
# 3                                     ABOILARI) Georges)
# 4      ABOVILLE (B** Christian d’) [et B*»”" née I1EN...
# ...                                                  ...
# 11097           ZOGHEB (OGeorges de) [et C-- née SINANO]
# 11098                        ZOGRAPHOS (M. et M"“ Solon)
# 11099                               Z0L0T0VITZ (Lubomir)
# 11100  ZUYLEN de NYEVELT (R-- Étienne de) [et B*“* né...
# 11101  ZYLOF de STEENBOURG (J.) [et M- née d’H ALLO Y...
#
#                             address
# 0              5S bis rue Jouffroy
# 1                103 rue La Boétie
# 2                32 rue Washington
# 3            46 avenue de Breteuil
# 4               23 rue de Grenelle
# ...                             ...
# 11097                 8 rue Alboni
# 11098             30 avenue Kléber
# 11099          103 boul. Haussmann
# 11100   70 av. du Bois-de-Boulogne
# 11101              9 rue de Sontay
#
# [11102 rows x 2 columns]

# %%
unknown = df_people[[x == "unknown" for x in df_people["address"] ]]
print("Missing addresses: " + str(len(unknown)/len(df)))
# Out:
# Missing addresses: 0.25209336791404224

# %% [markdown]
# # First try:

# %%
# Merging people information and removing empty lines
buffer = ""
all_people = []
for line in raw_data:
    if(line == '\n'):
        if(len(buffer) > 0):
            all_people.append(buffer)
            buffer = ""
    elif(starts_with_family_name(line)):
        if(len(buffer) > 0):
            all_people.append(buffer)
        buffer = line
    else:
        buffer += line
all_people
# Out:
# ['A\n',
#  "Aage (cl’) voir Colmet (I'Aage.\n",
#  'ABRADIE-d’ARRAST (Michel-Robert d’), 5S bis, rue\nJouffroy (xvu*) — et d’Elhorriaga, S Saint-\nJcan-de-Luz (Basses-Pyrénées).\n',
#  "ABBATUCCI, née de FORESTA (M-), 103, rue La\nBoétie (vin*) [35 321.S7] — et fljj Rey de Foresta, SI\n[s ' â [A] Montmorency (Seine-et-Oise).\n",
#  'ABBATUCCI (C“ Jacques), 103, rue La Boétie (mi‘)\n[35 521.57] — et même A . Sp-RR\n',
#  'ABBATUCCI (C1""*), 32, rue Washington (vni\'j.\n',
#  'ABEILLE (Adolphe),27, Faubourg-Saint-Honoré (vm*)\net haras de Viroflay, CK! feâ Virollay [35 3)\n',
#  '(Seine-et-Oise). RR-UA-T\n',
#  'ABOILARI) Georges), U. #,[et M“" née BONUS], 46,\navenue de Breteuil (vu*) [35 707.11] — et de\nPeyrieu, Kl \\p= eS Peyrieu (Ain). AC-M-YC\n',
#  "ABOVILLE (V‘* H. d’), O.iK, Colonel du 131' de ligne\nà Orléans [et V*,“‘ née de GOUVELLO de KÉ-\nRIAVAL], à d® Kerentré, K {s= aË [0] Auray\n(Morbihan) — et de Rouville, K à\n[P.L.M.] Malesherbes (Loiret).\n",
#  'Paris-Mondain — 1908\n',
#  'ABOVILLE (B** Christian d’) [et B*»”" née I1ENNE-\nCART], 23, rue de Grenelle (vu*)— et A deGlux,\nK Chàteau-Chinon fs= St-Prix-sous-Beuvray, 1 kil.\n(Nièvre), Etang, 22 kil. (Saône-et-Loire) ou gg.\n',
#  'de E’achin-le-Chàtelet, 10 kil. — et ^ de Brouay,\nK ]ÿ= Audrieu (Calvados).\n',
#  'Alt RA Ml (II* Henri) [et M«« née KNITTEL], 28, rue\nCopernic (xvi*), 35 667.01.\n',
#  "ABRANTÈS, née JL'XOT (LE RAY, v--° d’), 12, ave-\nnue Henri-Martin (xvi*) — et sêâ de Bailleul, K)\nGorron (Mayenne), ^ [O] St-Denis-de-Gastines.\n",
#  "ABRANTÈS (Duc d’), Capitaine d'infanterie hors\ncadres, à F État-major du Gouverneur de Xicer\n[et !)**• nee Nicole, de MAIGRET], 12, avenue Henri-\nMartin (xvi*) —- même de Bailleul — et villa\n",
#  '“ Myosotis " Vallon des Fleurs à Nice.\n',
#  'ABRANTÈS (M** d’}, Lieutenant au 14e hussards à\nAlençon (et Mi,# née Hélène LANGSDORFF], 12,\navenue Henri-Martin (xvi*) — et même M.\n',
#  "ABRANTÈS (Cte d’}, Lieutenant au îS6* d'infanterie\nà St-Lô (Manche), mêmes adresses.\n",
#  '3\n',
#  'ABZ\n',
#  '34\n',
#  'A GH\n',
#  'ABZAC (C1""* Paul d’), 181, rue de La Pompe (xvi*).\n',
#  'fACHER de MONTGASCON ll!°» d’) [et B”""\' née Jeanne\nde COURCY], 18, avenue d’Antin (vui"),— et ià\nde Villequier, E M [Q], Caudebec-en-Caux (Seine-\nInférieure) Villequier.\n',
#  "ACHERY de SAS DON'N'IN'O (P“ d’), Ex-camérier\nsecret, 62, avenue de la Grande-Armée (xvn‘) — et\nde Soisy-sous-Montmorency, 121 35 *3 [N]\n",
#  'Soisy-sous-Montmorency (Seine-et-Oise).\n',
#  "ACHON (B°n René d'), Capitaine au l*r chasseurs [et\nB'*” née de LAMOLÈRE, Cu”* d'HUST], 124, rue\nde Provence (vm*), — et de la Roche-de-\nGennes, El Gennes (Maine-et-Loire), M [Or],\n",
#  'Les Rosiers-sur-Loire.\n',
#  'AGLOQLE (Mm*) née DU CH AN O Y\', 26, avenue Mar¬\nceau (xvi" )— et jÎ5 de La Borde, E Saint-An-\ntoiue-du-Rocher, (35 au £•£ .N” S), M Mettray\n(Indre-et-Loire).\n',
#  "ACLOQL'E (M»« AWnée SEBERT, 9, place des Etats-\nUnis (xvi*)-[35 698.92].\n",
#  "ACI.OQl'E (Maurice), 19, rue de Presbourg (xvi') — et\nvilla Monténégro [35 590], à Cannes (Alpes-Mari¬\ntimes). AC-Y\n",
#  'ACOLLÀS (René), K, Conseillerréférendaire à la Cour\ndes Comptes [et Mm* née de MOY], 29, avenue\nFriedland (vin*) [35 547.26]\n',
#  'Acquasanta (d’) voir de Narducci.\n',
#  'ADAM (Achille), Député du Pas-de-Calais, 21, avenue\nd’Antin (vin*) [35 311.04] — et 10, rue Victor-Hugo,\nà Boulogne-sur-Mer (Pas-de-Calais), —et « La Soli¬\ntude », à Saint-Quentin-en-Tourmont, par Rue\n(Somme). AC-B-HRRUA\n',
#  'ADAM (M“* Achille), née VERBERKMOÉS — et *£$\nde Verneuil, E î;~ Si [Or] Verneuil-sur-Indre\n(Indre-et-Loire).\n',
#  'ADAM (M“* Eugène), 2 bis, rue de La Baume (vin")\n[35 520.00] — et 24, rue de Confiai», à\'Poissy,\n35 (Seine-et-Oise).\n',
#  'ADAM (Henri), mêmes adresses. AC\n',
#  'ADAM (Mm* Hippolytel, 47 bis, rue Ampère (xvn")\n[35 525.33] — et & des Mazurettes, E é3\n',
#  '[N] Boulogne (Pas-de-Calais),\n',
#  'ADAM (M- Léon) née JÉROME PICHON, 33, av.\nd’Antin (vnr).\n',
#  'ADAM (M. et M“* Georges), 23, av. de Messine (vin")\n— et 14, rue Circulaire, à Versailles.\n',
#  'ADAM (Louis), Agent de change [et M»» née PIERRETJ\n23, av. de Messine (vm") (bureaux: 48, rue de Pro¬\nvence) (ix*) [35 136.13] — et jgj deBrancas, E jj=\néS [0] Sèvres (Seine-et-Oise), — et villa Ellon, à\nLion-sur-Mer (Calvados).\n',
#  'ADAM (Juliette LAMBER) (M“* Edmond), abbaye de\nGif (Seine-et-Oise).\n',
#  'ADAN (Emile), ÿ [etMm,],75,r. deCourcelles(vm")UA\n',
#  'ADDA SALVATERRA (M11* d’), 37, avenue Montaigne\n(vin").\n',
#  'ADELINE, née F AU (M” Edmond), 31, rue Pierre-\nCharron (xvi*) — et {£à de Sérigny, 0 J: ^\n[Or] Cour-Cheverny (Loir-et-Cher).\n',
#  'ADELINE (M““ Raoul), née FROGER des CHESNES,\npavillon de La Louetière, E â [Or] Cour-\nChcverny (Loir-et-Cher).\n',
#  'ADELINE (Gaston) [et M"" née DELONDRE], 55, rue\nPierre Charron (vin") —■ et {^3 de Moussonvilliers,\nE ]ÿ= S\'-Maurice-les-Charençais, 5 kil. (Orne) gji\n[0] La Ferté-Vidame (Eure-et-Loir). H-UA\n',
#  "ADELON, née HAENTJEN'S (M- Henry), 24, rue\nde Courcelles (vm*) [35 517.06].\n",
#  'ADELON (Marcel), même adresse.\n',
#  'ADELSWARD (B””»" Axel d\'), née WUHRER,20, rue\nDaru (vm") — et à Nice.\n',
#  'ADELSWARD (B***" Gustave d\'), née de POURTALÈS\n63, boulevard de Courcelles (vin*) [35 508.32] — et\n(£3 du Plessis-Mornay, E Rochefort-en-Yveliues,\n1f= [35 24], Donrdan (Seine-et-Oise).\n',
#  "ADEN'IS de LA ROZERIE (A.-H), Conseiller Maître\nà la Cour des Comptes, 0. K, 3, rue de Monceau (vin0),\n",
#  'ADHÉMAR (C""" d’), née MARIANT, 33, rue Was¬\nhington (vm*).\n',
#  'ADHÉMAR (V“ Olivier d’), K [etV1*"*\' née VERDET]\n86, rue do Yarenne (vu*)— et à de Saint-Hubert,\nE Sorgues-sur-l’Ouvèze (Vaucluse — et éêS de\nTeillan, E Marsillargues (Hérault).\n',
#  'ADHÉMAR (Vf Robert d’), à Lille (Nord).\n',
#  'AFFRE de SAINT-ROME (Cl°“* Denis) [née de NOGA-\nRET], 147, rue de Rennes (vi*) — et à Soisy-sous-Mont¬\nmorency, E îf= (Seine-et-Oise).\n',
#  'AGACHE (Alfred), 14, rue Weber (xvi*). UA\n',
#  'AGHION (M. et Mm" Jules), 24, rue Clément-Marot,\n(vm") [35 501.87]. CF\n',
#  'Agneau (d’) voir: Carpentier d’AGNEAU.\n',
#  'Agneaux (d’) voir: de S" Marie d’Agneaux.\n',
#  "AGN'ELLET (M. et Ilm‘ Augustin), 50, av. Victor-\nHugo (xvi*).\n",
#  'AGN\'ELLET (M11* Emma), 59, rue de Prony (xvn")\n— et villa à Menthon-Saint-Bernard, E [Z- (Haute-\nSavoie), fg [P.-L.-M.] Annecy.\n',
#  'AGNES (Eugène), 59, rue Chardon-Lagache (xvi»),\n',
#  'AGO.N (la Générale M“* d’), née TIEUSONNYER, 78,\navenue Henri-Martin (xvi*) — et *& de Sampange,\nE Nevers (Nièvre).\n',
#  'AG0PIAN-PACHA (M»"), née KHORASSANDJ1,\n98, boulevard Malesherbes (vui").\n',
#  'AGOPIAN-PACHA (L.), môme adresse. Y\n',
#  'AGOl\'LT (M**d’) [et M\',"néede MONTRICH AHD], gft\nde Vandœuvre, E Coulans (Sarthe) àZ [0|. Le\nMans (Sarthe).\n',
#  'AGOl\'LT (C\'" d’), ancien député [et C1""” née\nd’ESTAMPES], 19, boulevard de La Tour-Maubourg\n(vu") et — {gs de Beauplan, E 35. Voreppe Isère .\n',
#  "AG R AIN née de GESTAS de LESPÉROUX, (M*“ d’),\n63 bis, rue de Yarenne — (vu*) et A de Rressey,\nE Arc-sur-Tille 3 kil. (Côte-d'Or) [P.-L.-M.].\nd’Arc-sur-Tille et Magny.\n",
#  'AGRAI.N (G** Jean d’) [et Cl,“* née Geneviève\nR0UT1NY], mêmes adresses — et villa St-Vallier\nà Nice.\n',
#  'AG R AIN (V“ Henri d’), mômes adresses.\n',
#  'AGR\n',
#  '33\n',
#  'ALF\n',
#  'AGRAIN (11\'» d’), Lieutenant au 1" Dragons [et\nM\'" née de JESSÉ-LEYAS], —même de Bressey\net à Joigny (Yonne) [Jï 30J.\n',
#  "AGl'EN (P.-L. d’) [et M”*], 74, rue Michel-Ange, [Ht\n239.81]—et fljj le Prieuré Saint-Michel, à Saint-\nPair-sur-la-Mer (Manche).\n",
#  "AGUERA (F. G. de), 8, rue Magellan (Viir). RR-UA\nAguesseau (d') : voir de Skguh d’AcuEssEAU.\n",
#  'AGUIAR (M” Guillaume PINTO d’), 31, rue Pierre-\nCharron (XVIe).\n',
#  'AGUIAR (Louis PINTO d’), même adresse. AG-GF\n',
#  'AICARD (M. Jean), 40, rue de Luxembourg, et villa\nles Lauriers-Roses à La Garde (Var).\n',
#  'AIGNAN, née MOSSELMAN (M”* Léon), 60, rue\nFrançois-lor (viii*).\n',
#  'AIGNAN (Gabriel) [et M““ née Mariquita del VALUE\nde MENA], 5, rue Montaigne (vnr)—et à Douvres-\nla-Délivrande (Calvados). SH-CM-UA\n',
#  "Aighepokt (d1) : voir d'Ai.F,YRAC (d1).\n",
#  "AILLIÈRES, née GÉRARD (M™ Fernand d’), 16, rue\nBayard (vin») — et jà d'Aiüières, a jg\n[0] Mamers (Sarthe).\n",
#  'AILLIÈRES (M. Louis d‘), mêmes adresses. J\n',
#  'AILLIÈRES (Le Colonel Etienne d’), Commandant le\n10° Cuirassiers, H, [et M“° née de SAINT-LAUMER],\n123, rue de Lille (vu0) et 8, boulevard du Nord,\nà Lyon (Rhône).\n',
#  'AILLIÈRES (M. Jean d’) [et M»° née de FRÉVILLE\ndeLORME],214, boni. Saint-Germain (vu») [P.-A.-T].\n',
#  "AILLY (B»—”1 Jacques d’J née Thérèse de JUMILHAC\n30, rue Boissière (xvr) — 0*3 d’Ailly, 123 Roanne\n(Loire), Le Coteau, 4 kil. tfë [P.-L.-M.] Le\nCoteau, l'Hôpital et Roanne, 4 kil.—et M d’Alosse,\n",
#  '1SI Marcilly-en-Villette, 4 kil. (Loiret), @1\n[Or] La Ferlé St-Aubin et St-Cyr-en-Yal, 12 kil.\n',
#  'AILLY lie VERNE CIL (M. d’), O. #, Sgndiedes Agents\nde change [et Mm» née TRICHARD], 30, avenue\nMontaigne (vin*).\n',
#  "A INVAL (Vu d’), Lieutenant d’Artillerie [et V'----\nnée HA Y des XETUM1ÈRESJ, 44, rue François-\nI,r (vin») fp.-â-t.).\n",
#  'AKEIÏMANN (M.) [et M“» née Germaine RENIER], 3,\nrue Le Nôtre (xvr).\n',
#  'ALADRO KASTRIOTI (S. A. S. le P°* don Juan de),\nancien Ministre Plénipotentiaire d’Espagne ien\nson hôtel), 9, square Lamartine (xvr). B-UA\n',
#  'ALAMAGNïj (Edouard), 26, rue Bayard (viir),\n[iH 331 Tl] — fià de Cm aise, ES) [£= Mont¬\nbrison (Loire). Sp\n',
#  'ALAVOINE (Auguste) [et Mm°], Ê des Ormeaux,\n',
#  "IS1 R= Benodet, [0' Quimper (Finistère). A\nAlbebti.ni : voir Uiaz-Albertini.\n",
#  'ALBEKTI (Léopold) [et M“* née REITLINGER], 73,\nboulevard Haussmann (vnr).\n',
#  'ALBERT-LAMBERT (M.), Sociétaire de la Comédie-\nFrançaise, O. I. ||, [et M“” née Angèle BASSA-\nLER], 224, rue de Rivoli IJ- 243.89].\n',
#  'ALBERT-MORIX (Jean) [et M- née JANNIN], jfo\nde Gravelles, a Etrechy (Seine-et-Oise). UA-Y\n',
#  "ALBIGNAC (M” d’) [et M'-» née d’OIfFEUILLE], 6,\nimpasse des Gendarmes, à Versailles — et ^\nd’Orthe, a ]ÿ= St-MartindeConnée(Mayenne),^\n",
#  '[OJ Sillé-le-Guillaume. ^\n',
#  "ALBON (M1* d’) [et M'-« née de SETTANCOURT-\nVAUBECOURT], 17, rue Vaneau (vu°) — et ^\nd’Avauge, a Pontcharra- sur-Tardine (Rhône),\nM [P-L-M] St-Romaiii-de-Popey. H-J-U\n",
#  "ALBRECHT do MARTENS, [et Mm” née de LAVA], 3,\nrue St Didier (xvr) — et gZz d'Epaux, a jj= gg\nChàleau-Thierry (Aisne).\n",
#  'ALBUFÉRA (SUCHËT, Duc d’) [et D»"» née de CAM¬\nBACÉRÈS], 35, rue St-Bominique (vu°) — et M de\nMontgoborta jÿ=^|[N]Yillers-Cotterêts (Aisne) J-U\n',
#  "ALBUFÉRA (SI CHET, M'1 d’), [et M -- née Anna\n",
#  "MASSENA de RIVOLI, P-° d'ESSLING], 40, av.\nHoche (vin») [A 511.49], et 10, rue Jean-Goujon\n(vnr), — et à de Montgobert, a Villers-Cotte-\nrets Cœuvres et Valsery, 3 kil., M [N| Villers-\nCotterets, 10 kil. ou Longpont 7 kil. (Aisne)-Bet\nvilla Masséna, 1, rue de France, à Nice (Alpes-\nMaritimes). J-U\n",
#  'ALBl’QUERQUE (B°” de), 4, sq. du Roule (vin*). UA\n',
#  "ALBYVILLE (C*« d') [et C'«— née de SERCEY],\néêü <in Chatelier, a Binan (Côtes-du-Nord) — et\n",
#  'ÉÊâ de Ilomigny, a Sains (Somme)\n',
#  'ALCANTARA ((>»■■« AI var d’), née de GAUDE-\n',
#  'CHART, 2, rue de la Planche (vu») — et O de\nQiierrieu, a Querrieu (Somme), [N] Amiens.\n',
#  "ALCANTARA (Cte Jean d’) et [(>■■' née T EINT DE\n",
#  'ROODENBEKE, mêmes adresses.\n',
#  'ALCEDO (M-- d’) [et M - née de BANUELOS], villa\nAlcedo, à Biarritz (Basses-Pyrénées) — et,\nCastrelos, Yigo (Espagne). AT-G-U\n',
#  'ALEM (M. Pierre) H M. A. [et M”* née Marie-Thé¬\nrèse de BOSKEDON], 1, place des Perchamps (xvr).\n',
#  "ALENÇON (S. A. R. Mgr. le Duc d'j, 11, rue Beau-\njon (vnr).\n",
#  'ALÈS de CORBET (Vu d’) [et Yu**e née deBEAUCÉ],\n2, square de La Tonr-Maubonrg(vir) — et jêj du\nHoussay, a Segré (Maine-et-Loire). A-H\n',
#  'ALEXANDER (M.etMm0 Charles), 64, avenue du Bois-\nde-Boulogne (xvr).\n',
#  'ALEXANDRY d’ORENGIANI (B01 Michel d’), Lieute¬\nnant au 13‘ Cuirassiers [et B»”— née de NEUVILLE],\n8, rue Pierre-Charron (xvr) — et du Puits,\na Coise-St-Jean-Piedgauthier, t-g St-Pierre-\nd’Albigny (Savoie).\n',
#  'ALF.XIS (S. A. I. le Grand-Duc), 38, avenue Gabriel,\n',
#  '(VIII-).\n',
#  'A LE Y B \\C fRoa René drd [et B0ttna née de COLOMBEL],\n78, rue des Saints-Pères ivn*).\n',
#  'ALEYRAG d’AlGKEPONT. (Bond’),et de Prélefort,\nSaint-A y (Loiret) t&S[0r] Meung-sur-Loire —\net villa de Monternot, igj [P-L-M.J Belle-\n',
#  'ville-sur-Saéne (Rhône).\n',
#  'ALFAS SA (Samuel) [et Mm* née HILLEL], 46, rue\nPierre-Charron (vme) [3? 519.94]. GF\n',
#  'ALG\n',
#  '36\n',
#  'AME\n',
#  'ALGAN (Le Colonel Henri), 0. ch, K [et M"* née\nCLÉMENT], lOi, rue Lauriston (xvf).\n',
#  'ALGAURA (Edouard de) [et M"* née d’ALBAU], 165,\navenue de Wagram [7. 557.85],\n',
#  'AL1C0T (M—), 33, rue Saint-Guillaume (vif).\n',
#  'ALICOT (Michel), ancien Député [et M"’ née BON-\nNARIC], même adresse.\n',
#  'ALIGNY (PICOT de MORAS, B“» d’) [et I!--- née\nMENANS], 31, quai d’Orsay (vu*) — et A de\nMontmirey-la-Ville, K Moissey (Jura). A-H\n',
#  "ALIGNY PICOT de MORAS (B- André d’), Lieute¬\nnant d'Arl illerie ! et [t”n^ née Thérèse de PARIEL],\n11, rue Saint-Dominique (vil») — et A de Montmi\nrcy-la-Ville, Kl Moissey (Jura) |j= 7. Montmirey-\nlc-Clihteau — et M de Fabrègues, K éâ\n",
#  'Aurillac (Cantal). A\n',
#  'ALIGRE, née de PRÉAULX (M\'“ d", 89, faubourg\nSt-Honoré (vm“), [7. 516.39] —et afo de La Rivière,\n53 [£= âl Ponlgouin (Eure-et-Loire) — et ^ des\nVaux,KÎf= Belhomert (Eure-et-Loir),[0] Pont-\ngouiu et La Loupe.\n',
#  'Aligre (d’) : voir Pomereu d’Aligre.\n',
#  'AL1NT.0URT (Cu d’), [et C""° née G1LL0TLX]\nG ELIOT], 17, avenue d’Eylau (xvf) [ik 693.68\n— et à Plainfaing (Vosges). B-H\n',
#  'Alinev d’Elya : voir d’Elva.\n',
#  'ALLAI RE (Colonel Ernest), 0. tjf, 16, rue Mari-\ngnati (vnf). AL\n',
#  'ALLAI RE (Jules), K, Juge au Tribunal delà Seine,\n16, rue de Marignan (vin*). AL\n',
#  'ALLAI RE (Mm* Etienne), 101, rue du Bac (vif).\n',
#  'ALLARD, née AUBINEAU (Yu“* d’), 23, rue du\nCherche-Midi (vf).\n',
#  'ALLARD (Jules) [et Mm” née LACOSTE de SAINT-\nAMAND], 10, rue La Terrasre (xvf) — et jêj du\nPrieuré de Gaillonnet, K Meulan (Seine-et-Oise).\n',
#  'ALLARD du CHOLLET (C“), 0. A y, *, * [et\nCl’“* née HARTOG], 114 bis, boulevard Malesherbes\n(xvtf).\n',
#  'ALLARD de GAILLOX (B- E.) [et B-"-- née FLO¬\nCON], 5, quai Malaquuis (Vf) [3* 817.07]. AG-H\n',
#  'ALLEMAGNE (B”» Paul d’) [ut B°-»>- née d’ABBADIE\nd’ARRAST], 88 bis, rue Joulïroy (xvif).\n',
#  'ALLEMAGNE (Edmond d’) [et M“* née liAZIKE], 15,\nrue d’Astorg (VHP) — et ^ de Polisv, K Po\nlisy, £g Polisot (Aube). AL\n',
#  'Allemans (d’) : voir du Lau (»’).\n',
#  'ALLEZ (Edouard) [et M”’ née HOULLIER], 19, rue\nLeroux (xvf) [TR 522.80] — et sà de Faiconne, 181\ngg [0] Nanterre (Seine-et-Oise). AC-H\n',
#  'ALLEZ (M”* Adrien), 21, avenue, de l’Alina (v np)\n[7. 519.87].\n',
#  'ALLEZ (Lucien), 39, rue d’Artois (vrip). AC-H\n',
#  'ALLEZ (M. et M"1 Emile-A.), 5 bis, rue de Rerri\n(vnf ) [7. 529.73] — et de Belesbat, K Boutigny\n(Seine-et-Oise).\n',
#  'ALLFRÉE, née ROGUANOEF (M“*Helen-Féodorovna),\n82, rue de Varcnnc (vil”) — et 61, Myddlctou Square,\nLondon (Angleterre).\n',
#  'ALLFREE (Alexandre-Charles), mêmes adresses.\n',
#  'ALLIBERT (Jacques) [et M"1” née de BAMMEYILLEJ,\n10, rue de Marignan (vnf) [3î 525.82], AG-H\n',
#  'ALL1ZÉ (M. Henry), Ministre de France à Stockholm\n[et Mm* née 11EBBETTE], 30, rue Boissière (xvf)\net à Stockholm-, légation de France (Suède).\n',
#  'ALMEIDA (C1\'”1" d’),30, avenue Henri-Martin (xvf)\n— et Villa Almeida, à Avon (Seine et Marne).\n',
#  'ALOISI (M. et M“" POMPEO), 28, avenue du Troca-\ndéro (xvf).\n',
#  'ALPHAND (M. Charles), Vice Consul, attaché aux\nAffaires Étrangères [et M“* née Margerin de GRÉ-\nMONT], 11, avenue de L11 Grande Armée (xvf).\n',
#  'ALPHEN SALVADOR (Mm* Emile), 9, rue Le Tasse\n(xvf) — et à de la Cornmaiiderle, SI A3 jÿ=\nBallan (Indre-et-Loire).\n',
#  'ALPHEN-SALVADOR, mêmes adresses.\n',
#  'ALSACE (C** Maurice d’), 20, rue Washington (vnf)\n',
#  'J-RR\n',
#  'ALSACE (C** Philippe d’) [etC‘““* née de BRIENEN],\n4, rue Dumont-d’Urville (xvf) [7î 520.64] — et\nMontgraham, S ]£= Souancé i Eure-et-Loir), ^8\nNogent-le-Rotrou. J-RR\n',
#  'Alsace (»’) : voir aussi d’Hénin (d’).\n',
#  "Altena (d’) : voir de Borciigiuve d'Altena.\nAltenbourg (d’) : voir de Ghampreux (d-).\n",
#  'ALT11AUS (Le Colonel B*” Augusto de), O. Sfr, Atta¬\nché militaire d i Pérou en France et en Italie, 72,\navenue Kléber (xvf).\n',
#  'ALTON (C1* d’), éês de la Bertraie, K S [Or]\nClefs, 4 kil. (Maine-et-Loire).\n',
#  'ALTON |V1" Charles d’) [et Y1"”” née de LA ROQUE-\nORDAN], 4, rue (\'.revaux (xvf) — Chalet-Branet,\nS >8 [Or] Buch (Gers) — et même fa . H-J\n',
#  'ALTON-SHÉE (G1”** d’), 12, rue Pergolèse (xvf).\n',
#  'ALTON-SHEE (Cte P. d’), même adresse.\n',
#  'ALVEAIl (Marcel-T. de) [et M- née PACIN1], 119,\navenue de Wagram (xvif) [7î 583.76].\n',
#  'AO-AE-B-H-ÜA\n',
#  'ALYES de ARAUJO (llippolyto) [et M“* née da\nPORGIUXCULA], 57, avenue Kléber (xvf).\n',
#  'AMAND-VILLEFOUT (M.) ch, Secrétaire d\'Ambas¬\nsade [et M"1\'née CIIIBOIRGJ, 14, rue Dupout-des-\nLoges (vif) [7. 702.461.\n',
#  "AMAT (D' Charles), ch, 0. A. «, [et M- née A. DU¬\nBOIS], 13, rue Lôon-Cogniet [7. 549.46],\n",
#  'Amécourt (d’) : voir de Ponton (d’).\n',
#  'Amblard de Beaumont (voir de Beaumont).\n',
#  "AMBOIX de LARBONT iLe Général à') C. ch [et\nM“* née de POUBTALÉS], 11, avenue Hoche (vnf )\n— et flà du Val-Larbont, K flg La Bastide-\nde-Sérou, distance 1 kil. (Ariége), U\n",
#  'AMBOIX de LARBONT (Paul d’), mêmes adresses.\n',
#  'AMBOIXdeI.ABBONT (M. Roger d’), mêmes adresses.\n',
#  'AMBRIÈRES (A. d’), Capitaine au 10• Hussards, [et\nM"" née LE COl\'PPEY], 60, rue Pierre Charron.\nAmbrines (d’) : voir de Valicourt d’AMimiNES.\nAmécourt (d’) : voir de Ponton d’AMÉcoiiRT,\n',
#  'AMELLNE (M-, Ernest) née FERRARI de CAMPO-\n',
#  'LEONT, 29, rue Chaptal (ix*) et à Yillers-sur-Mer\n(Calvados).\n',
#  'AME\n',
#  '31\n',
#  'AMELINE de LA BRISELAINE, née ABEILLE (M—\nH.), 9, rue Portalis (vin*).\n',
#  'AMELINE de LA BRISELAINE (Roger), même adr.\n',
#  'AMELOT de LA ROUSS1L1IE, née CHOPPIN d’AR-\n',
#  'NOL VILLE (C1*1** Br*), 9, boulevard de La Tour-\nMaubourg (vir).\n',
#  'AMELOT de LA UOUSSILHE (C1*), Secrétaire d’Am¬\nbassade [et O*” née CORBIN], 3, boni, de La Tour\nMaubourg (vii*) •— et ^ de Mortefontaine, E\nPlailly (Oise) Mortefontaine, gg [NJ. Survilliers.\n',
#  'H-UA\n',
#  'AMELOT de LA ROUSSILHE (V>-> [et V--»- née de\nSEGUR-LAMOIGNON], 9, b. de La Tour-Maubourg\n(vif) — ffo de Méry, E fe= 4§ï[N ot °] Méry-sur.\nOise (Seine-et-Oise) — et Domaine de Belleval, K)\nÎ5= Beaucaire (Gard), ig [P-L-M] Arles. A\n',
#  "AMILA KVARI (LL. AA. RR.) (P°- et P°-°>, 64, ave¬\nnue du Bois-de-Boulogne (xvt'J,.\n",
#  'AMI LL V (Cu Maurice d’) [et C""* née Germaine de\n',
#  'LAAGEJ, S, rue de Marignan (vu*) — et ^\nd’Amilly, K Berd’huis (Orne), jÿ= à Nogent-le-\nRotrou (Eure-et-Loir) -— et Pavillon des Evées,\n13 Jÿ= & [35 3] Senonches (Eure-et-Loir).\n',
#  'AMODIO (M-de), 4.4.4, [et SP- née WAINWRIGHT],\n88, avenue Kléber (xvi*) [75 678.41]— de 8t.-\nMaurice-du-Désert ( 75 au flà ), Kl â La Ferté-\nMacé (Orne).\n',
#  "ASIODRU i l>' Laurent), Député et Conseiller général\nde Seine-et-Oise [et M—], 66, avenue des Champs-\nElysées (vin*) [7* 518.44] — et A de Chamarande,\nE^éS [Or] (Seine-et-Oise).\n",
#  'ANCEAL (SI- Eugène) née HEODERERT, 114, ave¬\nnue des Champs-Elysées (vin”) [75 506.31].\n',
#  "ANCEL (M”' Adolphe), 103, rue La Boétie, (vin*)\n[75 521.37].\n",
#  'ANCEL (Raoul) [et M“* née COPPINGER], 19, rue de\nBassano (xw=) — et de Gournay, Eâl [O]\nHarfleur (Seine-Inférieure) \\y Gainneville: A\n',
#  'ANCEL (Georges), 191, boni. St-Gcrmain (vii*) —et\n',
#  'ÊÊ) des Petit-Colmoulins, K) flg [O] Harfleur\n(Seine-Inférieure). A-Y\n',
#  'Avdernay (d’) voir de Vassart d’Andernay.\n',
#  'ANDERSON (Captain J.-H.), 33, av. Montaigne (viir),\n— et Albany, 2, Piccadilly, à Londres. RR-UA-Y\n',
#  "ANDIGNÉ, née de BARBENTANE (M'*' d’), 77, rue\nde Lille (vu*). [75130.10] — âjtj de Monet, 153\nBeaufort-en-Vallée (Maine-et-Loire), è-4 [Or]\nLa Ménitré, Brion-lumelle et Beaufort — et {gj de\nBarbentane, la )- - Barbentane (Bouches-du-Rhône).\n",
#  'ANDIGNÉ (M"“ d’), mêmes adresses — et *£* (je\nCondillac, Kl M La Coucourde (Drôme).\n',
#  "ANDIGNE (M‘‘d’) [et M‘“ née Madeleine GODDARD],\n77, rue de Lille (vu*) [75130.10] — de Monet,\nE) Beaufort-en-Vallée (Maine-et-Loire), {jglÉtl.\nLa Ménitré et Jumelles-Brion — {fis de Giraud, El\nLe Sambuc (Bouches-du-Rhône), l'Armelliére-\nGiraud, [P-L-M] l’Arnelliére-Giraud et Arles-\nsur-Rhône — et de Richebourg, El La Bassée\n(Pas-de-Calais) H-J-RR\n",
#  'AND\n',
#  'ANDIGNÉ (C‘* d’), officier de cavalerie démission¬\nnaire, Conseiller municipal de Paris, Conseiller\ngénéral de la Seine, 49, rue de Boulainvilliers\n(xvi*) — et 2, rue SchelTer (xvi*)— et mêmes O .\n',
#  'CM-RR-H-J\n',
#  'ANDIGNÉ, née de CROIX (C1*"* de), 3, rue de La\nChaise (vil*) — îgj de Grip, SI Durtal\n(Maine-et-Loire), â [Or], Moraunes et Durtal —\nde Barneville, E £f= ^1 [O], Honfleur (Cal¬\nvados)— et êêj de Franc-Slarct, E Vezin(Belgique),\nMarche-les-Dames tôE) Nainur.\n',
#  "ANDIGNÉ (C“ Jean d’), [et Cl“'“ née de VILLE-\nCHAIZE], 3, rue La Chaise (VII») — et mêmes {£s\n",
#  'A-H-J\n',
#  'ANDIGNÉ (C** Henri d’) [et Cl**‘» née d’EVRY],\n10, rue Clément Marot (vin*) — ^ de R esteau,\nE Chemiré-le-Gaudin (Sarthe), *75 (O) La\nSuze — et {ga de Thomasin, E If2 Chantenay\n(Sarthe), (O) Noyen.\n',
#  'ANDIGNÉ (C‘* Maurice), 68, av. de la Grande-Armée\n(xvi*)—et A delà Jousselinière, E Beaupréau,\nlOkil. (Maine-et-Loire), ^ [Ét et Or]. Chaloimes-\nsur-Loire). UA\n',
#  'ANDIGNÉ (V- Louis, d’) [et V1*»** née COLEMAN]\nveuve de COURCY-MAY], 6, rue de Berri (vm-j\n[75 528.76] — et même {gj. AG-B-H-J-RR\n',
#  'ANDIGNÉ (C‘“ Geoffroy d’) [et C1*”* née CHANDON\nde BRIAILLES], 13, rue de Berri (vm*) [75 537.41]\n— et afo de la Blanchaye, E jÿ= éS [0] Sogrê\n(Maine-et-Loire). H-J-RR\n',
#  'ANDIGNE (C** Robert d’), Lieutenant au 14* Hus¬\nsards, à Alençon [et C1*"* née LEFÈVRE], —\nmême {gj J\n',
#  "ANDI.AU (C1»*'* d’), 170, faub. Saint-Honoré (vm*).\n",
#  'ANDLAU (Ct0 d’) [et C1*1** née de CHABROL-\nCHAMEANE], 4, rue de Marignan (vin») — M de\nYoré, E Ucmalard 3 kil. (Orne), jâg [0] Re-\nmalard, 4 kil. et Condé-sur-Huisne, 11 kil.\n',
#  'A-H-RR-U\n',
#  'ANDLAU (C1* Antoine d’), même adresse. J\n',
#  "ANDLAU (C‘“ Jean d'), mêmes adresses.\n",
#  'ANDRAL, née DELIES (SI”*), 26, Cours la Reine\n(vm*), — et {fij de Ghâteauvieux, E lf= éS [Or]\nSaiut-Aignan (Loir-et-Cher).\n',
#  "ANDRASSY, née C1**'* PALFFY (C'»“»), 68, boni, de\nCourcelles (xvn*).\n",
#  "ANDRAULT (C.), Conseiller honoraire à la Cour\nd'Appel, 30, quai du Louvre — et au Petit-Bois-\nprés Melle (Deux-Sévrc-).\n",
#  'ANDRÉ (R°- d‘) [et B»"“" née de BlUCQl.\'EMONT],\n3, rue Auguste-Vacquerie (xvi*) — et ^3 de la\nSouque, e {#= eS[Or]Rabaslens-surTarn (Tarn\'\n',
#  'H\n',
#  'ANDRÉ (B»"** Émile d’), 76, rue de la Pompe (xvi°).\n',
#  'ANDRÉ (B** Albert d’) [et B"°* née GUILLAUD],\n86, avenue de Yllliers (xvi*).\n',
#  'ANDRÉ, née JOLY de BAMMEVILLE (SI- Alfred),\n49, rue La Boétie (vm*) [75 531.53] — et {êî de\nCrassier, E îp 75gg Divonnc-les-Bains (Ain).\n',
#  'AND\n',
#  'APC\n',
#  '38\n',
#  'ANDRÉ, née JAQUEMART (M- Édouard), 138, boni.\n',
#  'Haussmann (vnr) [35 317.96],\n',
#  'ANDRE (L.) [et M“* née RIGAULT], 3, rue La Boétie\n[vin»).\n',
#  'ANDRÉ (Alexandre) [et M-*née ROBERT de MASSY],\n20, rue d’Aguesseau (viii«) [3- 237.81] — et de\nLa Frogerie, 8 Ligny-le Ribault (Loiret).\n',
#  "ANDRÉ, née L'HÉRITIER (Mm* Georges), de\nLesmont, la js= Lesmont (Aube), ê3 [E] l’iney\net Brienne-le-Chàteau.\n",
#  'ANDRE (René) [et M"* née LE MIRE], 3, avenue\nVictor-Hugo (XVIe).\n',
#  'Andreis : voir De Andreis.\n',
#  'ANDREZEL (Charles d\'), dfc, Lieutenant de vaisseau,\n[et M”" née de FROTTÉ], 17, rue Yernet (vnr),\n',
#  'ANDRIEIIN (L.), #, Ancien Député, ancien Préfet\nde Police, ancien Ambassadeur [et M™ née\nKOECHLIN], 42, rue Scheffer (xvil [35693.82] — et\niêB du Casset, 8 M [P-L-M] Montluel (Ain.)\n',
#  'ANETHAN (B*"* Alix d’), 12 rue Oudinot (vu*).\n',
#  'ANGELIS (M“ d’), Ministre plénipotentiaire [et M”»\nnée du BOUZET de CAUSSINS de MARIN], 8, rue\nMeissonier (xvifl — et à Saint-Florent (Corse).\n',
#  'ANGÉLY ïC‘» Albert d’), à Sérillac, 8 Beaumont-\nsur-Sarthe (Sarilie). UA\n',
#  'ANGÉLY (Emile d’) [et Mne née de CONFLANS], 7,\n',
#  '- rue Alboni (xvie) — et ^ La Héraye, 8 Ta-\nvers, gg Beaugency, (Loiret),\n',
#  'ANGÉLY (Mne Maurice d’), 64, rue de Rennes (vie).\n',
#  'ANGLADE (Achille), #, [etM- néePETITGUÉNOT],\n32, avenue Montaigne (vm*) — et jgj de Saint-\nEutrope, 8 Montlhéry (Seiue-et-Oise). AL\n',
#  'ANGLADE (M. René) [et M”» BOSSERONT d’], 113,\nrue de Courcelles (xvii,)It- et ^ l’Andiran, 8\n^ ggj Nérac (Lot-et-Garonne).\n',
#  "ANGLEMONT, née THOMAS (V>-- Christian d'), 14,\nrue Greuze (xvi»>.\n",
#  '.ANGLEMONT (Vle Henry d’) [et V>» "» née de MA-\nCHADO], 14, rue Greuze (x\\T).\n',
#  'ANGLESEY (M”* d’), 17 bis, rue Mansart à Ver¬\nsailles (Seineet-Oisei.\n',
#  'Anglure (d’| : voir de Noblet (TAnglure.\n',
#  'ANGOT (Alfred) [et M”* née AGELASTO], 176, rue\nde l’Université (vu*) [35 700.07] (Jeudi).\n',
#  'ANGULO (Rafaël), K [et M“» née SANCHEZ de\nMOVELLAN],7, avenue de l’Alma (vm*) [35 308.72],\n— et jgj de Rouvres, 8 4Ü Vigneux (Seine-\net-Oise) [35 38] Villeneuve-St-Georges. H-Y\n',
#  "ANGULO Y GARCIA (Gregorio), 17, avenue de l'Alma\n(vin*) — et û El Cid, 8 eë La Baule (Loire-\nInférieure»,\n",
#  'ANINAT (Benjamin) [et M“* liée SEMINARIO], 20 bis\nrue Iioissière (xvr).\n',
#  'ANINAT (M** Antoine), née de VIALE-RIGO, 20, rue\ndu Bouquet-de-Longchamp (xvi*).\n',
#  'ANISSON du PEBRON (Roger), Ancien député, 13,\navenue Hoche (vm*) [35 804.46] — et (fil de St-\nAubin, 8 Allouville-llellefosse, 5 kil. (Seine-\nInférieure), ^ [0] Foucart et Alvimare, 6 kil.\n',
#  'A-H-RR-U-UA\n',
#  'ANISSON du PERRON (Jacques), Capitaine au\nlO’ChasseursfiMouhm) [et M“*néedeBOISGELIN],\n13, avenue Hoche (vm*) — et même à — etfljjde\nSt-Fargeau,8 ^ M [35 6] St-Fargeau (Yonne).\n',
#  'H-RR\n',
#  'Anlezv (d’| : Voir de Damas (I’Am.fzy.\n',
#  "Annflet (d’) : Voir Rurthe d'A.NNELEi.\n",
#  'ANNENKOFF (M”* Dagmarf, 24, avenue du Troca-\ndéro, (xvi*) [35 694.47].\n',
#  'ANSAC (M11* d’), 32, avenue Hoche (vui‘).\n',
#  "Ansac (d’) : Voir aussi M'* de Chabf.rt (d').\n",
#  'ANTERROCHES (C‘« d’) [et C>-- née MATHIEU],\nS, rue de Monceau (vm*) — et {gj de Champeaux,\ni^i Palinges (Saône-et-Loire) — et A d’Anlerro-\nches, 8 Æ Murat (Cantal).\n',
#  'ANTERROCHES (Y1* d’) [et V[-*nce des ROTOURS],\n64, boulevard .Malesherbes (vm*).\n',
#  'ANTHENAISE, née de PERItUSSE des CARS (Y*»“ d’),\n24, Cours la Reine (vm*) — et fgj de la Jaillière,\n8 Varades (Loire-Inférieure), M [Or] Iugran-\ndes-sur-Loire.\n',
#  'Anthenav (d’) : Voir aussi Renoist iTAntiienay.\n',
#  'ANTHENAY (B”“ Georges d’), Ancien Receveur des\nFinances [etB°“*],10, avenue de AVagram (vm*)—\net {fe de La Chapelle, 8 Troyes (Aube).\n',
#  'ANTRES (B*»»» Ph. d’), 21, avenue Niel (xvil*).\n',
#  'Antues (d’) : Voir de Heeckeiien ü’Anthes.\n',
#  'ANTHOUARD de YRAINCOURT (C‘«d\') [et c°*"° née\nde MONSEIGNAT], 19, avenue d’Iéna (xvi»), — et\n(fil de Yraincourt, 8 Clerinout-en-Argoime\n(Meuse). A-H\n',
#  'ANTHOUARD de WASSERVAS (R°- Albert d’), Secré¬\ntaire (TAmbassade, K [et B*"* née deROMEL\'F),\n146, boulevard Haussmann (vm*).\n',
#  'ANTIOCHE (C‘“ d’), iK, 23, rue Barbnbde-Jouy (vu*)\n— M de Selorre, 8 St-Yan, 1 kil. (Saône-et-\nLoire), âl [P-L-M.] Saint-Yan, 4 kil. et Paray-le-\nMonial, 12 kil. — et A de Nernier, 8 ]?= Nernier\n(Haute-Savoie), [P-L-M] Genève, 23 kil. et\nBons-Saint-Didier, 18 kil., bateau à vapeur, Ner¬\nnier. H-U\n',
#  'ANTIOCHE (MIU d’), mêmes adresses.\n',
#  'ANTOCOLSKI i,M- Marc), née d’APOTOFF, — et La\nllaromietta, Locarno (Lago Maggiore) (Italie).\n',
#  "ANTONETTI (C'« Pierre) [et née KNAPP],\n",
#  '6, rue Arsène-Houssaye (vnr).\n',
#  "ANTONIX MERCIÉ, Membre de l'Institut, C. K,\n13, avenue de l’Observatoire (vi») [35811.96] —\net Villa Antonin-Mercié, Croix Daurade, 8jÿ=(â\n[Or] Toulouse (Haute-Garonne). UA\n",
#  "Antonio d'Orléans (S. A. R. don) voir Duc de Gal-\nliéra.\n",
#  'AOLST (M* d’) [et M"* née VERGER], 47. faub. St-\nHonoré (vm*)—et jfgj de S\'-Léger, 8 [ï= Croisille\n(Pas-de-Calais). A-H-UA\n',
#  'APCHIER LE MAUGIN (G\'*"* A. d’). 6, rue Sédillot\n(vu*) — et à Grasse (Alpes-Maritimes) — et à\ndu Malzieu, 9-J fs- Le Malzieu (Lozère), i£3 [M]\nSMMiély d’Apchier.\n',
#  'APC\n',
#  '39\n',
#  'ARG\n',
#  'APCHIER LE MAUGIN (C‘e d’)„ Secrétaire tïAmbas¬\nsade, 8, rue Séilillot (vu”).\n',
#  'APCHIER LE MAUGIN (V1* d\'), Capitaine au 4*.\nDragons, à Chambéry [et Y1""" née ROZAT de\nMANDRES], 6, rue Sédillot (vu*) (p.-à-l.) — et\nA*} de Malzieu, K) Malzieu-ia-Yille M St-Chely-\nd\'Apchier (Lozère) — et villa des Charmilles, à\nChambéry (Savoie!.\n',
#  "APCHIER LE MALGIN (Y1' Jehan d'), Vice-Consul\nde France, 6, rue Sédillot (vif) — et A du\nMalzieu, El lf= Malzieu-Yille, é§ Saint-Chély-\nd’Apchier (Lozère).\n",
#  'APERT (IP Eugène) [et M"* née NOÉL], 11, rue Ma\nrignan (vni“) [ F. SS1.68] — et {fig de Terrides, Si\nLabourgade, Larrazel à 5 kil. (Tarn-et-\nGaronne).\n',
#  "APLETSCHËIEFF (Alexandre-André d’) [et M”'née de\nBERGMANN], 99, rue de Courcelles (xvn°). H\n",
#  'APPERT (Colonel Henri), K [et Mm* née ROLAND-\nGOSSELIN], 47, avenue de l’Alma (vm°).\n',
#  'ARAGO (François), 0. Député des Alpes-Mari¬\ntimes [et I1" née DUPUY], 46, avenue du Bois-\nde-Boulogne (xvi°) — et fl*} de Fauguerolles, S\nFauguerolles (Lot-et-Garonne) AC-CF\n',
#  'ARAGUAYA (C,e et Cle,,e d’), 127, boulevard Hauss-\nmann{(vwe). UA\n',
#  'ARAMON (M" d’) [et MUe née de LA BASTIDE], 2, rue\nGoethe (xvie) [3:564.16] — **} d’Aramon, S\n[P.LM.] Aramon (Gard). J\n',
#  'ARAMON (G** Guillaume d’), [et Cte,’e née de MONT-\nSAULNIN], 34, rue de Chaillot (vin*) [35561.39] —\net {fi} de Bernay, ifi! La Guerche (Cher) et — {fi}\nde la Grande-Garenne, IS fs= Neuvy-sur-\nBarangeon (Cher). H-J\n',
#  'ARAMON (Cle Jacques d1) [et O»"» née FISHER],\n1, boni, de La Tour-Maubourg (vu1) [35701.04] — et\n{fi} d’Anizy,s ^=^[N] Anizy-Ie-Chàteau(Aisne). J\n',
#  "ARAMON (Cle Bertrand d') [ot CteMe née Suzanne\nSTERN], 28, rus de Berri (vin») — et mêmes\nadresses. J\n",
#  'ARAMON (C,e Paul d’), [et C,eeee née Rita BELL],\n1, boni. Latour-Maubourg (vu*) — et même {£} .\n',
#  'J-T\n',
#  'Araiijo : voir Pimo de Arauo.\n',
#  "ARBOIS de JLBAINYILLE (d’), Membre de l'Institut,\nO {K, 84, boni. Montparnasse (x,iv) — et {fi} de\nJubainville, K Martigny-les-Gerbonvaux (Vosges).\n",
#  'ARBOIS de JUBAINVILLE (Léopold d’) [et Mmi née\nCERISE], 2, place des Saussaies (vin") — et\nmême {fis .\n',
#  'ARBOIS de JUBAINVILLE (Paul d’) [et M- née\nMICHELET] — même .\n',
#  'Arbouse (d1) : voir de Veyny d’Arbocse.\n',
#  'ARCHAMBAULT-GUYOT (Maurice), Avocat à la Cour\n[et M“* née P1CH0T], 61, rue de Miromesnil (vm*)\n[35548.83] — et {fi} Les Grandes Bourdinières, £3\nRomorantin (Loir-et-Cher). AL\n',
#  'ARCHDEACON, née de ROCQUTGNY du FAYEL\n(M“* Edmond-S.), 15, avenue des Champs-Elysées\n(vup) — et {fi} de Cheney, K Tonnerre (Yonne).\n',
#  'ARCHDEACON (Jules) [etM"> née Madeleine PARANT],\n63, avenue do Villiers (xvu*) [35 516.47] — et {fifl de\nMenucourt, £3 Vaux (Scinc-et-Oise). B-RR\n',
#  'ARCHDEACON (Ernest), Avocat « lu Cour, [et M“*\nnée de FONTAINES], 77 rue de Prony (xvn°>\n[35511.22], - AC\n',
#  'ARCHDEACON (Jacques), 38, rue Marbeuf (vm*) —\net {fi} de Beaumarchais, K Autrèche (Indre-et-\nLoire) . AL\n',
#  "ARCHIAC (C>- DEXMIER d'), Ancien Officier de\nCavalerie, K 46, rue de Miromesnil (vm'), — {fi}\nde Villiers-St-Paul, El {f= Nogent les-Vierges,\n3 kil. (Oise), M [N] Creil et Villers-St-Paul — et\n{fi} d’Argiliy, g| â [E et P L M] Nuits-St-\nGeorges (Côte-d’Or) Argilly. J-UA\n",
#  'ARCHINARD (Louis), C. # [etMme], 9, rue Brémon-\ntier (xvne).\n',
#  'ARCICOLLAR (M“ d’) [et M‘»‘ née de CANDAMO],\n44, rue de la Faisanderie (.XVIe) [35 680.98]. AC-U\n',
#  'ARCOS (Santiago de), Artiste peintre, Gentilhomme\nde S. M. Catholique [et M“e née de CUADRA], 56,\nrue de Bassano (vin*). T3A\n',
#  'Arcosse (d’) : voir Fossé-d’Arcosse.\n',
#  "Arcy (d’) : voir de Bnv-d'AiRCY.\n",
#  'ARCY (B011 d’) [et B"“* née de R00DENBEKE),\n173, boulevard Pereire (xvne).\n',
#  'ARDENNE DE TIZAC (M. d’), Conservateur du musée\nCernuschi [et Mme néo Andrée JACQUET], 7, ave¬\nnue Velasquez [35 323.31],\n',
#  'ARENBERG <P°* Auguste d’), ancien Député, Con¬\nseiller général du Cher, Membre de tInstitut, 20,\nnie de la Yille-L’Ëvèque (vm“) [35 112.69] — et\n{fi} de Menetou-Salon, K îS [Or] Alenetou-\nSalon (Cher), — {fiz d’Arlay, K Arlay, M\nDomblans, 5 kil. (Jura). H-J-U-UA\n',
#  "ARENBERG (Pee Pierre d’), [et P'*,,e née de GRA-\n",
#  '5IONT de LESPARRE] 20, rue de la Ville-l’Evêque\n(vme) [35 112.69] — et mêmes {fi} .AO-H J-RR\n',
#  'ARENBERG (Pce Ernest d’), 10, rue d’Astorg (vm*).\n',
#  'ARFEUILLE (Cte*“ d’) née de LA PERRIÈRE, {£}\nd’Arfeuille, [Si Remy-en-Rolat (Allier) — et {£} de\nLafont, K Brou-Vernet (Allier),[Or et P-L-.M|\nGannat.\n',
#  "A RG AND ON A, P°e de la GLORIETA (Francisco de),\nMinistre plénipotentiaire de Bolivie, [et M“” née\nde L'RIOSTE], 33, avenue Victor-Hugo (xvi*)\n[35545.58].\n",
#  "AISGENCE (M’’ d’), 1 bis, rue de Chaillot (xvi”) —\n{fi} du Grand-Lucé, K jÿ= èS [0] le Grand-Lucé\n(Sarthe) — et {fi} de 'Louvoie, es fÿ= â [O].\nSavigné-l’Evêque (Sarthe).\n",
#  'ARGENCE (C1* Frédéric d’) [et Cte"e née BARROT],\n12, rue Logelbach (xvu”) (p.-à.-t.) — et jfifl de Rou-\nvoie, K |?= eâ [OJ Savigné-l’Évèque (Sarthe).\n',
#  'ARGENCE de PITTI-FERRANDI («■•“ LE GOUESLIER\nd’), 11, rue de Lisbonne (vine) — Manoir à Pont-\nl’Evèque (Calvados) — et villa Hélène, 30, rue de\nParis, àTrouville.\n',
#  'ARG\n',
#  '40\n',
#  'ARN\n',
#  'ARGENCE (Robert-G. d’), 21, avenue du Trocadéro\n(xvp) — mêmes adresses.\n',
#  "ARGENSON (M» d’) [et M >* née d’HARCOL'RT], 11,\nruo Barbet-de-Jouy (vu*) [D 716.59] — et ^ des\nOrmes, k{f= Ormes-sur-Yienne (Vienne). H-J-U\n",
#  "ARGENSON (G- d’) [et G.. LANJl'INAIS], 11,\n",
#  'rue Barbct-de-Jouy (vit*) [1115.30 — et même A . J\n',
#  "ARGENT (Cle d') [et C**“ née de LHOMEL], 1, rue\nLincoln (vin*) — (le Bouville, E3 d§ [Or]\nCloyes (Eure-et-Loir). A-B\n",
#  'ARGENT (V1* d’) [et Vte,,< née Yvonne de SADE], 19,\nrue de Yarenne (vu*) — et même {ÊS -\n',
#  "ARGENTI, née RALLI (M”>* L.I'.j, 42, avenue Ga¬\nbriel (VIII*).\n",
#  'ARGENTI (Auguste), même adresse.\n',
#  'Assis (d’) : voir Horaire d Assis.\n',
#  'ARGUELLES, née MOXTERO (11- de), 5, avenue\nHoche (vin*).\n',
#  'ARIËS (Dr), 51, rue Ampcre .(XVII*) [J 533.89].\n',
#  'ARISTARCHY BEY (Grégoire), Ministre plénipo¬\ntentiaire, 15, rue Treilhard (vm*).\n',
#  'ARISTE, née M1GN0TTE ÎM- Ch. d’), 43, boni.\nMalesherbes (vm*) — et à Ghambourcy (Seine-et-Oise).\n',
#  '■ ARJl\'ZON, née CL\'VELIER (G1*’" d’), 13, avenue\nBosquet (vil*) — et à Dreux (Eure-et-Loir).\n',
#  "ARJL'ZON (C‘* d’) [et G'-- née Mary YVADDINGTON],\n16 1er, avenue Bosquet (vu*) — {êa de St-Uemy,\nEl ^ St-Remy-sur-Avre (Eure-et-Loir), gg [0]\nSt-Gerinaiu-St-Remy — villa St-Remy, Houlgate\n(Calvados) — et à Dreux (Eure-et-Loir). A H-J-UA\n",
#  'ARJL\'ZON (Y‘= d’) [et V1"”* née de VILMORIN], 12,\nrue Dupont-des-Loges (vu*) [ Z 120.01] —à Dreux\n(Eure-et-Loir) — à Verrières-le-Buisson (Seine-et-\nOise) — et villa « La Colline » à Antibes (Alpes-\nMaritimes). A\n',
#  'Arjuzox : voir Carol d’Arjlzom.\n',
#  'Arleüx (d’) : voir Morel d’Am.rcx.\n',
#  'ARLINCÔURT (G1* Jacques d’) [et G-- née PEL-\nLENC], 28, rue Murillo (vm*)— et du Saussart,\nE [3* 2] gg [N] Serifontaine (Oise).\n',
#  'H-RR-UA\n',
#  'ARLINGOLRT (Cl* et Gl,“* Adrien d’), la, rue\nBoissière (xvi*) — et chalet des Mouettes, à Trou-\nville (Calvados).\n',
#  'ARLOT de SAINT-SALD (G- d’) [et G»— née de\nROCHECHOLART], 4, avenue du Trocadéro (xvi*)\n(p.-à.-t.) — {êa de la Valouze, K gg [Or] La\nRoche-Ghalais-St-Aigulin (Dordogne) — et â de\nClisson, O â [Et] Bressuire (Deux-Sèvres) —\net 82, rue du Lancera, à Bordeaux (Gironde).\n',
#  "ARLOT de SAINT-SALD (C‘“ Jacques d’), Secrétaire\nd’ambassade [et G1*'** née de LAFAYE], 29, rue\nde Berne (vin*).\n",
#  'AUMAILLÉ, née de SËGLR (C1*”* d’), 9, square de\nMessine (vin*) — et 62, rue Aguado, à Dieppe.\n',
#  ".ARMAILLÉ (G** d’) [et G1*1** née Raymonde do NI¬\nCOLAY'], 63, rue de Varenno (vu*) — et fit de la\nMenantiére, Kl : Montrevault ,-èu Varades\n(Maine-et-Loire). A-H\n",
#  'ARMAILLÉ (V‘* d’) [et V>*«* née de MARSAY], 3,\nboulevard de la Tour-Maubourg (vu*) — du\nTremblay, K [P-L-M] Vandenesse (Nièvre)\n',
#  '— et à Loches (Indre-et-Loire). H-J-RR\n',
#  'Aiiman de Caillavet : voir de Caillavet.\n',
#  'ARMANCOLRT (C“ d’) [et G--* née de BEALRE-\n',
#  'PAIRE de L0UVAGNY’], 63, rue des Sts-Pères\n(vi»> — et 3, rue des Vieux-Rapporteurs, à Chartres.\n',
#  'ARMAND (G»*—) née de GONTALT-BIRON, 49, rue\nSaint-Dominique (vu*) [3*125.30],\n',
#  'ARMAND (G1*), ancien Capitaine de Cavalerie [et\nC‘*”e née de BRANTES], 20, rue Hamelin (xvi*)\n[Ut 693.20] — {êj d’Arcis-sur-Aube, K [El\n',
#  'Arcis-sur-Aube (Aube) — et ^ d’Ailleville, K f?=\nM [E] Bar-sur-Aube (Aube). A-AC-UA\n',
#  'ARMAND (C** Albert), (K [et C1*"* Marie ARMAND,\nnée BEl’F], 11, rue Laid», à Marseille [ 7. 112]\n',
#  '(Réception vendredi) — de Toursainte, à Mar¬\nseille — et La Torse, à Aix (Bouches-du-Rhône).\n',
#  'E-ÜA\n',
#  'ARMAND (Edmond), 41, rue Pierre-Charron — et\n',
#  'SÊS d’Eperlecques) K St-Omer (Pas-de-Calais).\n',
#  'ARMAND (Maurice), Lieutenant au 9* Cuirassiers,\nmêmes adresses.\n',
#  'ARMAND (M. et M"* Auguste), 48, avenue d’Iéna\n(xvi*) [Ti685.51)\n',
#  "ARMAND-DELILLE (T)' P.-F.) [et M”e née LATHAM],\n20, rue de Tilsitt (XVIIe).\n",
#  'ARMANDY {Le Général Cle) [et Cle“* E. dL 34, rue\nde Bassano (vin*) — et {gj des Cinq-Cantons, K\n[p=^l Carpenlras (Vaucluse) UA\n',
#  'ARMEZ (M. Louis), Ingénieur civil, Député des Côles-\ndu-Nord [et M“* née Gl’ILLON], 25, rue de Bour¬\ngogne (vne)—et jJj du Bourgblanc, K Plourivo,\nëâ Paimpol (Côtes-du-Nord).\n',
#  'ARMSTRONG (Thomas de SAINT-GEORGES de), C.\nqopqoR, Ancien député, gentilhomme de la Cour\nde S. M. le Roi de Portugal [et M“* née de FARIA],\n40, avenue Kléber (xvie). H\n',
#  "Arnal (d') : voir de Serres (d’).\n",
#  'ARNAL, née DAGLIN (M"* Albert), 53, rue de Pon-\nthieu (vine), - et (S d’Auberive, K\n(Haute-Marne).\n',
#  'ARNAUD (C,e Raoul d’) O. I. tzS, C. K, [et Cu”* liée\nMARTIN-DESLANDES],44, avenue Marceau(vm*l.\n',
#  'AG\n',
#  'ARNAUD de L’ARIÈGE (Joseph), 19, quai du\n4-Septembre, à boulogue-sur-Seiue.\n',
#  'ARNAUD JEANTI (M. et M“* Georges), 14, avenue de\nMessine (vm*).\n',
#  'ARNAUD-JEANTI, née LA CHAUSSÉE (M-* L.), 11,\nrue Arsène-lloussaye (vin*).\n',
#  'ARNAUD JEANTI (Yl. et M"* Gaston), 10, rue Léonce\nReynaud (xvi*) — et à Carolles, K Sartilly (Man¬\nche).\n',
#  "Arnex (d'| : voir de Rory J’Arnex.\n",
#  'ARNOULD (Dr) [et M— liée DUBARRY, 24, rue\nd’Assas (vi») [I 102.20],\n',
#  "ARNOULD (Casimir-Victor) [et Mm* née de PERCY'],\n12, avenue Victor-llugo (xvi*).\n",
#  'ARN\n',
#  '41\n',
#  'AST\n',
#  "ARXOl'LT • (Edmond), 12, Villa Spontini (xvf)\n[35697.44].\n",
#  'ARNOULT (Léon), 167, bon!. Malesherbes (xvtf); AG\n',
#  'ARNOUS (Mm" L.), née ANDRÉ de LA CHARENTE,\n8, place dTéna (xvi°) — et de Montchaude, K\nfi [Or] Rarbczieux (Charente) — et fl-jj de la\nBoulnie, si Sancerre (Cher).\n',
#  'ARNOUX (C1* et C\'""» cl\'),. 1, avenue Marceau (xvf)\n',
#  '17» 529.10].\n',
#  "Arnouville (d'j : voir Ciioppin (d').\n",
#  'AROSA (Achille), S, avenue Victor-Hugo (xvf) — et\njgj de Martigny, la \\y~ fi [0] Arques-la-Iiataille\n(Seine-Inférieure). AC\n',
#  'AROSA (Paul) [et M“" née ROOSEVELT], 26, rue\nBrunei (xvif). AG\n',
#  'ARQUINVILLIERS (R°° d’) [et R°->- née de CASA-\nB1ÀNCA], 83, avenue du ISois-de-Boulogne (xvt").\n[35683-46] — et ffo de la Carrière, SI î?= 35 Saint-\nAvertin (Indre-et-Loire), fi [Or et Et] Tours.\n',
#  'Arroara (d’) : voir de Trabadklo.\n',
#  'ARROU (Dr Joseph), Chirurgien des Hôpitaux [et\nM“* née FÉLIX-VOISIN], 9, rue Bayard (viir).\n',
#  'Ars (d’) : voir de Bréhond d’ARS.\n',
#  'ARSIGNY (C“ d’) [et <>•■• née d’AIGNAl\'X], il, rue\nFrançois-Ponsard (xvf) [if Im. 677.44]— et "g* de\nGlatigny, s }f= Souday [4 k], fi Mondoubleau et\nle Plessis-Dorin (Loir-et-Cher).\n',
#  'Arsï (d’) : voir de Goiy d’ARCY.\n',
#  'ARTEMARE (M™ d’), née ROUSSEAU des MÉLO-\n',
#  'TRIES, 2, square de La Tour Maubourg (vu*)— éêî\ndu Haut-Philaine, [>2 fi Blois (Loir-et-Cher).\n',
#  'ARTEMARE (Henri d\') [et M\'"* née de BUZOXNIÈRE],\nmêmes adresses.\n',
#  'ARTEMARE (M. Pierre d’) [et Mm* née Yvonne DE-\nBROU], 2, square de La Tour-Maubourg (vif)W\net même ^gj .\n',
#  'ARTENSAC, née de LAMBERTERIE <C-°-° de CAL¬\n',
#  'MEES d’), — jgj de Montvalcnt, IS1 Martel\n(Lot), fi [Or], Montraient, 2 ldi.\n',
#  'ARTHEZ-LASSALLE (Armand d’) [et Mm* née de\n',
#  'RAYMOND de LALANDE], 11, rue Boissière (xvt*),\n',
#  '— et jà d’Aberats, El fi Saint-Palais\n',
#  '(Basses-Pyrénées). H-UA\n',
#  'ARTHUR-MERCIER, Docteur en Médecine [et M1,10 née\nLAMY], 15, avenue Mac-Mahon (xvir) [35 582.16].\n',
#  'ARTHUY’S (B°” d’) [et B”*** née Denise TA VEAU de\nLAYIGERIE], 30, rue de Saint-Pétersbourg (vin*)\n',
#  '— et jgj de St-Étienne, KJ St-Servan fi\nSt-Malo (Ille-et-Vilaine).\n',
#  'ARTICLE (J.-Bertrand), 62, avenue du Bois de\nBoulogne (xvt") — et jgz d’Hautelort (Dordogne).\n',
#  'AC-CF\n',
#  'ARTOIS (Vu Edmond d) [et Vl*”* nee PUMJLES\nd’HERBINGHEM], 84, rue d’Amsterdam <ix°).\n',
#  'ARTOIS de BOURXONVILLE (Armand d’), O. I. y,\nHomme de lettres, conservateur à la bibliothèque\nMazarine [et M“» née Jeanne-Marie HERVET], 23,\nquai Conti (Datais de l’Institut) (vi*) — et ifo la\nMozuticre Varennes-Jarcy, ISJ Mandres (Seine et\nOise) hr: fi [P-L-M] Combs la-Ville.\n',
#  'ARTl\'S (Louis) [et M“” née PIAT], 105, boulevard\nHaussmann (vin").\n',
#  'ARVENGAS (René), Chef tfEscadron (l’Artillerie\n[et Mme née Louise MASSIAS], 14 bis, rue Jadin\n(xvii*) — et (£j de la Iloussaye, Kl 1900“]\nMarcilly-en-Villelte," fi La Fcrtê-Saint-Aubin\n(Loiret). TJA\n',
#  'ASSAILLY (Cl*“" Octave d’) née CUNIN-GR1DAINE,\n10, rue de Marignan (vin*) — et de la Sal-\nmondière, K Niort, dist. 9 kil., fi halte d’Ar\n',
#  'thenay (Deux-Sèvres).\n',
#  'ASSAILLY (C1"" A. d’), née MALLET, 27, rue\nCambacérès (vin*) — et même (g) .\n',
#  'ASSAILLY . Y*»"* Arthur née OLIVIER des BOR¬\n',
#  'DEAUX, à Pont-de-PArche (Eure).\n',
#  'ASSAS (M“ d’) [et M"\' née de CAMItRAY], 103, rue\nLa Boétie (vin") [35 521.57] — et xgz d\'Ortiés, ESI\njÿ= 35fiSalbris (Loir-et-Cher) — et de Castel¬\nnau, K Nant (Aveyron).\n',
#  'ASSAY (C1""* Léonce d’), née d’ANTHENAISE, 21,\navenue de Tourville (vit*) — et {gs des Rodons,\nKl fi [Or] La Chapelle-d’Angillon (Cher).\n',
#  'ASSAY (C‘« H. DESTUTT d’) [et C-°- née d’ÉRARDJ,\n46, boulevard Maillot, à Neuilly-sur-Seine — et\nÊ(*a de Vicques, KJ Jort (Calvados).\n',
#  'ASSAY (C1* Alain DESTUTT d-), mêmes, adresses.\n',
#  "ASSAY (C1* Henry DESTUTT d^fetC'**” néedeFAY’ET],\n8, rue de Varenne (vil*) — et fgj d’Ecos, KJ jj=\nEcos fi Bray-Ecos (Eure).\n",
#  'ASSELIN de CRÈVECOEUR (M. et M““), 47, rue La\nBruyère (ix*) —etjgj d’Irrcville, KJ Evreux (Eure).\n',
#  'ASSËZAT de BOUTEYRE (M”*), née DOUT1IWAITE,\n46, boni, de La Tour Maubourg (vu") — et {gj de\nBouteyre, K ]>= fi[P-L-M] LePuy (Haute-Loire).\n',
#  'ASSIER (Cle Charles d’), 3, rue Grellulhe (VIII*).\n',
#  'RR-UA\n',
#  'ASSIER de POMPIGNAN (Raoul d’), #, Lieutenant\nde Vaisseau [et M“" née LAWLESS], 75, rue do\nRennes (vi“).\n',
#  'ASSIER de VALENCHES (M“* d’), née CARTIER,\n18, avenue Friedland (vin*).\n',
#  'Assv (d’), voir aussi d’ArniGNY ü’Assy.\n',
#  "ASTAMËRES (C1* Clément d’) [et C1*’1' née de\nPANGE], 12, rue de Martignac (vif) — et à Ca-\nbreton (Landes). RA\n",
#  'ASTIER de LAYIGERIE [Colonel B“» d\'), O. #, [et\nR"»"» née de FRANCE], 4, rue Cortambert (xvf) —\net gga de Fortoiseau, K [35 N" 5], Dam-\nmarie les-Lys, 4 kilBScine-et-Marne), fi [P-L-M]\nMelun. H-M-UA\n',
#  "ASTIER de LA VIGF.RIE (B“ Maurice d'), même\nadresse — et même {g).\n",
#  'ASTIER de LA Y1GER1E (B"» Raoul d’ [et B°— née\nde MONTALIYET], il, rue de Courcelles (vuf ) — et\n',
#  'ÉÊj de Rançay, K {j= Niberne fi Cliàteauroux\n(Indre). J\n',
#  "ASTIER d'USSEL, née de NOLLENT (CA*— d’) 11 bis,\nrue Chomel (vif) — et à Alençon (Orne).\n",
#  'AST\n',
#  '42\n',
#  'AUB\n',
#  'ASTIER d\'USSEL (Cu Georges d!] [et C\'*"» née de\nMARICOURT], 20, rue de Miromesuil (vnr) — et\n{êî de La Carrière, E [ÿ= 3 kil., Cormolain\n(Calvados).\n',
#  'ASTRESSE (Philippe), Avocat à la Cour, I. SJ!, ®,\n>J< [et Mm" liée ATNET], 82, boul. Saint-Germain\nIv”) [Ut 817.06 — et à Cheimevières-sur-Marne,\nKl {?= éS La Yarenne (Seine-et-Oise).\n',
#  'ATLÉE (M. et Al"» George-Falconer), 4, rue Léo-\nDelibes <xvi°>.\n',
#  'ATLEE (MUo), 24, rue Octave-Feuillet (xvf).\n',
#  'Atbisco (Duc d’) : Voir Duc de Bauffremont.\n',
#  "ATTAIXYH.LE, née MA SSE.NA d'ESSLING (M“* LES-\n",
#  'CUA’ER d’), 8, rue Jean-Goujon (viii») — et (gj de\nDroite, K éë [Et] Droué (Loir-et-Cher).\n',
#  "ATTALNVILLE (Pierre LESCEVER d') [M- née de\nYEGARANO], 8, rue Jean-Goujon (VIII») T 821.42]\n",
#  '— et même à - H-B-RR-UA\n',
#  'AUBAN-MOET (M—*), 102, boulevard Malesherbes(xvn»)\n',
#  '.]35 568-14J— en son hôtel,à Épernay (Marne)—{& de\nSaran El Epernay (Marne) — et Villa Saint-Victor,\nCimier, à Nice.\n',
#  "Al'BARET (C*-) [et C1-* née SIRY] ,11, rue de Ga¬\nlilée (xvr) — et Villa des Terrasses, E i^= La\nCelle-Saint-Cloud (Seine-et-Oise) [0] Vaucresson.\n",
#  'UA\n',
#  'Aübé de Bracoijf.mont : Voir de Rracqfemont.\n',
#  "AL'BË (Émile), 6, rue Cambacérès (viif)— et 7, rue\nde Provence, à Versailles. UA\n",
#  'AEBË \'(Jules), Agent de change [et M"* née JOE\'S-\nSET], 81, avenue Victor-Rugo (xvi°> [35 843.84]. —\nà de Montjoy. [35 N» 12], E jÿ= iS [Orsay] (Seine-\net-Oise).\n',
#  "AEBERJO.N (C1* d’), 130, faubourg S'-Honoré (vin»)\n",
#  '— et de Saint-Félix, E [M] Saint-Félix\n',
#  '(Haute-Garonne). H-Sp\n',
#  'AEBERJON (M‘‘ d’), mômes adresses.\n',
#  'AUBERJON (V*- d’) [et V-— née JENTY], 130, fau¬\nbourg Saint-Honoré (vin*) — et {ÊS de Verdalle,\nE jÿ= Verdalle, Soual (Tarn). H-Sp\n',
#  'AEBERJON (C‘» Antoine d’), Lieutenant au & cuiras¬\nsiers, à Noyon (Oise), — et mêmes adresses.\n',
#  'AEBERJO.N, née de BOISSAC, (C1’1" Dominique d’),\n9, rue Jean Jacques Bel, à Bordeaux — et ($5 de\nla Pominarède, E Labécède-Lauragiiais (Aude).\n',
#  'AEBERNON (Raoul) [et AP"* née de NE R VILLE], II,\nrue Montchanin (xvnî [35857.18] — et ^ de\nNointel, E jjp: [35-8] Breuil-le-Sec (Oise),[N]\nNointel-S‘-Aubin. AC-B-J\n',
#  'AUBERT M»- Pauli née do CHASSELOUP de CHA-\n',
#  'TILLON, 86, rue de Lille (vit») [35727.16] — et\nLe Cottage, E [ 1 Saint-Hilaire-Saint-Florent\n(Maine-et-Loire), — ê de Quinault, E tiS\nLibourne (Gironde).\n',
#  'Adbkrtot : voir Houruet-Aibertot.\n',
#  'AUBIGNY (AI" d’), Lieutenant-Colonel de cavalerie\nen retraite, O. # [et AP»* née de WTTTE], 51, rue\nSclielfer (xvi*) (Villa 11“ 18.) — et de Mont-\nvaillant, E [4= Brandon (Saône-et-Loire),\nP-L-Al] Clermain.\n',
#  'AUBIGNY (C1* Ludovic d’), Ministre plénipotentiaire\nde France, K, 18, rue Miromesnil (viii*). U\n',
#  'AUBIGNY (Cu Edouard d’) [et C1*"* née de CATHE-\nLINEAU], 70, rue de Aliromesnil (vin*) — et 3,\nrue Saint-Louis, à Amiens (Somme).\n',
#  "AUBIGNY (C1* Jacques <T>, 61, avenue d'Antin (vin*)\n",
#  '— et 5, rue Saint-Louis, à Amiens B-SH\n',
#  'AUBIGNY (Le Général M" d’) G. O. H-, [et AP- née\n',
#  'LE BOEUF], 20, rue Vaneau (vit») — d’O, E\njî= Alortrée gS Surdon (Orne).\n',
#  'AUBIGNY (AI- Octave de), née DESAIAROÜX de\n',
#  'GAELAIIN, 1, rue de La Planche (vu*).\n',
#  'AUBIGNY (B»” Albert d’), même adresse.\n',
#  "AUBIGNY (B»” Lucien d') [et B0””* née de VILLE-\nNEUVE], 30, rue Boissière (xvi») — et gà de Bois-\nDoublet, E jf= éS Torcé (Sartlie).\n",
#  "AUBIGNY d’ASSY (AI--) [et AI - née de B0NV0E-\nLOIR], d'Assy, E Langaimerie (Calvados).\n",
#  "AUBIGNY d'ASSY, née BUSSON-DUVIVIER (O-d'),\n42, avenue Henri-AIartin (xvi») — et même flà .\n",
#  "AUBIGNY d'ESAIYARDS, née GOUPIL (C-- Dr“ d’),\n18, av. de Messine (VIII»), — et à d’Esmyards,\nE Brandon (Saône-et-Loire) M [P-L-M] Clermain.\n",
#  "AUBIGNY d'ESAIYARDS (Cu d’) [et C*»»»* née de\n",
#  'RANST de BERCHEAI], 4, avenue Hoche (vm») —\net même à • A-H\n',
#  'AUBIGNY d’ESAIYARDS <V>» d’) [et V-- née de\nFLEERTEU], 9, boul. de La Tour-Maubourg (vif)\n',
#  '— et M de Lécluse, E jt— ^ [P-L-AI] Bel-\nleville-sur-Saône (Rhône), — et ^ de Peschéré, E\nBreil-sur-AIerize (Sarthe).\n',
# ...
#  '(Aude) — et à Verdun-sur-Garonne (Tarn-et-\nGaronne).\n',
#  'BARBUAT du PLESSIS, née ROCAULT (M»«de), 19,\nquai Malaquais (vi«) — {fis de Sainte-Sabine,\n12! Pouilly-en-Moutagno (Côte-d’Or) — et à Po-\nmard, [g Beau me (Côte-d’Or), si [P-L-M] Po-\n',
#  'mard.\n',
#  'BARBUAT du PLESSIS (Pierre de) [et Mm® née de\nSAINTE-ANNE], 18, avenue de La Bourdonnais\n( vu*) — et {fis de Maulnes, K Cruzy-le-\n',
#  'Cbàtel (Yonne). A-H\n',
#  'BARCLAY, née de BELZIM (Lady), G, avenue Mar¬\nceau (VIII*).\n',
#  'BARCLAY (Cecil), même adresse. RR\n',
#  'BARCLAY (Colville), 2”e Secrétaire de l’Ambassade\n(ïAngleterre, 39, faubourg Saint-Honoré (vin*).\n',
#  'BARDAC (Noël) [et M”*], 1, avenue Montaigne,\n(vm*) [3*501.50] — et {fis le Haut Bue, la\nVersailles 35 (Seine-et-Oise).\n',
#  'AC-AL-B-CF-Y\n',
#  'BARDAC (Léon), mêmes adresses.\n',
#  'BARDAC (Joseph), 1, avenue Marceau (xvi*) [35519.43],\n',
#  'AL-Y\n',
#  'BARDAC (M. Sigismond), 6, rue de La Baume (vm*)\n[35 581.68], AC\n',
#  'BARDIN (C“*“ de), 17, avenue de Tourville (vu*).\n',
#  'Paris-Mondain — 1608\n',
#  'BAR\n',
#  'Bardon de Segonzac : voir de Segonzac.\n',
#  'BARDONNET HYDE de NEUVILLE (V‘« et Y"-de),\n21, rue de Marignan (vm*) —et {fia de Lestang, S\ns| [P-L-M] Sancerre (Cher).\n',
#  'BARDOT (Henri), Juge au Tribunal de Commerce\nde la Seine [et M“* née L1ÉNARD], 190, rue de la\nCroix-Nivert (xv°> [35 719.36].\n',
#  'BARDOUX (M”*), 37, rue Jean-Goujon (vm*).\n',
#  'BARDOUX (Jacques), Docteur ès lettres [et M”* née\n',
#  'GEORGES PICOT], 11, rue Mérimée (xvi*) — et\nvilla de Saint-Saturnin £53 Saint-Amant-Pal-\nlende (Puy-de-Dôme), â [P-L-M] Les Martres-de-\nYeyre.\n',
#  'Bargemon : voir de Villeneive-Bargemon.\n',
#  'BARI S. A. R. (M”* la G-»» de), 8, rue Mati¬\ngnon (vnr). [35304-77] — et Petit {fij de la Mal-\nmaison, [g Rueil (Seine-et-Oise).\n',
#  'BARI (<> de), mêmes adresses. AC-H\n',
#  'BARIATINSKY (P°* et P0**** A.-W.), 6, place des\nEtats-Unis (xvi*) — -villa Notre-Dame, à Saint-\nRaphaël (Var) — et à Staruberg (Bavière).\n',
#  'H-RR-U-DA\n',
#  'BARIATINSKY (P** Alexandre) [et P°**“ née S. A.\nP**”* Catherine YOURIENYSKY], villa Georges, à\nNice (Alpes-M”**). RR\n',
#  'BARILLOT (Léon), K, Artiste peintre [et M“* née\nYILLEMENOT], 29 bis, rue Demours (xvn*). UA\n',
#  'Barnevili.e : voir Brisoüt de IUrnevilie.\n',
#  'BAR0GHE (M- A.), née NAN1JUETTE, 53, rue La\nBoétie (vine) 35 |330.08] —et {fia de la Sergentière,\nKl jÿ=ê3 Juziers (Seine-et-Oise) —et {fia du Banel,\n',
#  'IS1 Matton-Clemancy, iÈ Carignan (Arden¬\nnes).\n',
#  "BARONCELLI de JAVON (B01 de), Chevalier du Cam¬\nbodge, O. A. '!], 8, rue des Saussaies (vm*).\n",
#  'BARON-LARCANGER (M”* A.) [née FRAGNIAUX],\n262, faubourg Saint-Honoré (vin*).\n',
#  "BARON-LARCANGER (Roger) [et M“* née HAUGK],\n35, rue de Clicliy (ix“)— et {fia d'Henncmont,\nK ÎF1 [O] Saint-Germain-en-Laye (Seine-et-\nOise). H\n",
#  'BARON-LARCANGER (Maurice) [et Mm* née dePON-\nTON-CH1BOURG], 12, cité Vanta* (vu*) — et {fia\nde Bellegarde, K {?= Chàteauneuf-la-Forêt(Haute-\nYienne), é3 [Or] Gliàteauneuf-Bujaleuf.\n',
#  'BARON-LARCANGER (Emmanuel) ]etM“” née LAR-\nK0ZE], 16, rue de Vienne (vm*).\n',
#  'RAROUX (M. et M“’), 48, rue Roissière (xvt*).\n',
#  'BARKACHLN (Ed.), 4, rue Saint-Florentin (i*r) — et\n{fij deSigny-le-Petit, K Jt=s|[E et i\\] Signy-le-Petit\n(Ardennes).\n',
#  'BARRACHIN (Pierre) [et M— née BROCHETON], 29,\nfaubourg Saint-Honoré Win ) — et même\n',
#  'B-RR-UA\n',
#  'BARRACHIN (Jean) [et Mm* née MORAND],35,avenue\nd’Eylau (xvi*) — même {fi{ — et la Solitude à\nSaint-Gratien, K 35 £§ [N], (Seine-et-Oise).\n',
#  'BARRACHIN (M11* Suzanne), 10, rue La Boétie (VIIIe)\n[35560.38].\n',
#  '4\n',
#  '50\n',
#  'BAS\n',
#  'BAR\n',
#  'BARRAL, née RIGAUX (C1—* de>, 36, avenue Klé¬\nber (xvi*) — et à Soissons (Aisne).\n',
#  'BARRAL (C“ de) [et C1"1" née Geneviève de BEAU-\nFRANCHET], mêmes adresses.\n',
#  'BARRAL (C“ de), mêmes adresses.\n',
#  'BARRAL-MOMAUVRARI) (O de), 14, rue Fortimy\n(xvul — et à de Barral-Bissy, SI j*= ëi [P-L-M]\nChambéry (Savoie).\n',
#  'BARRAL-MONTFERRAT iMu de), Ancien Secrétaire\nd\'Ambassade [et M" née PAI1ANAGUA], 7, rue\ndu Parc de Clagny, à Versailles — et de Bar¬\nrai, [S [j= [P-L-M] Voiron (Isère). A\n',
#  "BARRAl. MO.VrFKRI1AT' (Cle de), mimes adresses.\n",
#  'BARRAUTE, née de BARBOTAS (C**— de), 118, rue\nLa Boétie (vin*) — et A de Barrante et d’Arinenda-\nritz, K Sauveterro-de-Béarn (Basses-Pyrénées).\n',
#  'Barhe de Na.medil : voir La Barre de...\n',
#  'BARRÉ de LAPiCY (F.), 32, rue Caumartin (ix«). UA\n',
#  'BARIÎÉDA 1111** de), 28, avenue Hoche (vin-).\n',
#  "BARRÈRE, née de PONTÉCOl'LANT (M«* de), 40,'\nrue Viguon (IX°) — et xLz de Pontécoulant, 53\nCondè-sur-Noireau (Calvadc:).\n",
#  'BARBET (C‘* de), 45, rue Ar.:poro (xvn*) — et (Si de\nGrainville, Kl Fleury-sur Anüelle (Eure) —\net à Verneuil (Eure). UA\n',
#  'BARRIAS (M”’ L.-E.), née BRELAY, 0, avenue des\nChasseurs (xvn*) [Z 533.11|.\n',
#  'Barros (de) : voir de Moxteibo de B.\n',
#  'BARROT (Joseph), 12, rue Logelbach (xvn*).\n',
#  'BARRY [Charles), Avocat au Conseil d\'Etat et à la\nCour de Cassation [et M"* née JOUET], 34, rue de\nGrenelle (vu*) — manoir de Bernouville, K Of-\nfranville (Seine-Inférieure) — et ^ de Thoisy-le-\ndésert, IK ifë Pouilly-en-Montagne (Côte-\n',
#  'd’Or). AL\n',
#  'BARRY (Le Général Emile), 0 éft [et Mm* née GAIL-\nLIARD], 22, avenue de Neuilly, à Neuilly-sur-\nSeine — et aà du Signal, K Sainte-Foy-lès-Lyon\n(Rhône). ÙA\n',
#  'BARTHÉLEMY (TP* de), Explorateur, 51, rue Pierre-\nCharron (vin*) [Ut 563-10]— et jà de Douaville, K\nParay-Douaville (Seine-et-Oise), |p= (g[Or| Ablis\nParay. A-HÜA-Y.\n',
#  'BARTHÉLEMY, née Marie AUBERT (M“* Anatole de),\nfl, rue d’Anjou (vnr) — et à de Malmy, K\nVille-sur-Tourbe (Marne).\n',
#  'BARTHÉLEMY (Cl* Jehan de), mêmes adresses. CF\n',
#  "BARTHOLDI (M“* Auguste), 82, rued'Assas (vr>).\n",
#  'BARTHOLDI, née DELESSERT (B»"»»i, 21, rue Ray-\nnouard (xvr) — et de Petit-Bois, K fp [0]\nJouy-en-Josas (Seine-et-Oise).\n',
#  'BARTHOLOMEU FERREIRA (Antonio Maria), Pre¬\nmier Secrétaire de la Légation du Portugal [et\nM”*], 8, rue Franklin (xvi*).\n',
#  'BARTHOLOMEY, née MÀRTINOW (M- Michel de),\n12, rue Boissy-d’Anglas (vin*).\n',
#  'BARTHOLONI, née FRASKR-FRISELL (M™* Anatole),\n53, rue de Verneuil (vu*) — et de Goudrée,\nK Ëâ [P-LMJ Thouon (H1* -Savoie), Sciez.\n',
#  'BARTHOLONI (Charles) [et M- née de CR0ISMARE),\n',
#  'SZz de Yersoix, K jÿ= [P-L-M] Yersoix\n(Genève-Suisse). UA\n',
#  'BARTHOLONI, née Jeanne de BEAUFORT (Mm* Fer¬\nnand), 12 rue de La Rochefoucauld (ix*) [T* 221.51]\n— et Villa Bartholoni, à Sécherou, K T.\n[P-L-M] Genève (Suisse).\n',
#  'BARTHOLONI (Jean), 12, rue de La Rochefoucauld\n(ix*) [Tî 221.51] —et même villa.\n',
#  'BARTHOLONI (René), Lieutenant au 3P dragons, à\nEpernay [et M”* née Louise GASTALDI], 12,\nrue de La Rochefoucauld (ix°) [T? 221.51] — et 22,\nrue du Commerce, à Epernay, K [75 2.41],\n«g (Est) Epernay (Marne),\n',
#  'BARTHON (Charles) [et Mm* née LEVAINV1LLE,26,\navenue de l’Alma (vin*), AL\n',
#  "BARTILLAT (M“ de) [et M'** née de MONTLIVAULT],\njês d’Ecaquelon, K Montfort-sur-Risle (Eure),\nag [0] Montfort-sur-Risle et St-Léger-Boissey. H\n",
#  'BARTILLAT (C** Henri de), ^ de La Boucheffoliére,\nK Cosso-le-Vivion (Mayenne), jÿ= gg [0] Chàteau-\nGonthier. A-H\n',
#  'BARTISSOL (V1* Edmond), A, Député des Pyrénées-\nOrientales [et V1»**»], 17, avenue du Bois-de-Boulo-\ngne (xvi®) — et à de Fleury-Mérogis, K\nM St-Michel-sur-Orge (Seine-et-Oise).\n',
#  'BARY (Albert de) [et Mme née de SEYNES], 13, rue\nVaneau (vu*).\n',
#  'BASCHET (Marcel), Artiste peintre, éft [et M" née\nGU1LLEMETEAU], 17, quai Voltaire (vu*) — et\nvilla, à Gagny (Seine-et-Oise). AL-UA\n',
#  'BASHKIRTSEFF (Mme Marie), 167, rue de France,\nà Nice.\n',
#  'BASILY (Alexandre de [et M”e née Isabelle SAM-\n',
#  'PIERIJ9, rue d’Anjou (vme) — et le Pausilippe,\nà Montmorency (Seine-et-Oise). H\n',
#  'BASSANO, née SYMES (Da*,e de), 9, rue Dumont-\nd’Urville (xvi*) — et 3, Malborough Gâte Bayswter-\nRoad, Hyde Park, London.\n',
#  'Bassaiiaba : voir de Rbancovan.\n',
#  'BASTARD (M. et M“* Edmond), 21, rue de Marignan\n(vin*).\n',
#  "BASTARD (Fernand), Capitaine d'artillerie [et M“e\nnée de RELLESEIZE],51,rue Pierre-Charron [vin*].\n",
#  'H\n',
#  'BASTARD, née GREENOUGH (B°»»e de), 36, avenue\ndu Bois-de Boulogne (xyi*)—et Ê de Grossouvre,\nK Sancoins 6 kil. (Cher), [Or.] Grossouvre\n500 mètres et Laguerche 10 kil.\n',
#  'BASTARD (B*“ de), mêmes adresses — et de Saint\nDenis, K 6= Layrac (Lot-et-Garonne), gg [M|\nLayrac et Lafox. H-J RR\n',
#  'BASTARD (I!°“ Pierre de), Lieutenant au 7* Dragons\nife de Grossouvre ES Sancoins (Cher) [Or]\nGrossouvre. J\n',
#  'BASTARD (B0* Raymond de), ^ de Bacliac, K\nCasteljaloux (Lot-et-Garonne), jg [M] Bou-\nglon,7kil. j\n',
#  'BAS\n',
#  '51\n',
#  'BAU\n',
#  'BASTARD, née de YIALEVILLE (B0"* Arthur de),\njÊj de Bellerive (Dordogne), El tâ [Or] Le\nBuisson.\n',
#  'BASTARD (B°“ Edouard de) [et B‘"me née Marie de\nROHAN-CHABOT], t, rue François I" (vnf) — et\n{gj de de la Çoste, K Castelnaud-Fayrac (Dordo¬\ngne). » H\n',
#  'BASTARD (B"VAlfred de), villa Bastard, à Pau\n(Basses-Pyrénées).\n',
#  'BASTARD d’ESTANG (O de), K, Ancien Sous-Pré¬\nfet, maire d’Avoise, 21, rue Saint-Dominique (vu*)\n—et {fis deDobert, K ]ÿ=iSl [0] Avoise(Sarthe). A\n',
#  'BASTERRÈCIIE (Stéphane) [et M™» née DRAKE del\nCASTILLO], 97, rue de Lille (vif) — et Là de\nBiaudos 53 Biaudos (Landes). U A\n',
#  'BASTIDE du LL’DE (Maurice) [et YI»» née TOUR.\nNOUER], 70 bis, rue Notre-Dame des-Champs (vr)\n— et du Lude (3! iS [Or] La Ferté-Saint-\nAubin (Loiret).\n',
#  'BASTIN (Eugène-Louis), #,I. D, Consul de Belgique\net du Grand Duché du Luxembourg [et Mme\nnée Alice HENARDT], 3, rue Hamelin (xvf) (jeudi).\n',
#  'BATAILLE (M“* la Générale), 24 bis, rue Greuze\n(xvf).\n',
#  'BATANERO de MONTENEGRO, née Marie YVAT-\n',
#  'JEN (M»»>, 87, avenue Kléber, (xvf) [S 694.96] —\net {ÊS des Nouettes, 53 jÿ= èS [O] Rai-Aube\n(Orne).\n',
#  'BATBEDAT (Roger), # [et YI"- née BOITTELLE],\n10, rue Octave Feuillet (xvf) — et villa Ylontgou-\nbert à Deauville (Calvados). RR\n',
#  'BATGAVE (M.) [et M“» née Henriette DEBRIE], 27,\nrue Mulitor (xvi-).\n',
#  "BATEREAU (Louis), Capitaine au 22* d'Artillerie, à\nVersailles [et Ylm» née LEROY-BEAULIEU], UA\n",
#  'BATTHYANY (C‘* Bêla) [et C“»“ née Jeanne SEIL-\n',
#  'LIÈRE), 56, avenue du Roule, à Neuilly-sur-Seine.\n',
#  'RR\n',
#  'BATZ (B"»»\' de), 36, rue de Tocqueville (xvifl.\n',
#  'BATZ (B0” R. de), même adresse.\n',
#  'BATZ-TRENQUELLÉON (B°-> André de), 19, rue de\nBerri (viif) — et à Compïègne (Oise).\n',
#  'BAUBIET, née DAUBRÉE (M"e Louis),\'250 ifs, boni.\nSaint-Germain (vif) — et de La Romagèrc, O\n',
#  'JIM [Or] St-Gaultier, 9 kil. (Indre).\n',
#  'BAUBIET (Henri) [etYl”» née de MAISTRE], 250 bis,\nboni. Saint-Germain (vif) — et même à.\n',
#  'BAUCHE de BRAGARD iLe Commandant Georges),\nK [et Mm* née AUTARD de BRAGARD, 1, rue du\nMidi, à Neuilly (Seine). AC-B\n',
#  'BAUDE {Commandant),# [etM- - née NIN0T], i,bou¬\nlevard Inkermann, à Neuilly (Seine).\n',
#  'BAUDE (B°» Georges), Villa Saint-Georges, à firoi-\nzette, 53 Cannes (Alpes-Maritimes). A-AL-H\n',
#  'BAUDE (Bon Pierre) [et B”*"” née de VAUFRELAND]\n63, avenue d’Antin (vnf) — et de Chardon]\n131 Saint-Germain-Laval (Loire), ^ [P-L-Mj\nBalbigny. H-J\n',
#  'BAUDE (B»” Elphége), 61, avenue de Neuilly, a\nNeuilly.\n',
#  "BAUDICOUR (de), Conseiller honoraire à la Cour\nd'appel, #, 91, boulevard Saint-Michel (v*> — jgj\nde Blanc-Buisson, 53 La Barre en Ouche (Eure),.\n",
#  '— et à de Saint-Cyr, 53 [E] St-Cyr-sur-Morin\n',
#  '(Seine-et-Marne).\n',
#  'BAUDICOUR (Prosper de), 91, boni. Saint-Michel(v*)\n',
#  '— et ^ de Blanc-Buisson, 53 La Barre (Eure).\n',
#  'BAUDICOUR (Paul de) [et M™ liée de LA FRES-\n',
#  'NAYE], 91, boulevard Saint-Michel (v) — {Ê de\nVauville, Kl jÿ= Beaumont èn Auge, (Calvados).\n',
#  'BAUDIN (Mm* François), de La Valette, K Chaste!\n',
#  '(Haute-Loire), jÿ= Védriinies-Saint-Loup (Cantal),\nâ [P-L-M] Saint-Georges-d’Aurac.\n',
#  'BAUDIN (Jean), K, Attaché au cabinet du Ministère\ndes Affaires étrangères [et Mm* née ROUX de\n',
#  'VEXCE ], 19, rue Clément-Marot (vin*) —• et jjj\ndes Prost,E3 |p= ^ [P-L-M] la Pacaudière (Loire).\n',
#  'BAUDIN (Pierre), Député [et M”* née OCHS], 6, ave¬\nnue Mac-Mahon (xvif) [A 580.95].\n',
#  'BAUDON de MONY, née de LIMAI RAC -M». , 8,\nrue François!" (vnf) — (£& du Ris-Chauveron\nK Le Dorât (Haute-Vienne), {5= é3 [Or] Thiat-\nOuradour — et de Gudanes, K M [MJ\nLes Cabamies (Ariège).\n',
#  'BAUDON de MONY" (Xavier) [et M"» née de COURCEL],\n106, rue de l\'Université (vif)— étais du Ris-Chau¬\nveron, K ê5 [YI] Azat-le-Riz Thiat-Ora-\ndour (H‘* Vienne). U\n',
#  'BAUDON de MONY (Charles) [et YI-- née ROCHER],\n113, rue de Grenelle (vif )— {gj du Ris-Chauveron,\n53 Le Dorât (Haute-Vienne), M[0r] Thiat-Ora-\ndour — et Casa Caradoc, Bayonne (Basses-Pvrénées).\n',
#  'H-U\n',
#  "BAUDREUIL (Ernest de) [et YI”' née de LA SELLE],\n5, rue Edmond-Valentin (vif) — et A de Favelle,\n53 jÿ= Saint-Viatre, .5 kil. (Loir-et-Cher), [Or]\nLamotte-Beuvron. A\n",
#  'BAUDREUIL (Louis de) [et YI“* née PÉBIGNON], 31,\nrue de l’Université (vif) — et xtzs de Billy,K^=\nSaint-Vrain (Seine-et-Oise),^ [Or] Bouray.\n',
#  'BAUDREUIL (Emile de) [et YI°>- née de FITTE de\nG0LCY’], 9, rue du Cherche-Ylidi (Vf).\n',
#  'Baldreuil (de): Voir aussi de Fontenay.\n',
#  'BAUDRIER (Jacques), 64, rue Miromesnil (vnf). Y\n',
#  'BAUDRIER (André) [et YI"» née Marie-Louise JAY1E\nTEL], 22, rue de Matignon (vnf) — et d’Aumont,\n(31 Senlis (Oise).\n',
#  'BAUDRY’ d’ASSON (JP’ de), député de la Vendée [et\nYP-- née de LAROCHEFOUCAULD-BAYEUS| —\naà de Foiueclose, l£] Kés LaGarnacue (Vemmu).\n',
#  'BAUDRY’ de SAUNIER (Charles-Louis), Homme de\nLettres [et YI"» née JALABER], 108, rue Lauris-\nton (xvf) [TR 687.08] — et chalet Eva, K Bride -\nles-Bains, YIoutiers (Savoie),\n',
#  'BAUER (Chevalier Robert de) [et B““” née de GINZ¬\n',
#  'BURG 21, avenue de l’Alma (vnf) [p.-à-t.].\n',
#  'BAU\n',
#  '82\n',
#  'BEA\n',
#  'BAUFFREMONT (P”, Duc de), 8", rue de Grenelle\n(vu") — et tà de Brieiiue-le-Chiiteau.K Ê§ Ie]\nBrienne-le-Chàteau (Aube).\n',
#  'BAUFFREMONT (P“ Théodore de), même jêj .\n',
#  'BAUGNIES (Georges), Inspecteur des Finances, 100,\nboulevard Maleslterbes (xvif ) [35 872.48] — et ^\nde Guy St-Fiacrc,K LO] Gournay-en-Bray,\n4 kit (Seine-inf.) DA\n',
#  'BAUGNIES (Jacques), artiste peintre [et M"“ née de\nMONTAGNAC], 23, avenue de Villiers (xvif ). UA\n',
#  "BAUGRAND (Georges), 49 bis, avenue d'Antin (vnfl\n[35 516.70]. AC-AL-B-CF\n",
#  'Ballnv (de): Voir Ogier de Baulnv.\n',
#  'BAULNY (B" de), K, 30, rue IIoissy-d’Aiiglas (vuf).\n',
#  'BAULNY (B“ Jean de), même adresse.\n',
#  'BAULNY (B"» Guy de) [et B“- née de MEFFRAY],\n6, rue Alfred-de-Yigny (vin*) — et ^ de Césarges,\nM Rourgoin (Isère). H-J-RR\n',
#  'BALXNY (B»" Christian de) [et !!"->»- née Louise\nROLHER], 52 bis, rue de Varenne (vu*) — et. tfa\ndu Pointe!, Kl ÎF ÊÜ Brou-Vernet (Allier). U\n',
#  'BAUMANN (Lucien), Administrateur des Grands\nMoulins de Corbeil [et M“s], 19, avenue d’Antin\n(VIII*) [35 672.74].\n',
#  'BAUX (Y1* François de) [et Y1*"* née de MAUSSION\nde GAN DÉ], 3, rue Pérignon (vu*) [35 735.32],\n',
#  'BAVINCHOVE (M— E. de) née CHAUFFARD, S,\nrue d’Estrécs (vu*).\n',
#  'BAYINCHOYE (B““ Paul) [et B*“* née de SAINT-POL],\nmême adresse.\n',
#  'Bayard de la Yi notice : voir La Yingtrie.\n',
#  'BAYE (B°* de), O. I. Q [et B*»** née B"»"* OPPEN-\nHE1M], 58, avenue de la Grande-Armée (xvu») —\net fa de Baye, K jÿ= Baye (Marne), ^ [E] Sézanne\net Epernay.\n',
#  'BAYE, G1* de SAINT-LAURENS (B°* Jean de), 6, av.\ndu Rois-de-Boulogne (xvi*)—et de Colombiéres,\nK Colombiéres (Calvados), jg [0] le Molay-\nLitry. U\n',
#  'BAYNAST de SEPTFOXTAINES (SP* de) [et M- née\n',
#  'LE PELET1ER], 15o, boulevard Saint-Germain (Vf).\n',
#  'BAYSER (M. et Mm” de), 1, rue de Longchamp (xvf).\n',
#  'BAZIN (Gaston),Notaire,[ et M"° née DELAUNA Y|, 52,\nruedeCliehy (tx*) [35 121.72].\n',
#  'BAZIN (William) [et M"” née LE POMELLEC ], 7, rue\nSt-Florentin (vuf) — et ^ de Yillegénis, K\niùB [Or] Massy (Seine et Oise).\n',
#  ...]

# %%
def getAddress(data):
    address=""
    for i, o in enumerate(data):
        if(o.replace(" ", "").isdigit() or 'bis' in o):
            for addr in data[i:]:
                address += addr.replace("\n", " ")
    if(len(address) < 1):
        return "unknown"
    return address

def is_family_name(str):
    if(len(str) < 2):
        return False
    nb_up = 0
    for c in str:
        if(c.isupper()):
            nb_up += 1
    
    return (nb_up/len(str) > 0.6)

def starts_with_family_name(line):
    if(" " not in line):
        return is_family_name(line)
    first_space = line.index(" ")
    if("]" in line[:first_space]):
        return False
    return is_family_name(line[:first_space])

def nom_jeune_fille(str):
    if("née" not in str):
        return ""
    name = ''
    nee_found = False
    for word in str.split(" "):
        if(word == "née"):
            nee_found = True
        if(is_family_name(word) and nee_found):
            name = "née "+ word.upper()
            break
    
    return name

# %%
people_split = []
names = []
addresses = []
for i, line in enumerate(all_people):
    data = line.split(',')
    if(len(data) > 1):
        if(starts_with_family_name(data[0])):
            names.append(data[0] + " " + nom_jeune_fille(data[1]))
            addresses.append(getAddress(data))
            people_split.append(data)
    
people_split
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-d0ab252c7e0a> in <module>
#       7         if(starts_with_family_name(data[0])):
#       8             names.append(data[0] + " " + nom_jeune_fille(data[1]))
# ----> 9             addresses.append(getAddress(data))
#      10             people_split.append(data)
#      11
#
# <ipython-input-70-574b2eb2d135> in getAddress(data)
#       4         if(o.replace(" ", "").isdigit() or 'bis' in o):
#       5             for addr in data[i:]:
# ----> 6                 if(addr[0] == '('):
#       7                     break
#       8                 address += addr.replace("\n", " ")
#
# IndexError: string index out of range

# %%
df = pd.DataFrame({"name" : names, "address": addresses})
df
# Out:
#                                                     name  \
# 0                   ABRADIE-d’ARRAST (Michel-Robert d’)
# 1                                  ABBATUCCI née FORESTA
# 2                                ABBATUCCI (C“ Jacques)
# 3                                     ABBATUCCI (C1""*)
# 4                                     ABEILLE (Adolphe)
# 5                                    ABOILARI) Georges)
# 6                                  ABOVILLE (V‘* H. d’)
# 7      ABOVILLE (B** Christian d’) [et B*»”" née I1EN...
# 8                                    ABRANTÈS née JL'XOT
# 9                                     ABRANTÈS (Duc d’)
# 10                                    ABRANTÈS (M** d’}
# 11                                    ABRANTÈS (Cte d’}
# 12                                ABZAC (C1""* Paul d’)
# 13     fACHER de MONTGASCON ll!°» d’) [et B”""' née J...
# 14                     ACHERY de SAS DON'N'IN'O (P“ d’)
# 15                      ACHON (B°n René d') née LAMOLÈRE
# 16                      AGLOQLE (Mm*) née DU CH AN O Y'
# 17                           ACLOQL'E (M»« AWnée SEBERT
# 18                                  ACI.OQl'E (Maurice)
# 19                                       ACOLLÀS (René)
# 20                                       ADAM (Achille)
# 21                    ADAM (M“* Achille) née VERBERKMOÉS
# 22                                    ADAM (M“* Eugène)
# 23                                         ADAM (Henri)
# 24                                 ADAM (Mm* Hippolytel
# 25                     ADAM (M- Léon) née JÉROME PICHON
# 26                             ADAM (M. et M“* Georges)
# 27                         ADAM (Louis) née PIERRETJ\n23
# 28                  ADAM (Juliette LAMBER) (M“* Edmond)
# 29                                         ADAN (Emile)
# ...                                                  ...
# 12317                              MARQUE de LAGARRIGUE
# 12318                            ZAFIROPULO née PSYCHARI
# 12319      ZAKARIAN (Zacharie-Grégoire) née DE\nPITOËFF]
# 12320                                   ZAMOYSKA (C‘““)
# 12321                           ZAMOYSKI (C1" Ladislas)
# 12322           ZANGARUSSIAN0 (M“* Georges) née PSOMADÈS
# 12323                                            ZARINE
# 12324                        ZBYSZEAYSKI (G1’ Ladislas)
# 12325                  ZÉDÉ (Général Charles) née DUPEY’
# 12326                                     ZELLER (J-S.)
# 12327                     ZELLER d’OOSTHOVE (Roger van)
# 12328                              ZELTENER née ANDERSON
# 12329                                     ZENS (P.-M. )
# 12330                                     ZENS (Ernest)
# 12331        ZENS (Albert) [et M"° née Mathilde CÉMONTJ
# 12332                                   ZENTZ d’A LNOIS
# 12333                                  Z1EGER (Charles)
# 12334                               ZIEGESAR née LARDNER
# 12335                             ZIZIN1A (C1* Étienne)
# 12336                                    ZIZINIA (Jean)
# 12337         ZOGHEB (C- Charles de) [et Cu- née RALLI]
# 12338          ZOGHEB (OGeorges de) [et C-- née SINANO]
# 12339      ZOGHEB (Vu Jacques de) [et Y**”* née SINANO]
# 12340                       ZOGRAPHOS (M. et M"“ Solon)
# 12341                              Z0L0T0VITZ (Lubomir)
# 12342                    ZURLINDEN {Général) née PARTOU]
# 12343                      ZURLO (P"*«“ Aurélie Capece)
# 12344                      Z1IRLO (P** et P1"’* Capece)
# 12345  ZUYLEN de NYEVELT (R-- Étienne de) [et B*“* né...
# 12346  ZYLOF de STEENBOURG (J.) [et M- née d’H ALLO Y...
#
#                                                  address
# 0       5S bis rue Jouffroy (xvu*) — et d’Elhorriaga ...
# 1       103 rue La Boétie (vin*) [35 321.S7] — et flj...
# 2       103 rue La Boétie (mi‘) [35 521.57] — et même...
# 3                             32 rue Washington (vni'j.
# 4      27 Faubourg-Saint-Honoré (vm*) et haras de Vir...
# 5       46 avenue de Breteuil (vu*) [35 707.11] — et ...
# 6                                                unknown
# 7       23 rue de Grenelle (vu*)— et A deGlux K Chàte...
# 8       12 ave- nue Henri-Martin (xvi*) — et sêâ de B...
# 9       12 avenue Henri- Martin (xvi*) —- même de Bai...
# 10           12 avenue Henri-Martin (xvi*) — et même M.
# 11                                               unknown
# 12                          181 rue de La Pompe (xvi*).
# 13      18 avenue d’Antin (vui")— et ià de Villequier...
# 14      62 avenue de la Grande-Armée (xvn‘) — et de S...
# 15      124 rue de Provence (vm*) — et de la Roche-de...
# 16      26 avenue Mar¬ ceau (xvi" )— et jÎ5 de La Bor...
# 17          9 place des Etats- Unis (xvi*)-[35 698.92].
# 18      19 rue de Presbourg (xvi') — et villa Monténé...
# 19               29 avenue Friedland (vin*) [35 547.26]
# 20      21 avenue d’Antin (vin*) [35 311.04] — et 10 ...
# 21                                               unknown
# 22      2 bis rue de La Baume (vin") [35 520.00] — et...
# 23                                               unknown
# 24      47 bis rue Ampère (xvn") [35 525.33] — et & d...
# 25                                33 av. d’Antin (vnr).
# 26      23 av. de Messine (vin") — et 14 rue Circulai...
# 27                                               unknown
# 28                                               unknown
# 29                             75r. deCourcelles(vm")UA
# ...                                                  ...
# 12317                     49 rue de Villiers à Neuilly.
# 12318                          19 rue de Téhéran (vm“).
# 12319   91 rue Jouffroy (xvu*) — et 62 rue de Rome (v...
# 12320                           6 quai d’Orléans (iv*).
# 12321                                            unknown
# 12322                                            unknown
# 12323                          3 avenue d’Antin (vin*).
# 12324   1 boulevard Beauséjour (xvi") [35 531.31] — e...
# 12325                         374 rue Saint-Honoré (r'j
# 12326                                                53
# 12327   3 rueBoccador (vin*) — Sj de Bawbecque Si ]f ...
# 12328                                         27 rue de
# 12329                                            unknown
# 12330                                            unknown
# 12331   4 rue Cambacérès (vin1) [35 224.25] — et jê) ...
# 12332              à Nantes — et 9 bis rue Legendre. RR
# 12333                       75 rue de Courcelles (vm«).
# 12334                           18 avenue Kléber (xvu).
# 12335                                            unknown
# 12336                                            unknown
# 12337                                            unknown
# 12338   8 rue Alboni (xvi*) [35 682.45] — et A de la ...
# 12339                                            unknown
# 12340                     30 avenue Kléber (xvi->. UA-Y
# 12341                        103 boul. Haussmann (var).
# 12342                       15 avenue Carnot (xvji*). H
# 12343                              59 av. Kléber (xvr).
# 12344   34 avenue Kléber (xvi* [35 541.81) — et Pless...
# 12345   70 av. du Bois-de-Boulogne (xvi”) [35 504.24]...
# 12346   9 rue de Sontay (xvu) — et ià de Steenbourg 1...
#
# [12347 rows x 2 columns]

# %%
unknown = df[[x == "unknown" for x in df["address"] ]]
print("Missing addresses: " + str(len(unknown)/len(df)))
# Out:
# Missing addresses: 0.3093059042682433

# %% [markdown]
# # Trials

# %%
import pandas as pd
#import lxml.etree.ElementTree as ET
from lxml import etree
path = 'fdh-gallica/bpt6k205233j/alto/bpt6k205233j_038.xml'

# %%
tree = etree.parse(path)
root = tree.getroot()
full_name = ''
addr_found = False
complete_person = False
for elem in (root.findall(".//{http://bibnum.bnf.fr/ns/alto_prod}TextLine")):
    for line in elem.findall(".//{http://bibnum.bnf.fr/ns/alto_prod}String"):
        word = line.attrib['CONTENT']
        #print(word)
        if(complete_person):
            complete_person=False
            if(is_family_name(word)):
                print(full_name)
                full_name=''
                addr_found= False
                print()
        full_name += word
        full_name += ' '   
        if('.' in word and addr_found):
            complete_person = True
        if(is_address(word)):
            addr_found = True
# Out:
# ABZ AGIT ABZAC (C""1 Pauld'), 181, rue de La Pompe (xvi*).
#
# fACHER de MONTGASCON (B™ d') [et B"" née Jeanne de COURCY], 18, avenue d'Antin (vin"),– et de Villequier, ES è53 [Q], Caudebec-en-Caux (Seine- Inférieure) ^= Villequier.
#
# ACHERY de SAN" DONNINO (P" d'), Ex-camérier secret, 62, avenue de la Grande-Armée (xvn*) et eJj de Soisy-sous-Montmorency, El Ji fi [S] Soisy-sous-Montmorency (Seine-et-Oise).
#
# ACHON (B°n Renéd'), Capitaine au l"r chasseurs [et B™" née de LAMOLÈRE, C"– d'HUST], 124, rue de Provence (vin*), et ^5 de la Roche-de- Gennes, El Sf Gennes (Maine-et-Loire), gg [Or], Les Rosiers-sur-Loire.
#
# ACLOQUE (M™) née DUCHANOY, 26, avenue Mar- ceau (xvi*) – et j*5 de La Borde, Kl Saint-An- toiue-du-Rocher, j: (I au d N" S), âï Wettray (Indre-et-Loire).
#
# ACLOQUE (M™ A.), née SEBERT, 9, place des Etats- Unis (xvi1)- [3698.92].
#
# ACLOQUE (Maurice), 19, rue de Presbourg (xvi1) et villa Monténégro [3°. 590], à Cannes (Alpes-Mari- times).
#
# AC-Y ACOLLAS (René), $(, Conseiller référendaire à la Cour des Cooptes [et Mme née de MOY], 29, avenue Friedland (vin-) [35 547.26] Acquasanta (d') voir de Narducci.
#
# ADAM (Achille), Député dit Pas-de-Calais, 21, avenue d'Antin (vin*) [3: 311.04] et 10, rue Victor-Hugo, à Boulogne-sur-Mer (Pas-de-Calais), -et « La Soli- tude », à Saint-Quentin-en-Tourniont, par Rue (Somme).
#
# AC-B-H-RR-UA ADAM (M- Achille), née VERBERKMOES – et & de Yerneuil, Kl tF & [Or] Veriieuil-sur-Indre (Indre-et-Loire). ADAM (M™' Eugène), 2 bis, rne de La Fiaume (vin0) [3- 520.00] et 21, rue de Conflans, à'Poissy, 3; (Seine-et-Oise).
#
# ADAM (Henri), mêmes adresses. AC ADAM (Mm* Hippolyte), 47 bis, rue Ampère (xvn") [35 S25.33] et fa des Mazurettes, 13 fc= èS [Nj Boulogne (Pas-de-Calais).
#
# ADAM (M»« Léon) née JÉRÔME PICHON, 33, av. d'Antin (viir).
#
# ADAM (SI. et M"" Georges), 23, av. de Messine (vin') et 14, rue Circulaire, à Versailles.
#
# ADAM (Louis), Agent dechange [et M– née PIERRETJ 23, av. de Messine ivni") (Bureaux: 48, rue de Pro- vence) (ix") [3:136.13] – et fa deBrancas, s jj= l£ [0] Sèvres (Seine-et-Oise), -et villa Ellon, à Lion-sur-Mer (Calvados).
#
# ADAM (Juliette LAMBER) (M- Edmond), abbaye de Gif (Seine-et-Oise). ADAN (Emile), # [et M""], 7S,r. de Courcelles (viu")UA ADDA SALVATERRA (M"« d'), 57, avenue Montaigne (vin-).
#
# ADELINE, née FAU (M™ Edmond), 31, rue Pierre- Charron (xvi«) et SA de Sérigny, si fè= â [Or] Cour-Cheverny (Loir-et-Cher).
#
# ADELINE (M- Raoul), née FROGER des CHESNES, pavillon de La Louetière, El ]s= ëH [Or] Cour- Chcverny (Loir-et-Cher). ADELIAE (Gaston) [et M™ née DELONDRE], 55, rue Pierre Charron (vin") et de Moussonvilliers, S f^= S'-Maurice-les-Charençais, 5 kil. (Orne) g|i [0] La Ferté-Vidame (Eure-et-Loir).
#
# H-UA ADELON, née HAENTJEXS (M" Henry), 24, rue de Courcelles (vin-) [3-317.00].
#
# ADELON (Marcel), même adresse. ADELSWARD (B" Axel d'), née WUHRER,20, rue Daru (vme) et à Nice.
#
# ADELSWARD (B"" Gustave d'), née de POURTALÈS 63, boulevard de Courcelles (vin") [3= 508.32] et tfa du Plessis-Mornay, Kl Rochefort-en- Yveliues, 1f= [35 24], £g Donrdan (Seine-et-Oise).
#
# ADEMS de LA ROZERIE (A.-H), Conseiller Maître à la Cour des Comptes, 0. ij^, 3, rue de Monceau (vm°).
#
# ADHËMAR (Ct. d'), née MARIAKI, 33, rue Was- hington (vm«).
#
# ADHËMAR (Y" Olivier d'), [etV– née VERDET] 86, rue de Varenne (vu*) – et éêù de Saint-Hubert, IS Sorgues-sur-l'Ouvéze (Vaucluse et fa de Teillan, E] Marsillargues (Hérault).
#
# ADHËMAR (Y" Robert d'), à Lille (Nord). AFFRE de SAINT-ROME (C'°- Denis) [née de NOGA- RET], 147, rue de Rennes (vie) – et à Soisy-sous-Mont- morency, [S3 Jf= (Seine-et-Oise).
#
# AGACHE (Alfred), 14, rue Weber (xvi«).
#
# UA AGHIO.N (M. et M°" Jules), 24, rue Clément-Marot, (vui«) [3=501.87].
#
# CF Acneau (d') voir: CARPENTIER d'Ac^EAU. AGNEAUX (d') 'voir: de S" MARIE d'Agneaux. AGNELLET (M. et M"' Augustin), 50, av. Victor- Hugo (xvi*).
#
# AGNELLET (M11* Emma), 59, rue de Prony (xvn«) – etvillaàMenthon-Saint-Bernard, El ^= (Haute- Savoie), ^ï [P.-L.-M.] Annecy.
#
# AGXUS lEugène), 59, rue Chardon-Lagache (xvi*).
#
# AûON (la Générale M»' d'), née T1ERSONNIER, 78, avenue fleiiri-Ilartiii (xvi*) – et jêj de Sampange, Kl Nevers (Nièvre).
#
# AG0PIAN- PACHA (M»'), née KHORASSANDJl, 95, boulevard Malesherbes (vui").
#
# AGOPIAN-PACHA (L.), même adresse. Y AG0ILT (M"d')[et M'-MiéedeMONTHICHAIU)], fa de Vandœuvre, IS Coulaus (Sarthe) tg [O|. Le Mans (Sarthe). AGOULT (C" d'), ancien député [et C' née d'ESTAMPES], 19, boulevard de La Tour-Maubourg (vir) et – {Ss de Beauplan, si ^= H Voreppe (Isère).
#
# AGRAIN née de de LESPÉROUX, (M'" d'), 63 bis, rue de Vareune (vu.) et fa de Bressey, IS Arc-sur-Tille 5 kil. (Côte-d'Or) â [P.-L.-M.J. d'Arc-sur-Tille et Magny.
#
# AGRAIN (C" Jean d') [et C1" née Geneviève BOliTlNY], mêmes adresses et villa St-V.illior à Nice.

# %%
addr = ['avenue', 'av.', 'rue', 'r.', 'boulevard', 'b.', 'mêmes adresses', 'même adresse', 'villa', 'place']
def is_address(str):
    return str in addr

# %%
def is_family_name(str):
    nb_up = 0
    for c in str:
        if(c.isupper()):
            nb_up += 1
    
    return (nb_up/len(str) > 0.6)

# %%
def nom_jeune_fille(str):
    if("née" not in str):
        return ""
    name = ''
    nee_found = False
    for word in str.split(" "):
        if(word == "née"):
            nee_found = True
        if(is_family_name(word) and nee_found):
            name = "née "+ word.upper()
            break
    
    return name

# %%
nom_jeune_fille("Arnaud CHAZEAU née GATeAU")
# Out:
# 'née GATEAU'

# %%
s = "34"
s.isdigit()
# Out:
# True
